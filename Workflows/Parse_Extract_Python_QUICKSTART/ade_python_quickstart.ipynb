# %% [markdown]
# ## ADE Python Library Quickstart
# This notebook follows the quickstart code snippets available at https://docs.landing.ai/ade/ade-quickstart
#
# It deviates only slightly from the quickstart example by using an alternate method for setting the API key by declaring it directly in a notebook cell. This is the fastest path to get started, but not the recommended method.
#
# https://docs.landing.ai/ade/agentic-api-key#method-3:-set-api-key-in-notebooks

# %%
# %env VISION_AGENT_API_KEY=your_api_key_here

# %%
# Install the ade-python library
# !pip install landingai-ade
# Out:
# Requirement already satisfied: landingai-ade in /Users/andreakropp/Documents/Github/ade-sample-projects/.venv/lib/python3.12/site-packages (1.4.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/andreakropp/Documents/Github/ade-sample-projects/.venv/lib/python3.12/site-packages (from landingai-ade) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/andreakropp/Documents/Github/ade-sample-projects/.venv/lib/python3.12/site-packages (from landingai-ade) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/andreakropp/Documents/Github/ade-sample-projects/.venv/lib/python3.12/site-packages (from landingai-ade) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/andreakropp/Documents/Github/ade-sample-projects/.venv/lib/python3.12/site-packages (from landingai-ade) (2.12.5)
# Requirement already satisfied: sniffio in /Users/andreakropp/Documents/Github/ade-sample-projects/.venv/lib/python3.12/site-packages (from landingai-ade) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /Users/andreakropp/Documents/Github/ade-sample-projects/.venv/lib/python3.12/site-packages (from landingai-ade) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/andreakropp/Documents/Github/ade-sample-projects/.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->landingai-ade) (3.11)
# Requirement already satisfied: certifi in /Users/andreakropp/Documents/Github/ade-sample-projects/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->landingai-ade) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/andreakropp/Documents/Github/ade-sample-projects/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->landingai-ade) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/andreakropp/Documents/Github/ade-sample-projects/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->landingai-ade) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/andreakropp/Documents/Github/ade-sample-projects/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->landingai-ade) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/andreakropp/Documents/Github/ade-sample-projects/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->landingai-ade) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/andreakropp/Documents/Github/ade-sample-projects/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->landingai-ade) (0.4.2)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from landingai_ade import LandingAIADE

# Parse a document
response = LandingAIADE().parse(
    document_url="https://docs.landing.ai/examples/bank-statement.pdf",
    model="dpt-2-latest"
)

# Print the parsing results.
# Learn more about the structure of the response from the Parse API at https://docs.landing.ai/ade/ade-json-response

print("Parse Markdown:")
print(response.markdown)

print("Parse Chunks:")
print(response.chunks)

print("Grounding Information:")
print(response.grounding)

print("Parse API Metadata:")
print(response.metadata)

# Save Markdown to a file
if response.markdown:
    with open('markdown-bank-statement.md', 'w', encoding='utf-8') as f:
        f.write(response.markdown)
    print("\nMarkdown content saved to a Markdown file.")
else:
    print("No 'markdown' field found in the response")
# Out:
# Parse Markdown:
# <a id='0abff718-ff0e-40a4-a8e9-717a0d1a8d4a'></a>
#
# BUILDER'S BANK
#
# <a id='aeb9693f-972a-47a6-9b67-59f648bc1abb'></a>
#
# 500 Financial Plaza
# New York, NY 10014
# Tel: 1-800-555-BANK
# www.buildersbank.example
#
# <a id='6558641f-dd61-4992-9798-1ba6abde62f4'></a>
#
# CHECKING ACCOUNT STATEMENT
#
# Account Holder: Sarah J. Mitchell
# Account Number: *****4892
# Statement Period: September 1 - September 30, 2025
#
# <a id='80565261-8cf1-476f-91df-1cbfa36bf263'></a>
#
# Account Type:               Premium Checking
# Statement Date:             September 30, 2025
# Customer Since:             March 2018
#
# <a id='c6c258e1-82f5-42fd-ab71-e27d59697d24'></a>
#
# <table id="0-1">
# <tr><td id="0-2">Beginning Balance (September 1, 2025):</td><td id="0-3">$5,247.83</td></tr>
# <tr><td id="0-4">Total Deposits and Credits:</td><td id="0-5">+$6,850.00</td></tr>
# <tr><td id="0-6">Total Withdrawals and Debits:</td><td id="0-7">-$4,923.16</td></tr>
# <tr><td id="0-8">Ending Balance (September 30, 2025):</td><td id="0-9">$7,174.67</td></tr>
# </table>
#
# <a id='c68ee2ac-68aa-43f7-aa74-b850ebcdc898'></a>
#
# TRANSACTION HISTORY
# <table id="0-a">
# <tr><td id="0-b">Date</td><td id="0-c">Description</td><td id="0-d">Withdrawals</td><td id="0-e">Deposits</td><td id="0-f">Balance</td></tr>
# <tr><td id="0-g">09/01</td><td id="0-h">Beginning Balance</td><td id="0-i"></td><td id="0-j"></td><td id="0-k">$5,247.83</td></tr>
# <tr><td id="0-l">09/02</td><td id="0-m">Direct Deposit - ACME CORP PAYROLL</td><td id="0-n"></td><td id="0-o">$3,425.00</td><td id="0-p">$8,672.83</td></tr>
# <tr><td id="0-q">09/03</td><td id="0-r">Debit Card Purchase - WHOLE FOODS MARKET</td><td id="0-s">$127.54</td><td id="0-t"></td><td id="0-u">$8,545.29</td></tr>
# <tr><td id="0-v">09/04</td><td id="0-w">Online Transfer to Savings</td><td id="0-x">$500.00</td><td id="0-y"></td><td id="0-z">$8,045.29</td></tr>
# <tr><td id="0-A">09/05</td><td id="0-B">ATM Withdrawal - BUILDER&#x27;S BANK ATM #4521</td><td id="0-C">$100.00</td><td id="0-D">(minus sign)</td><td id="0-E">$7,945.29</td></tr>
# <tr><td id="0-F">09/06</td><td id="0-G">Debit Card Purchase - SHELL GAS STATION</td><td id="0-H">$52.30</td><td id="0-I">(minus sign)</td><td id="0-J">$7,892.99</td></tr>
# <tr><td id="0-K">09/08</td><td id="0-L">Check #2847 - PROPERTY MANAGEMENT LLC</td><td id="0-M">$1,850.00</td><td id="0-N">(minus sign)</td><td id="0-O">$6,042.99</td></tr>
# <tr><td id="0-P">09/09</td><td id="0-Q">Debit Card Purchase - AMAZON.COM</td><td id="0-R">$89.99</td><td id="0-S">(minus sign)</td><td id="0-T">$5,953.00</td></tr>
# <tr><td id="0-U">09/10</td><td id="0-V">Debit Card Purchase - STARBUCKS</td><td id="0-W">$6.75</td><td id="0-X">(minus sign)</td><td id="0-Y">$5,946.25</td></tr>
# <tr><td id="0-Z">09/11</td><td id="0-10">Bill Pay - ELECTRIC COMPANY</td><td id="0-11">$143.28</td><td id="0-12"></td><td id="0-13">$5,802.97</td></tr>
# <tr><td id="0-14">09/12</td><td id="0-15">Debit Card Purchase - TARGET</td><td id="0-16">$76.42</td><td id="0-17"></td><td id="0-18">$5,726.55</td></tr>
# <tr><td id="0-19">09/13</td><td id="0-1a">Mobile Deposit - Check</td><td id="0-1b"></td><td id="0-1c">$250.00</td><td id="0-1d">$5,976.55</td></tr>
# <tr><td id="0-1e">09/14</td><td id="0-1f">Debit Card Purchase - RESTAURANT</td><td id="0-1g">$68.90</td><td id="0-1h"></td><td id="0-1i">$5,907.65</td></tr>
# <tr><td id="0-1j">09/15</td><td id="0-1k">Bill Pay - INTERNET SERVICE</td><td id="0-1l">$79.99</td><td id="0-1m"></td><td id="0-1n">$5,827.66</td></tr>
# <tr><td id="0-1o">09/16</td><td id="0-1p">Direct Deposit - ACME CORP PAYROLL</td><td id="0-1q"></td><td id="0-1r">$3,425.00</td><td id="0-1s">$9,252.66</td></tr>
# </table>
#
# <!-- PAGE BREAK -->
#
# <a id='9cffe2a2-d229-4791-9518-dafef00c5619'></a>
#
# BUILDER'S BANK
#
# <a id='7a5bffc4-8b99-44e9-9a85-c28f836cebda'></a>
#
# Account: *****4892
# Period: 09/01/2025 - 09/30/2025
#
# <a id='67d85902-c5c3-4faf-99c6-394d18285f35'></a>
#
# TRANSACTION HISTORY (CONTINUED)
# <table id="1-1">
# <tr><td id="1-2">Date</td><td id="1-3">Description</td><td id="1-4">Withdrawals</td><td id="1-5">Deposits</td><td id="1-6">Balance</td></tr>
# <tr><td id="1-7">09/17</td><td id="1-8">Debit Card Purchase - PHARMACY</td><td id="1-9">$34.85</td><td id="1-a"></td><td id="1-b">$9,217.81</td></tr>
# <tr><td id="1-c">09/18</td><td id="1-d">Debit Card Purchase - GROCERY STORE</td><td id="1-e">$145.67</td><td id="1-f"></td><td id="1-g">$9,072.14</td></tr>
# <tr><td id="1-h">09/19</td><td id="1-i">ATM Withdrawal - BUILDER&#x27;S BANK ATM #4521</td><td id="1-j">$80.00</td><td id="1-k"></td><td id="1-l">$8,992.14</td></tr>
# <tr><td id="1-m">09/20</td><td id="1-n">Bill Pay - CREDIT CARD PAYMENT</td><td id="1-o">$450.00</td><td id="1-p"></td><td id="1-q">$8,542.14</td></tr>
# <tr><td id="1-r">09/21</td><td id="1-s">Debit Card Purchase - GAS STATION</td><td id="1-t">$58.20</td><td id="1-u"></td><td id="1-v">$8,483.94</td></tr>
# <tr><td id="1-w">09/22</td><td id="1-x">Debit Card Purchase - COFFEE SHOP</td><td id="1-y">$5.50</td><td id="1-z"></td><td id="1-A">$8,478.44</td></tr>
# <tr><td id="1-B">09/23</td><td id="1-C">Bill Pay - MOBILE PHONE</td><td id="1-D">$95.00</td><td id="1-E"></td><td id="1-F">$8,383.44</td></tr>
# <tr><td id="1-G">09/24</td><td id="1-H">Debit Card Purchase - ONLINE SHOPPING</td><td id="1-I">$124.99</td><td id="1-J"></td><td id="1-K">$8,258.45</td></tr>
# <tr><td id="1-L">09/25</td><td id="1-M">Venmo Transfer - From Friend</td><td id="1-N"></td><td id="1-O">$50.00</td><td id="1-P">$8,308.45</td></tr>
# <tr><td id="1-Q">09/26</td><td id="1-R">Debit Card Purchase - RESTAURANT</td><td id="1-S">$92.45</td><td id="1-T">–</td><td id="1-U">$8,216.00</td></tr>
# <tr><td id="1-V">09/27</td><td id="1-W">Bill Pay - GYM MEMBERSHIP</td><td id="1-X">$65.00</td><td id="1-Y">–</td><td id="1-Z">$8,151.00</td></tr>
# <tr><td id="1-10">09/28</td><td id="1-11">Debit Card Purchase - GROCERY STORE</td><td id="1-12">$113.24</td><td id="1-13">–</td><td id="1-14">$8,037.76</td></tr>
# <tr><td id="1-15">09/29</td><td id="1-16">ATM Withdrawal - BUILDER&#x27;S BANK ATM #4521</td><td id="1-17">$60.00</td><td id="1-18">–</td><td id="1-19">$7,977.76</td></tr>
# <tr><td id="1-1a">09/30</td><td id="1-1b">Interest Earned</td><td id="1-1c"></td><td id="1-1d">$3.28</td><td id="1-1e">$7,981.04</td></tr>
# <tr><td id="1-1f">09/30</td><td id="1-1g">Monthly Service Fee Waived</td><td id="1-1h">*</td><td id="1-1i">*</td><td id="1-1j">$7,981.04</td></tr>
# <tr><td id="1-1k">09/30</td><td id="1-1l">Debit Card Purchase - PHARMACY</td><td id="1-1m">$806.37</td><td id="1-1n">*</td><td id="1-1o">$7,174.67</td></tr>
# </table>
#
# <a id='00d1c722-3865-4604-8aef-6804c547bded'></a>
#
# ## ACCOUNT SUMMARY
#
# Total Number of Deposits: 5
# Total Number of Withdrawals: 26
# Average Daily Balance: $7,456.21
# Interest Paid This Period: $3.28
# Year-to-Date Interest: $26.74
#
# <a id='0a6e50f4-f019-46f2-bd92-0cddc9a830ef'></a>
#
# IMPORTANT INFORMATION:
# Please examine this statement carefully. If you find any errors or have questions, contact us immediately at 1-800-555-BANK or visit any branch location. You have 60 days from the statement date to notify us of any errors.
#
# <a id='762ce1cf-1b14-4225-87da-05ed64cc14d7'></a>
#
# FRAUD PROTECTION: If your debit card is lost or stolen, notify us immediately to limit your liability. Your account is protected by Builder's Bank's Zero Liability Policy for unauthorized transactions.
#
# <a id='4b371486-9343-41ae-a8a3-e5d9b72851de'></a>
#
# KEEP THIS STATEMENT FOR YOUR RECORDS. This is an official bank statement and may be required for tax purposes or loan applications.
# Parse Chunks:
# [Chunk(id='0abff718-ff0e-40a4-a8e9-717a0d1a8d4a', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.1011468842625618, left=0.08151024580001831, right=0.390119731426239, top=0.06389040499925613), page=0), markdown="<a id='0abff718-ff0e-40a4-a8e9-717a0d1a8d4a'></a>\n\nBUILDER'S BANK", type='text'), Chunk(id='aeb9693f-972a-47a6-9b67-59f648bc1abb', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.1247374415397644, left=0.7578508853912354, right=0.9178066253662109, top=0.06449198722839355), page=0), markdown="<a id='aeb9693f-972a-47a6-9b67-59f648bc1abb'></a>\n\n500 Financial Plaza\nNew York, NY 10014\nTel: 1-800-555-BANK\nwww.buildersbank.example", type='text'), Chunk(id='6558641f-dd61-4992-9798-1ba6abde62f4', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.2586582899093628, left=0.0801955908536911, right=0.4964502453804016, top=0.16068844497203827), page=0), markdown="<a id='6558641f-dd61-4992-9798-1ba6abde62f4'></a>\n\nCHECKING ACCOUNT STATEMENT\n\nAccount Holder: Sarah J. Mitchell\nAccount Number: *****4892\nStatement Period: September 1 - September 30, 2025", type='text'), Chunk(id='80565261-8cf1-476f-91df-1cbfa36bf263', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.2587934732437134, left=0.5046236515045166, right=0.8292679786682129, top=0.20115329325199127), page=0), markdown="<a id='80565261-8cf1-476f-91df-1cbfa36bf263'></a>\n\nAccount Type:               Premium Checking\nStatement Date:             September 30, 2025\nCustomer Since:             March 2018", type='text'), Chunk(id='c6c258e1-82f5-42fd-ab71-e27d59697d24', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.40606096386909485, left=0.09554427862167358, right=0.9070314764976501, top=0.29108068346977234), page=0), markdown='<a id=\'c6c258e1-82f5-42fd-ab71-e27d59697d24\'></a>\n\n<table id="0-1">\n<tr><td id="0-2">Beginning Balance (September 1, 2025):</td><td id="0-3">$5,247.83</td></tr>\n<tr><td id="0-4">Total Deposits and Credits:</td><td id="0-5">+$6,850.00</td></tr>\n<tr><td id="0-6">Total Withdrawals and Debits:</td><td id="0-7">-$4,923.16</td></tr>\n<tr><td id="0-8">Ending Balance (September 30, 2025):</td><td id="0-9">$7,174.67</td></tr>\n</table>', type='table'), Chunk(id='c68ee2ac-68aa-43f7-aa74-b850ebcdc898', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.9161099195480347, left=0.0798012912273407, right=0.9220126867294312, top=0.44064462184906006), page=0), markdown='<a id=\'c68ee2ac-68aa-43f7-aa74-b850ebcdc898\'></a>\n\nTRANSACTION HISTORY\n<table id="0-a">\n<tr><td id="0-b">Date</td><td id="0-c">Description</td><td id="0-d">Withdrawals</td><td id="0-e">Deposits</td><td id="0-f">Balance</td></tr>\n<tr><td id="0-g">09/01</td><td id="0-h">Beginning Balance</td><td id="0-i"></td><td id="0-j"></td><td id="0-k">$5,247.83</td></tr>\n<tr><td id="0-l">09/02</td><td id="0-m">Direct Deposit - ACME CORP PAYROLL</td><td id="0-n"></td><td id="0-o">$3,425.00</td><td id="0-p">$8,672.83</td></tr>\n<tr><td id="0-q">09/03</td><td id="0-r">Debit Card Purchase - WHOLE FOODS MARKET</td><td id="0-s">$127.54</td><td id="0-t"></td><td id="0-u">$8,545.29</td></tr>\n<tr><td id="0-v">09/04</td><td id="0-w">Online Transfer to Savings</td><td id="0-x">$500.00</td><td id="0-y"></td><td id="0-z">$8,045.29</td></tr>\n<tr><td id="0-A">09/05</td><td id="0-B">ATM Withdrawal - BUILDER&#x27;S BANK ATM #4521</td><td id="0-C">$100.00</td><td id="0-D">(minus sign)</td><td id="0-E">$7,945.29</td></tr>\n<tr><td id="0-F">09/06</td><td id="0-G">Debit Card Purchase - SHELL GAS STATION</td><td id="0-H">$52.30</td><td id="0-I">(minus sign)</td><td id="0-J">$7,892.99</td></tr>\n<tr><td id="0-K">09/08</td><td id="0-L">Check #2847 - PROPERTY MANAGEMENT LLC</td><td id="0-M">$1,850.00</td><td id="0-N">(minus sign)</td><td id="0-O">$6,042.99</td></tr>\n<tr><td id="0-P">09/09</td><td id="0-Q">Debit Card Purchase - AMAZON.COM</td><td id="0-R">$89.99</td><td id="0-S">(minus sign)</td><td id="0-T">$5,953.00</td></tr>\n<tr><td id="0-U">09/10</td><td id="0-V">Debit Ca ...
# Grounding Information:
# {'0abff718-ff0e-40a4-a8e9-717a0d1a8d4a': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.1011468842625618, left=0.08151024580001831, right=0.390119731426239, top=0.06389040499925613), page=0, type='chunkText'), 'aeb9693f-972a-47a6-9b67-59f648bc1abb': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.1247374415397644, left=0.7578508853912354, right=0.9178066253662109, top=0.06449198722839355), page=0, type='chunkText'), '6558641f-dd61-4992-9798-1ba6abde62f4': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.2586582899093628, left=0.0801955908536911, right=0.4964502453804016, top=0.16068844497203827), page=0, type='chunkText'), '80565261-8cf1-476f-91df-1cbfa36bf263': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.2587934732437134, left=0.5046236515045166, right=0.8292679786682129, top=0.20115329325199127), page=0, type='chunkText'), 'c6c258e1-82f5-42fd-ab71-e27d59697d24': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.40606096386909485, left=0.09554427862167358, right=0.9070314764976501, top=0.29108068346977234), page=0, type='chunkTable'), '0-1': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.4008736017896837, left=0.10509924716012975, right=0.8986901030117451, top=0.2956118188852839), page=0, type='table'), '0-2': GroundingParseResponseTableCellGrounding(box=ParseGroundingBox(bottom=0.31721224843727086, left=0.10509924716012975, right=0.43168131537420207, top=0.2956118188852839), page=0, type='tableCell', position=GroundingParseResponseTableCellGroundingPosition(chunk_id='c6c258e1-82f5-42fd-ab71-e27d59697d24', col=0, colspan=1, row=0, rowspan=1)), '0-3': GroundingParseResponseTableCellGrounding(box=ParseGroundingBox(bottom=0.3172463018150262, left=0.4315775260797501, right=0.8985959157901878, top=0.29564943758994167), page=0, type='tableCell', position=GroundingParseResponseTableCellGroundingPosition(chunk_id='c6c258e1-82f5-42fd-ab71-e27d59697d24', col=1, colspan=1, row=0, rowspan=1)), '0-4': GroundingParseResponseTableCellGrounding(box=ParseGroundingBox(bottom=0.3377350672128551, left=0.10511688412371753, right=0.4315775260797501, top=0.3171884440479626), page=0, type='tableCell', position=GroundingParseResponseTableCellGroundingPosition(chunk_id='c6c258e1-82f5-42fd-ab71-e27d59697d24', col=0, colspan=1, row=1, rowspan=1)), '0-5': GroundingParseResponseTableCellGrounding(box=ParseGroundingBox(bottom=0.3377291311294226, left=0.4314787712006181, right=0.8986190248792594, top=0.31721224843727086), page=0, type='tableCell', position=GroundingParseResponseTableCellGroundingPosition(chunk_id='c6c258e1-82f5-42fd-ab71-e27d59697d24', col=1, colspan=1, row=1, rowspan=1)), '0-6': GroundingParseResponseTableCellGrounding(box=ParseGroundingBox(bottom=0.3715970321042854, left=0.10513367915268423, right=0.4314787712006181, top=0.3377291311294226), page=0, type='tableCell', position=GroundingParseResponseTableCellGroundingPosition(chunk_id='c6c258e1-82f5-42fd-ab71-e27d59697d24', col=0, colspan=1, row=2, rowspan=1)), '0-7': GroundingParseResponseTableCellGrounding(box=ParseGroundingBox(bottom=0.37160926640297187, left=0.4313157532354911, right=0.8986572744990862, top=0.33772063403972197), page=0, type='tableCell', position=GroundingParseResponseTableCellGroundingPosition(chunk_id='c6c258e1-82f5-42fd-ab71-e27d59697d24', col=1, colspan=1, row=2, rowspan=1)), '0-8': GroundingParseResponseTableCellGrounding(box=ParseGroundingBox(bottom=0.4008736017896837, left=0.10516135130478452, right=0.4313157532354911, top=0.3715884938722013), page=0, type='tableCell', position=GroundingParseResponseTableCellGroundingPosition(chunk_id='c6c258e1-82f5-42fd-ab71-e27d59697d24', col=0, colspan=1, row=3, rowspan=1)), '0-9': GroundingParseResponseTableCellGrounding(box=ParseGroundingBox(bottom=0.400800175940211, left=0.4311751883659123, right=0.8986901030117451, top=0.3715970321042854), page=0, type='tableCell', position=GroundingParseResponseTableCellGroundingPosition(chunk_id= ...
# Parse API Metadata:
# ParseMetadata(credit_usage=6.0, duration_ms=9261, filename='bank-statement.pdf', job_id='a93a2ce3ee5d4829b7b6768cb07255f0', org_id='u3z0u1hn4acl', page_count=2, version='dpt-2-20251103', failed_pages=[])
#
# Markdown content saved to a Markdown file.

# %%
from landingai_ade import LandingAIADE
from landingai_ade.lib import pydantic_to_json_schema
from pydantic import BaseModel, Field
from pathlib import Path

# Define your schema: this tells the API what fields to extract
class Account(BaseModel):
    name: str = Field(description="Account holder name")
    number_deposits: int = Field(description="The number of deposits")

# Convert to JSON schema
schema = pydantic_to_json_schema(Account)

# Extract fields
response = LandingAIADE().extract(
    schema=schema,
    markdown=Path('markdown-bank-statement.md'),
    model="extract-latest"
)

# Print the extracted fields
# Learn more about the structure of the response from the Extract API at https://docs.landing.ai/ade/ade-extract-response

print("Extracted Fields:")
print(response.extraction)

print("Extracted Field Metadata:")
print(response.extraction_metadata)

print("Extract API Usage Metadata:")
print(response.metadata)
# Out:
# Extracted Fields:
# {'name': 'Sarah J. Mitchell', 'number_deposits': 5}
# Extracted Field Metadata:
# {'name': {'value': 'Sarah J. Mitchell', 'references': ['6558641f-dd61-4992-9798-1ba6abde62f4']}, 'number_deposits': {'value': 5, 'references': ['00d1c722-3865-4604-8aef-6804c547bded']}}
# Extract API Usage Metadata:
# Metadata(credit_usage=1.5452, duration_ms=2499, filename='markdown-bank-statement.md', job_id='c3c70b2edfaa481189b68c68044ff6f1', org_id='u3z0u1hn4acl', version='extract-20251024', fallback_model_version=None, schema_violation_error=None)

# %% [markdown]
# ## What's Next
#
# After completing this basic example, learn more about the ADE Python Library capabilities at https://docs.landing.ai/ade/ade-python and try more sample code at https://docs.landing.ai/ade/ade-code-examples-resources
