# %% [markdown]
# # 💡 Fast, Accurate Parsing of Invoices with LandingAI
#
# This notebook demonstrates how to use the `landing-ade` Python package to extract structured information from invoices using LandingAI's Agentic Document Extraction (ADE) service.
#
# We'll walk through:
# - Parsing documents with ADE Parse API.
# - Defining a custom schema for use with invoices using `pydantic` or `JSON`.
# - Extracting the desired fields using ADE Extract API
# - Viewing structured field extractions and metadata.
# - Not covered:
#     - Connecting to upstream document sources.
#     - Inserting parse() and extract() results into structured tables.
#     - Optimizing pipeline throughput.
#
# > 📎 Supported formats: `.pdf`, `.png`, `.jpg`, `.jpeg`. (More coming soon)

# %%
# ---
# Title: Fast, Accurate Parsing of Invoices with LandingAI
# Author: Andrea Kropp
# Description: How to apply a custom extraction schema to pull fields out of photos and PDFs of invoices.
# Target Audience: Developers, Product Managers
# Content Type: How-To
# Publish Date: 2025-10-06
# ADE Version: landingai-ade-0.17.1
# Change Log:
#    - v1.0: Initial draft
# ---

# %% [markdown]
# ### ✨ Install LandingAI's Agentic Document Extraction
#
# ```bash
# !pip install landing-ade
# ```
#
# ### 🗝️ Obtain and Set an API Key
#
# Obtain your API Key from the Visual Playground at https://va.landing.ai/settings/api-key
#
# Read about options for setting your API at https://docs.landing.ai/ade/agentic-api-key

# %% [markdown]
# ## 📦 Setup and Imports

# %%
# Standard libraries
import os
import json
from dotenv import load_dotenv
from datetime import date
from pathlib import Path

# %%
# LandingAI ADE library
from landingai_ade import LandingAIADE

# %%
# Helper functions for using ADE library
from ade_utilities import *

# Helper functions specific to this use case
from invoice_utilities import *

# Import your Pydantic schema for this use case
from invoice_schema import InvoiceExtractionSchema

# %%
# Load setting (including the VISION_AGENT_API_KEY) from the .env file
load_dotenv()
# Out:
# True

# %%
client = LandingAIADE(apikey=os.environ.get("VISION_AGENT_API_KEY"))
print("Authenticated client initialized")
# Out:
# Authenticated client initialized

# %%
import landingai_ade
print(landingai_ade.__version__)
# Out:
# 0.17.1

# %% [markdown]
# ## 📁 Define Input and Output Directories
#
# Specify where your documents are located and where results will be saved.

# %%
# Define input and output directory paths
base_dir = Path(os.getcwd())
input_folder = base_dir / "input_folder"
results_folder = base_dir / "results_folder"

# Create output folders if they don't exist
results_folder.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 🗂️ Collect Document File Paths
#
# This block filters input files for supported formats.

# %%
# Collect all document file paths in input folder with supported extensions
# Convert each Path object to a string to ensure compatibility with parse()

file_paths = [
    str(p)
    for p in input_folder.iterdir()
    if p.suffix.lower() in [".pdf", ".png", ".jpg", ".jpeg"]
]
file_paths[0:5]
# Out:
# ['/Users/andreakropp/Documents/Github/andrea-kropp/ade_demos/Invoices/input_folder/invoice_12.pdf',
#  '/Users/andreakropp/Documents/Github/andrea-kropp/ade_demos/Invoices/input_folder/invoice_13.pdf',
#  '/Users/andreakropp/Documents/Github/andrea-kropp/ade_demos/Invoices/input_folder/invoice_9.pdf',
#  '/Users/andreakropp/Documents/Github/andrea-kropp/ade_demos/Invoices/input_folder/invoice_11.pdf',
#  '/Users/andreakropp/Documents/Github/andrea-kropp/ade_demos/Invoices/input_folder/invoice_10.pdf']

# %% [markdown]
# ## 📋 Understanding the Invoice Extraction Schema
#
# Before we start parsing, let's understand what data we're extracting. Our `InvoiceExtractionSchema` defines a structured template for invoice data extraction. It's organized into 6 main categories:
#
# ### 1. **Invoice Information** (`invoice_info`)
# - Invoice date (raw format and standardized YYYY-MM-DD)
# - Invoice number
# - Order date, PO number
# - Payment status (PAID/UNPAID)
#
# ### 2. **Customer Information** (`customer_info`)
# - Customer name (person or organization)
# - Billing address
# - Email address
#
# ### 3. **Supplier Information** (`company_info`)
# - Supplier company name and address
# - Contact details (email, phone)
# - Sales representative
# - Tax identifiers (GSTIN, PAN for India)
#
# ### 4. **Order Details** (`order_details`)
# - Payment terms (e.g., Net 30)
# - Shipping carrier and date
# - Tracking number
#
# ### 5. **Financial Totals** (`totals_summary`)
# - Currency code (ISO format)
# - Total amount due (raw text and numeric)
# - Subtotal, tax, shipping, handling fees
#
# ### 6. **Line Items** (`line_items`)
# Each purchased item includes:
# - Line number, SKU/part number
# - Description
# - Quantity, unit price, extended amount
# - Item total
#
# > 💡 **Note**: ADE supports **one level of nested schemas**. Our schema has a top-level `InvoiceExtractionSchema` with nested models like `DocumentInfo`, `CustomerInfo`, etc.
#
# The complete schema is defined in `invoice_schema.py` using Pydantic models with field descriptions that guide the AI extraction engine.

# %% [markdown]
# ## 📄 Single Invoice Parsing
#
# Let's start with a single document to understand the ADE workflow.
#
# ### Two-Step Process: Parse → Extract
#
# ADE uses a **two-step pipeline**:
#
# #### Step 1: **Parse**
# The `parse()` method converts the document into structured markdown and chunks:
# - **`markdown`**: Full document content in markdown format
# - **`chunks`**: Individual text/image regions (paragraphs, tables, logos, etc.)
# - **`grounding`**: Bounding box coordinates showing where each chunk appears in the original document
# - **`metadata`**: Document info (filename, version, processing time, page count)
# - **`splits`**: Page splits for multi-page documents
#
# > 💡 **Parsing** is like OCR + layout understanding. It gives you the raw extracted content but not yet structured into your schema.
#
# #### Step 2: **Extract**
# The `extract()` method applies your custom schema to pull specific fields:
# - Takes the markdown from Step 1
# - Uses your Pydantic schema (e.g., `InvoiceExtractionSchema`)
# - Returns structured data matching your schema fields
# - Includes extraction metadata (confidence scores, source chunks)
#
# > 💡 **Extraction** is like applying a template to the parsed content, pulling out only the fields you care about.
#
# ### Why Two Steps?
#
# - **Flexibility**: Parse once, extract multiple times with different schemas
# - **Debugging**: Inspect the raw parsed content to troubleshoot extraction issues
# - **Efficiency**: Reuse parse results for multiple extraction needs
#
# Let's see both steps in action!

# %%
# Example 1: Parse only (no saving or extraction yet)
# This converts the PDF/image into structured markdown and chunks

client = LandingAIADE()
single_result = client.parse(document=Path(file_paths[0]),)

# The parse result contains:
# - markdown: full document text
# - chunks: individual regions with bounding boxes
# - metadata: document version, processing info
print(f"Number of chunks: {len(single_result.chunks)}")
print("Global markdown:", single_result.markdown[:200] + "...")
# Out:
# Number of chunks: 46
# Global markdown: <a id='810c399c-9902-4970-a2c1-8a43d71a853a'></a>
#
# <::logo: Condor
# condor
# The logo features the word "condor" in bold, sans-serif, lowercase letters, followed by a circular emblem containing a stylize...

# %%
# Explore the parse result structure
# Uncomment any line below to inspect different parts:

# single_result.markdown           # Full document as markdown text
# single_result.chunks              # List of text/image regions with bounding boxes
# single_result.metadata            # Document info: filename, version, pages, processing time
# single_result.splits              # Page boundaries for multi-page documents
# single_result.grounding           # Bounding box coordinates for each chunk

# %%
# Example 2: Parse and save results to JSON
# This is the same as Example 1, but saves the output to a file
# Saved file: results_folder/parse_invoice_13.json

single_result_parse_save = parse_and_save(document_path=file_paths[1], client=client, output_dir=results_folder)
single_result_parse_save
# Out:
# Parse results saved to: /Users/andreakropp/Documents/Github/andrea-kropp/ade_demos/Invoices/results_folder/parse_invoice_13.json
# ParseResponse(chunks=[Chunk(id='d38cc036-b449-457f-ba7a-ed5ec8db2df8', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.04086274281144142, left=0.3944183588027954, right=0.505725085735321, top=0.021210074424743652), page=0), markdown="<a id='d38cc036-b449-457f-ba7a-ed5ec8db2df8'></a>\n\nTax Invoice", type='marginalia'), Chunk(id='95b3f28f-7aa0-4ba9-adfd-92552a14e65f', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.03962094336748123, left=0.6299343705177307, right=0.8244345784187317, top=0.017798636108636856), page=0), markdown="<a id='95b3f28f-7aa0-4ba9-adfd-92552a14e65f'></a>\n\n(ORIGINAL FOR RECIPIENT)", type='text'), Chunk(id='634f7e5f-23be-428e-8015-4137f52b2c03', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.402715265750885, left=0.06802284717559814, right=0.49336951971054077, top=0.04924289882183075), page=0), markdown="<a id='634f7e5f-23be-428e-8015-4137f52b2c03'></a>\n\nKANDHAN METAL COMPANY\nOLD NO: 12, NEW NO :33,JANI BATCHA STREET.\nROYAPETTAH.CHENNAI-600014\nPH:044-28612601/48581793\nGodown No 69/227 NageswaraRao Road\nAthipet, Chennai-58\nGSTIN/UIN: 33AAJPS6304G1ZS\nState Name: Tamil Nadu, Code: 33\nE-Mail: kandhanmetal@gmail.com\n\nConsignee\nSAGAR ASISAGAR ASIA PRIVATE LIMITEDA PVT LTD\nSy. No. 379 to 382, Manoharabad Mandal,\nKallakal Village, Medak, Telangana,\n502336\nGSTIN/UIN : 36AAACZ2890G1Z4\n\nBuyer (if other than consignee)\nSMARTQUIP OVERSEAS COMPANY\nNO 16, 2ND CROSS J C ROAD, SUDHAM\nNAGAR, BANGALORE, Bengaluru (\nBangalore) Urban, Karnataka, 560002\nGSTIN/UIN : 29AGGPJ0910N1ZA", type='text'), Chunk(id='eaea7b32-6076-49b2-909d-671b3d6941a5', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.4024697244167328, left=0.4851920008659363, right=0.8442955613136292, top=0.04986181855201721), page=0), markdown='<a id=\'eaea7b32-6076-49b2-909d-671b3d6941a5\'></a>\n\n<table id="0-1">\n<tr><td id="0-2">Invoice No. 812</td><td id="0-3">Dated 2-Dec-2021</td></tr>\n<tr><td id="0-4">Delivery Note</td><td id="0-5">Mode/Terms of Payment</td></tr>\n<tr><td id="0-6">Supplier\'s Ref.</td><td id="0-7">Other Reference(s)</td></tr>\n<tr><td id="0-8">Despatch Document No.</td><td id="0-9">Delivery Note Date</td></tr>\n<tr><td id="0-a">Despatched through</td><td id="0-b">Destination</td></tr>\n<tr><td id="0-c">Bill of Lading/LR-RR No.</td><td id="0-d">Motor Vehicle No. AP39TD4595</td></tr>\n<tr><td id="0-e" colspan="2">Terms of Delivery SAGAR ASIA PRIVATE LIMITED Sy. No. 379 to 382, Manoharabad Mandal, Kallakal Village, Medak, Telangana, 502336 GST:36AAACZ2890G1Z4</td></tr>\n</table>', type='table'), Chunk(id='29b75730-01df-45c6-a796-a0b7ab300753', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.6210481524467468, left=0.07013878226280212, right=0.8427619934082031, top=0.39703235030174255), page=0), markdown='<a id=\'29b75730-01df-45c6-a796-a0b7ab300753\'></a>\n\n<table id="0-f">\n<tr><td id="0-g">Description of Goods</td><td id="0-h">HSN/SAC</td><td id="0-i">Quantity</td><td id="0-j">Rate</td><td id="0-k">per</td><td id="0-l">Amount</td></tr>\n<tr><td id="0-m">ALUMINIUM SCRAPS</td><td id="0-n">7602</td><td id="0-o">26,440.000 Kg</td><td id="0-p">193.00</td><td id="0-q">Kg</td><td id="0-r">51,02,920.00</td></tr>\n<tr><td id="0-s">IGST @ 18%</td><td id="0-t"></td><td id="0-u"></td><td id="0-v">18</td><td id="0-w">%</td><td id="0-x">9,18,525.60</td></tr>\n<tr><td id="0-y">ROUND OFF</td><td id="0-z"></td><td id="0-A"></td><td id="0-B"></td><td id="0-C"></td><td id="0-D">0.40</td></tr>\n<tr><td id="0-E">Total</td><td id="0-F"></td><td id="0-G">26,440.000 Kg</td><td id="0-H"></td><td id="0-I"></td><td id="0-J">60,21,446.00</td></tr>\n</table>', type='table'), Chunk(id='7a084fd5-5b9c-4afe-b443-c2906ed05c90', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.8153880834579468, left=0.06953784823417664, right=0.84192955493927, top=0.61434006690979), page=0), markdown='<a id=\'7a084fd5-5b9c-4afe-b443-c2906ed05c90\'></a>\n\n<table id="0-K">\n<tr><td id="0-L">Amount Chargeable (in words) INR S ...

# %%
# Example 3: Complete pipeline - Parse AND Extract
# This does BOTH steps:
#   1. Parse the document (convert to markdown + chunks)
#   2. Extract structured data using InvoiceExtractionSchema
# Saves two files: 
#   - results_folder/parse_invoice_9.json (raw parse output)
#   - results_folder/extract_invoice_9.json (structured invoice fields)

single_result_full_pipe = parse_extract_save(file_paths[2], client, InvoiceExtractionSchema, output_dir= results_folder)
single_result_full_pipe
# Out:
# Parse results saved to: /Users/andreakropp/Documents/Github/andrea-kropp/ade_demos/Invoices/results_folder/parse_invoice_9.json
# Extract results saved to: /Users/andreakropp/Documents/Github/andrea-kropp/ade_demos/Invoices/results_folder/extract_invoice_9.json
# (ParseResponse(chunks=[Chunk(id='a4f89b4f-3569-49bc-ac94-6bf78ee607e6', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.096154123544693, left=0.08743181824684143, right=0.44194576144218445, top=0.033484891057014465), page=0), markdown="<a id='a4f89b4f-3569-49bc-ac94-6bf78ee607e6'></a>\n\n<::logo: Freshworks\nfreshworks\nA stylized leaf-like icon composed of multiple facets in shades of gray is positioned to the left of the text.::>", type='logo'), Chunk(id='f47a315b-a6f5-46b9-a458-5c1fd01e937f', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.21089597046375275, left=0.08651575446128845, right=0.4332708418369293, top=0.10671643912792206), page=0), markdown="<a id='f47a315b-a6f5-46b9-a458-5c1fd01e937f'></a>\n\nFreshworks Inc., (formerly known as Freshdesk Inc.)\n2950 S. Delaware St,\nSuite 201, San Mateo, CA 94403,\nU.S.A.\nPhone: +1 (866) 832 3090\nTax ID: 33-1218825\nTax Reg #: 33-1218825", type='text'), Chunk(id='41b10bea-d855-4c29-91d4-fd6bf2b21353', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.19167819619178772, left=0.5961894392967224, right=0.8421856760978699, top=0.03922150284051895), page=0), markdown="<a id='41b10bea-d855-4c29-91d4-fd6bf2b21353'></a>\n\n# INVOICE\n\nInvoice #: FCL233308\nInvoice Date: May 26, 2021\nInvoice Amount: $10.00 (USD)\nPayment Terms: Due Upon Receipt\n\nPAID\n---\n", type='text'), Chunk(id='da1a9e49-b3cb-43e2-9f4d-859c142535cd', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.3217448592185974, left=0.08736848086118698, right=0.3143427073955536, top=0.23484545946121216), page=0), markdown="<a id='da1a9e49-b3cb-43e2-9f4d-859c142535cd'></a>\n\nBILLED TO\nLeo Charles Vincent\nabaxystech\n1061 Midvale Ave\nMorrsiville, North Carolina 27560\nUnited States", type='text'), Chunk(id='ed5ff35a-69f1-4f58-b6fa-fba66f4014f9', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.2687315344810486, left=0.59776771068573, right=0.8604755401611328, top=0.23522764444351196), page=0), markdown="<a id='ed5ff35a-69f1-4f58-b6fa-fba66f4014f9'></a>\n\nSUBSCRIPTION\nBilling Period May 26 to May 26, 2021", type='text'), Chunk(id='4e1e97c3-30b9-4103-88b6-c7c17a4e9f3d', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.5344086289405823, left=0.08666667342185974, right=0.9102663993835449, top=0.3424803912639618), page=0), markdown='<a id=\'4e1e97c3-30b9-4103-88b6-c7c17a4e9f3d\'></a>\n\n<table id="0-1">\n<tr><td id="0-2">DESCRIPTION</td><td id="0-3">UNITS</td><td id="0-4">UNIT PRICE</td><td id="0-5">AMOUNT (USD)</td></tr>\n<tr><td id="0-6">Freshcaller Phone Credits</td><td id="0-7">10</td><td id="0-8">$1.00</td><td id="0-9">$10.00</td></tr>\n<tr><td id="0-a"></td><td id="0-b"></td><td id="0-c">Total</td><td id="0-d">$10.00</td></tr>\n<tr><td id="0-e"></td><td id="0-f"></td><td id="0-g">Payments</td><td id="0-h">($10.00)</td></tr>\n<tr><td id="0-i"></td><td id="0-j" colspan="2">Amount Due (USD)</td><td id="0-k">$0.00</td></tr>\n</table>', type='table'), Chunk(id='e8892225-ce4c-4c1c-bc09-a1ea1ea279a1', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.5945142507553101, left=0.08779513835906982, right=0.5508441925048828, top=0.5478050708770752), page=0), markdown="<a id='e8892225-ce4c-4c1c-bc09-a1ea1ea279a1'></a>\n\nPAYMENTS\n\n**$10.00** was paid on 26 May, 2021 11:49 PDT by Visa card ending 2136.", type='text'), Chunk(id='a6b25878-652e-4697-b837-d7f4ecb3911a', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.6606581807136536, left=0.08871494233608246, right=0.5692809820175171, top=0.6159620881080627), page=0), markdown="<a id='a6b25878-652e-4697-b837-d7f4ecb3911a'></a>\n\nNOTES\n---\nPlease always include your invoice number when making any payment!", type='text'), Chunk(id='5c68b4b2-a8ba-4358-bc2e-963fe1e18862', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.7406542897224426, left=0.08950304985046387, right=0.7812685966491699, top=0.6689214110374451), page=0), markdown="<a id='5c68b4b2-a8ba-4358-bc2e-963fe1e18862'></a>\n\n**Reference to our Bank details:**\n\ ...
#  ExtractResponse(extraction={'invoice_info': {'invoice_date_raw': 'May 26, 2021', 'invoice_date': '2021-05-26', 'invoice_number': 'FCL233308', 'order_date': None, 'po_number': None, 'status': 'PAID'}, 'customer_info': {'sold_to_name': 'Leo Charles Vincent', 'sold_to_address': 'abaxystech\n1061 Midvale Ave\nMorrsiville, North Carolina 27560\nUnited States', 'customer_email': None}, 'company_info': {'supplier_name': 'Freshworks Inc.', 'supplier_address': '2950 S. Delaware St,\nSuite 201, San Mateo, CA 94403,\nU.S.A.', 'representative': None, 'email': 'billing@freshworks.com', 'phone': '+1 (866) 832 3090', 'gstin': None, 'pan': None}, 'order_details': {'payment_terms': 'Due Upon Receipt', 'ship_via': None, 'ship_date': None, 'tracking_number': None}, 'totals_summary': {'currency': 'USD', 'total_due_raw': '$0.00', 'total_due': 0, 'subtotal': 10, 'tax': None, 'shipping': None, 'handling_fee': None}, 'line_items': [{'line_number': None, 'sku': None, 'description': 'Freshcaller Phone Credits', 'quantity': 10, 'unit_price': 1, 'price': None, 'amount': 10, 'total': None}]}, extraction_metadata={'invoice_info': {'invoice_date_raw': {'value': 'May 26, 2021', 'references': ['41b10bea-d855-4c29-91d4-fd6bf2b21353']}, 'invoice_date': {'value': '2021-05-26', 'references': ['41b10bea-d855-4c29-91d4-fd6bf2b21353']}, 'invoice_number': {'value': 'FCL233308', 'references': ['41b10bea-d855-4c29-91d4-fd6bf2b21353']}, 'order_date': {'value': None, 'references': []}, 'po_number': {'value': None, 'references': []}, 'status': {'value': 'PAID', 'references': ['41b10bea-d855-4c29-91d4-fd6bf2b21353']}}, 'customer_info': {'sold_to_name': {'value': 'Leo Charles Vincent', 'references': ['da1a9e49-b3cb-43e2-9f4d-859c142535cd']}, 'sold_to_address': {'value': 'abaxystech\n1061 Midvale Ave\nMorrsiville, North Carolina 27560\nUnited States', 'references': ['da1a9e49-b3cb-43e2-9f4d-859c142535cd']}, 'customer_email': {'value': None, 'references': []}}, 'company_info': {'supplier_name': {'value': 'Freshworks Inc.', 'references': ['f47a315b-a6f5-46b9-a458-5c1fd01e937f']}, 'supplier_address': {'value': '2950 S. Delaware St,\nSuite 201, San Mateo, CA 94403,\nU.S.A.', 'references': ['f47a315b-a6f5-46b9-a458-5c1fd01e937f']}, 'representative': {'value': None, 'references': []}, 'email': {'value': 'billing@freshworks.com', 'references': ['8b0c6837-34b6-48c9-b8b4-9f7c0bfa2653']}, 'phone': {'value': '+1 (866) 832 3090', 'references': ['f47a315b-a6f5-46b9-a458-5c1fd01e937f']}, 'gstin': {'value': None, 'references': []}, 'pan': {'value': None, 'references': []}}, 'order_details': {'payment_terms': {'value': 'Due Upon Receipt', 'references': ['41b10bea-d855-4c29-91d4-fd6bf2b21353']}, 'ship_via': {'value': None, 'references': []}, 'ship_date': {'value': None, 'references': []}, 'tracking_number': {'value': None, 'references': []}}, 'totals_summary': {'currency': {'value': 'USD', 'references': ['41b10bea-d855-4c29-91d4-fd6bf2b21353', '0-5', '0-9', '0-k']}, 'total_due_raw': {'value': '$0.00', 'references': ['0-k']}, 'total_due': {'value': 0, 'references': ['0-k']}, 'subtotal': {'value': 10, 'references': ['0-d']}, 'tax': {'value': None, 'references': []}, 'shipping': {'value': None, 'references': []}, 'handling_fee': {'value': None, 'references': []}}, 'line_items': [{'line_number': {'value': None, 'references': []}, 'sku': {'value': None, 'references': []}, 'description': {'value': 'Freshcaller Phone Credits', 'references': ['0-6']}, 'quantity': {'value': 10, 'references': ['0-7']}, 'unit_price': {'value': 1, 'references': ['0-8']}, 'price': {'value': None, 'references': []}, 'amount': {'value': 10, 'references': ['0-9']}, 'total': {'value': None, 'references': []}}]}, metadata=Metadata(credit_usage=1.6, duration_ms=6400, filename='upload', job_id='t5784ij3auz4pt15ervu6c3dw', org_id='u3z0u1hn4acl', version='extract-20250930')))

# %% [markdown]
# ## 🧩 Parallel ADE Parsing with Progress Tracking
#
# This section performs **parallel document parsing** using the LandingAI Agentic Document Extraction (ADE) client.
# It scans the input directory for all `.pdf`, `.png`, `.jpg`, and `.jpeg` files, sends each file to the ADE API,
# and saves the extracted results to the specified output folder.
#
# Key features:
# - ⚡ **Parallel processing** with `ThreadPoolExecutor` to speed up large batches
# - 📊 **Real-time progress bar** using `tqdm` to visualize parsing progress
# - 💾 **Automatic result saving** via `save_parse_results()`
# - 🧱 **Robust handling** — skips over failed files gracefully
# - 🧠 **Results aggregation** — all successful `ParseResponse` objects are stored in `results_summary`
#
# After execution, you'll see:
# - A live progress bar showing parsing completion
# - Status messages for each document
# - A summary of how many documents were successfully parsed and saved

# %%
from pathlib import Path
from landingai_ade import LandingAIADE
from concurrent.futures import ThreadPoolExecutor, as_completed
import time
from tqdm import tqdm
from ade_utilities import parse_extract_save
from invoice_schema import InvoiceExtractionSchema

# --- CONFIG ---
input_dir = Path("input_folder2")
output_dir = Path("results_folder")
output_dir.mkdir(parents=True, exist_ok=True)

max_workers = 10  # adjust for your system and ADE rate limits
pause_between_requests = 0.2  # small delay to avoid hitting rate limits

# --- CLIENT ---
client = LandingAIADE()

# --- FILE LIST ---
file_paths = [p for p in input_dir.glob("*.*") if p.suffix.lower() in (".pdf", ".png", ".jpg", ".jpeg")]
print(f"Found {len(file_paths)} documents to parse and extract.")

# --- WORKER FUNCTION ---
def process_file(path: Path):
    try:
        # Parse AND extract using the utility function
        parse_result, extract_result = parse_extract_save(
            path, 
            client, 
            InvoiceExtractionSchema, 
            output_dir=output_dir
        )
        time.sleep(pause_between_requests)
        return (parse_result, extract_result)  # 👈 return both results as tuple
    except Exception as e:
        print(f"❌ {path.name} failed: {e}")
        return None

# --- PARALLEL EXECUTION WITH PROGRESS BAR ---
results_summary = []
with ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = [executor.submit(process_file, p) for p in file_paths]
    # tqdm progress bar updates as futures complete
    for future in tqdm(as_completed(futures), total=len(futures), desc="Processing documents"):
        result = future.result()
        if result is not None:
            results_summary.append(result)

# --- SUMMARY ---
success_count = len([r for r in results_summary if r is not None])
print(f"\n✅ Completed {success_count}/{len(file_paths)} documents successfully.")
print(f"📊 Each document has been parsed AND extracted with structured data.")
# Out:
# Found 3 documents to parse and extract.
# Processing documents:   0%|          | 0/3 [00:00<?, ?it/s]
# Parse results saved to: results_folder/parse_invoice_2.json
# Parse results saved to: results_folder/parse_invoice_1.json
# Parse results saved to: results_folder/parse_invoice_3.json
# Extract results saved to: results_folder/extract_invoice_2.json
# Processing documents:  33%|███▎      | 1/3 [00:14<00:29, 15.00s/it]
# Extract results saved to: results_folder/extract_invoice_1.json
# Processing documents:  67%|██████▋   | 2/3 [00:18<00:08,  8.25s/it]
# Extract results saved to: results_folder/extract_invoice_3.json
# Processing documents: 100%|██████████| 3/3 [00:20<00:00,  6.87s/it]
# ✅ Completed 3/3 documents successfully.
# 📊 Each document has been parsed AND extracted with structured data.

# %%
results_summary[0:5]
# Out:
# [(ParseResponse(chunks=[Chunk(id='5e627a04-6af2-4ca1-b7d7-24a9edea248d', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.2219770848751068, left=0.07200773060321808, right=0.4208279848098755, top=0.05207393318414688), page=0), markdown='<a id=\'5e627a04-6af2-4ca1-b7d7-24a9edea248d\'></a>\n\n<::logo: RR Roofing Renovations\nRR\nROOFING RENOVATIONS\nThe logo features a stylized house outline with large gray "RR" letters and smaller "ROOFING RENOVATIONS" text below.::>', type='logo'), Chunk(id='9e6635a3-de58-4fe2-956e-787713d5bca7', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.08431334048509598, left=0.4983729124069214, right=0.7101038694381714, top=0.04254310578107834), page=0), markdown="<a id='9e6635a3-de58-4fe2-956e-787713d5bca7'></a>\n\nRoofing Renovations INC\n336-862-5235", type='text'), Chunk(id='3d4edaa6-d809-4408-aa77-edc4baee0bc0', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.11778980493545532, left=0.7225770354270935, right=0.948281466960907, top=0.04463685676455498), page=0), markdown="<a id='3d4edaa6-d809-4408-aa77-edc4baee0bc0'></a>\n\n4917 Old Randleman Rd\nGreensboro, North Carolina\n27406\nUnited States", type='text'), Chunk(id='4218c1aa-560b-476b-8f2e-ec9508896069', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.3697735369205475, left=0.053897738456726074, right=0.27652907371520996, top=0.2791130840778351), page=0), markdown="<a id='4218c1aa-560b-476b-8f2e-ec9508896069'></a>\n\nBilled To\nReal Property Management\n1901 Lendew St Suite 7\nGreensboro, NC\n27408", type='text'), Chunk(id='65fbe8ff-f266-49cf-b951-4abb97fa3ac2', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.37434762716293335, left=0.31915000081062317, right=0.4350220263004303, top=0.27977097034454346), page=0), markdown="<a id='65fbe8ff-f266-49cf-b951-4abb97fa3ac2'></a>\n\nDate of Issue\n01/29/2020\n\nDue Date\n01/29/2020", type='text'), Chunk(id='72cdd2d9-6f2a-4450-a82b-8ec4009a1eef', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.37731799483299255, left=0.4983806610107422, right=0.6679202318191528, top=0.27792099118232727), page=0), markdown="<a id='72cdd2d9-6f2a-4450-a82b-8ec4009a1eef'></a>\n\nInvoice Number: 0001131\n\nReference: 7783 Newhaven Dr", type='text'), Chunk(id='2b891183-123d-4ee0-b61a-a6631ee7f205', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.3389115631580353, left=0.7339104413986206, right=0.9473931789398193, top=0.2780686318874359), page=0), markdown="<a id='2b891183-123d-4ee0-b61a-a6631ee7f205'></a>\n\nAmount Due (USD)\n$2,650.00", type='text'), Chunk(id='3bf54dcf-f6a8-478f-94b7-342f9689568a', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.6818450093269348, left=0.05395421385765076, right=0.9484430551528931, top=0.436617910861969), page=0), markdown='<a id=\'3bf54dcf-f6a8-478f-94b7-342f9689568a\'></a>\n\n<table id="0-1">\n<tr><td id="0-2">Description</td><td id="0-3">Rate</td><td id="0-4">Qty Line Total</td></tr>\n<tr><td id="0-5">Replace HVAC Unit.</td><td id="0-6">$2,650.00</td><td id="0-7">1 $2,650.00</td></tr>\n<tr><td id="0-8"></td><td id="0-9">Subtotal</td><td id="0-a">2,650.00</td></tr>\n<tr><td id="0-b"></td><td id="0-c">Tax</td><td id="0-d">0.00</td></tr>\n<tr><td id="0-e"></td><td id="0-f">Total</td><td id="0-g">2,650.00</td></tr>\n<tr><td id="0-h"></td><td id="0-i">Amount Paid</td><td id="0-j">0.00</td></tr>\n<tr><td id="0-k"></td><td id="0-l">Amount Due (USD)</td><td id="0-m">$2,650.00</td></tr>\n</table>', type='table'), Chunk(id='2702091f-6a0d-43f3-ae65-eeaf5e5da24d', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.7661049365997314, left=0.053102198988199234, right=0.1496189683675766, top=0.720390796661377), page=0), markdown="<a id='2702091f-6a0d-43f3-ae65-eeaf5e5da24d'></a>\n\nNotes\nT8EW3A3", type='text'), Chunk(id='a331fa69-2369-42c9-b672-5b4d30e70c47', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.8537522554397583, left=0.053189873695373535, right=0.557619571685791, top=0.8029360771179199), page=0), markdown="<a id='a33 ...
#   ExtractResponse(extraction={'invoice_info': {'invoice_date_raw': '01/29/2020', 'invoice_date': '2020-01-29', 'invoice_number': '0001131', 'order_date': None, 'po_number': None, 'status': None}, 'customer_info': {'sold_to_name': 'Real Property Management', 'sold_to_address': '1901 Lendew St Suite 7\nGreensboro, NC\n27408', 'customer_email': None}, 'company_info': {'supplier_name': 'Roofing Renovations INC', 'supplier_address': '4917 Old Randleman Rd\nGreensboro, North Carolina\n27406\nUnited States', 'representative': None, 'email': None, 'phone': '336-862-5235', 'gstin': None, 'pan': None}, 'order_details': {'payment_terms': None, 'ship_via': None, 'ship_date': None, 'tracking_number': None}, 'totals_summary': {'currency': 'USD', 'total_due_raw': '$2,650.00', 'total_due': 2650, 'subtotal': 2650, 'tax': 0, 'shipping': None, 'handling_fee': None}, 'line_items': [{'line_number': None, 'sku': None, 'description': 'Replace HVAC Unit.', 'quantity': 1, 'unit_price': 2650, 'price': None, 'amount': 2650, 'total': 2650}]}, extraction_metadata={'invoice_info': {'invoice_date_raw': {'value': '01/29/2020', 'references': ['65fbe8ff-f266-49cf-b951-4abb97fa3ac2']}, 'invoice_date': {'value': '2020-01-29', 'references': ['65fbe8ff-f266-49cf-b951-4abb97fa3ac2']}, 'invoice_number': {'value': '0001131', 'references': ['72cdd2d9-6f2a-4450-a82b-8ec4009a1eef']}, 'order_date': {'value': None, 'references': []}, 'po_number': {'value': None, 'references': []}, 'status': {'value': None, 'references': []}}, 'customer_info': {'sold_to_name': {'value': 'Real Property Management', 'references': ['4218c1aa-560b-476b-8f2e-ec9508896069']}, 'sold_to_address': {'value': '1901 Lendew St Suite 7\nGreensboro, NC\n27408', 'references': ['4218c1aa-560b-476b-8f2e-ec9508896069']}, 'customer_email': {'value': None, 'references': []}}, 'company_info': {'supplier_name': {'value': 'Roofing Renovations INC', 'references': ['9e6635a3-de58-4fe2-956e-787713d5bca7']}, 'supplier_address': {'value': '4917 Old Randleman Rd\nGreensboro, North Carolina\n27406\nUnited States', 'references': ['3d4edaa6-d809-4408-aa77-edc4baee0bc0']}, 'representative': {'value': None, 'references': []}, 'email': {'value': None, 'references': []}, 'phone': {'value': '336-862-5235', 'references': ['9e6635a3-de58-4fe2-956e-787713d5bca7']}, 'gstin': {'value': None, 'references': []}, 'pan': {'value': None, 'references': []}}, 'order_details': {'payment_terms': {'value': None, 'references': []}, 'ship_via': {'value': None, 'references': []}, 'ship_date': {'value': None, 'references': []}, 'tracking_number': {'value': None, 'references': []}}, 'totals_summary': {'currency': {'value': 'USD', 'references': ['2b891183-123d-4ee0-b61a-a6631ee7f205', '0-m']}, 'total_due_raw': {'value': '$2,650.00', 'references': ['2b891183-123d-4ee0-b61a-a6631ee7f205', '0-m']}, 'total_due': {'value': 2650, 'references': ['0-g']}, 'subtotal': {'value': 2650, 'references': ['0-a']}, 'tax': {'value': 0, 'references': ['0-d']}, 'shipping': {'value': None, 'references': []}, 'handling_fee': {'value': None, 'references': []}}, 'line_items': [{'line_number': {'value': None, 'references': []}, 'sku': {'value': None, 'references': []}, 'description': {'value': 'Replace HVAC Unit.', 'references': ['0-5']}, 'quantity': {'value': 1, 'references': ['0-7']}, 'unit_price': {'value': 2650, 'references': ['0-6']}, 'price': {'value': None, 'references': []}, 'amount': {'value': 2650, 'references': ['0-7']}, 'total': {'value': 2650, 'references': ['0-7']}}]}, metadata=Metadata(credit_usage=1.4, duration_ms=7123, filename='upload', job_id='t9u14ihog14ktc6216uo4i1h6', org_id='u3z0u1hn4acl', version='extract-20250930'))),
#  (ParseResponse(chunks=[Chunk(id='163da434-a2a8-4ac9-8cd0-559a3d6b3a78', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.05794680491089821, left=0.08026599884033203, right=0.22372639179229736, top=0.019250627607107162), page=0), markdown='<a id=\'163da434-a2a8-4ac9-8cd0-559a3d6b3a78\'></a>\n\n<::logo: Zoom\nzoom\nThe logo features the word "zoom" in a rounded, sans-serif gray typeface.::>', type='logo'), Chunk(id='bf2d2f02-1e8c-4aeb-8533-90457ae2e841', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.05059296637773514, left=0.7920073866844177, right=0.887368381023407, top=0.02749837189912796), page=0), markdown="<a id='bf2d2f02-1e8c-4aeb-8533-90457ae2e841'></a>\n\nINVOICE", type='marginalia'), Chunk(id='dd80af68-b3ca-4001-a459-a2f2cc9c0550', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.17177818715572357, left=0.08041708916425705, right=0.29107004404067993, top=0.11402059346437454), page=0), markdown="<a id='dd80af68-b3ca-4001-a459-a2f2cc9c0550'></a>\n\nZoom Video Communications Inc.\n55 Almaden Blvd, 6th Floor\nSan Jose, CA 95113\nbilling@zoom.us", type='text'), Chunk(id='2212472c-3e6d-4a44-a244-f156da313013', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.2614942491054535, left=0.48799511790275574, right=0.8308323621749878, top=0.11438507586717606), page=0), markdown="<a id='2212472c-3e6d-4a44-a244-f156da313013'></a>\n\nInvoice Date: 07/29/2020\nInvoice #: INV33543191\nPayment Terms: Due Upon Receipt\nDue Date: 07/29/2020\nAccount Number: 3003959185\nCurrency: USD\nAccount Information: Abaxys Tech LLC\n1061 Midvale Ave,\nMorrisville, North Carolina 27560\nUnited States\n\nleo.charles@outlook.com", type='text'), Chunk(id='9aed0e25-1736-4bfd-8bff-0ad112c3f20c', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.32542896270751953, left=0.08024725317955017, right=0.2426876723766327, top=0.2439139485359192), page=0), markdown="<a id='9aed0e25-1736-4bfd-8bff-0ad112c3f20c'></a>\n\nPurchase Order Number:\n\nTaxExemptCertificateID:\n\nZoom W-9", type='text'), Chunk(id='6d456466-8829-49e4-8a26-b5ea6c7d6f17', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.48815441131591797, left=0.07352882623672485, right=0.9261178374290466, top=0.3482363820075989), page=0), markdown='<a id=\'6d456466-8829-49e4-8a26-b5ea6c7d6f17\'></a>\n\n<table id="0-1">\n<tr><td id="0-2" colspan="5">CHARGE DETAILS</td></tr>\n<tr><td id="0-3">Charge Description</td><td id="0-4">Service Period</td><td id="0-5">Subtotal</td><td id="0-6">Tax</td><td id="0-7">TOTAL</td></tr>\n<tr><td id="0-8">Charge Name: Standard Pro Annual Quantity: 1 Unit Price: $149.90</td><td id="0-9">07/29/2020-07/28/2021</td><td id="0-a">$149.90</td><td id="0-b">$0.00</td><td id="0-c">$149.90</td></tr>\n</table>', type='table'), Chunk(id='dd84e4e1-ee27-4d11-9cf4-51149c31c870', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.644868016242981, left=0.07345104217529297, right=0.9257943630218506, top=0.5179883241653442), page=0), markdown='<a id=\'dd84e4e1-ee27-4d11-9cf4-51149c31c870\'></a>\n\n<table id="0-d">\n<tr><td id="0-e">INVOICE TOTALS</td><td id="0-f"></td><td id="0-g"></td></tr>\n<tr><td id="0-h" rowspan="3"></td><td id="0-i">Subtotal:</td><td id="0-j">$149.90</td></tr>\n<tr><td id="0-k">Total (Including Tax):</td><td id="0-l">$149.90</td></tr>\n<tr><td id="0-m">Invoice Balance:</td><td id="0-n">$0.00</td></tr>\n</table>', type='table'), Chunk(id='eb0d17d1-18b6-43c5-a118-d029b713a56c', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.7314551472663879, left=0.0746067464351654, right=0.9229556322097778, top=0.6538018584251404), page=0), markdown='<a id=\'eb0d17d1-18b6-43c5-a118-d029b713a56c\'></a>\n\n<table id="0-o">\n<tr><td id="0-p" colspan="5">TAX DETAILS</td></tr>\n<tr><td id="0-q">Charge Name</td><td id="0-r">Tax Name</td><td id="0-s">Jurisdiction</td><td id="0-t">Charge Amount</td><td id="0-u">Tax Amount</td></tr>\n<tr><td id="0-v" colspan="3"></td><td id="0-w">Total Tax</td><td id="0-x">$0.00</td></tr>\n</table>', type='table') ...
#   ExtractResponse(extraction={'invoice_info': {'invoice_date_raw': '07/29/2020', 'invoice_date': '2020-07-29', 'invoice_number': 'INV33543191', 'order_date': None, 'po_number': '', 'status': None}, 'customer_info': {'sold_to_name': 'Abaxys Tech LLC', 'sold_to_address': '1061 Midvale Ave, Morrisville, North Carolina 27560 United States', 'customer_email': 'leo.charles@outlook.com'}, 'company_info': {'supplier_name': 'Zoom Video Communications Inc.', 'supplier_address': '55 Almaden Blvd, 6th Floor San Jose, CA 95113', 'representative': None, 'email': 'billing@zoom.us', 'phone': None, 'gstin': None, 'pan': None}, 'order_details': {'payment_terms': 'Due Upon Receipt', 'ship_via': None, 'ship_date': None, 'tracking_number': None}, 'totals_summary': {'currency': 'USD', 'total_due_raw': '$149.90', 'total_due': 149.9, 'subtotal': 149.9, 'tax': 0, 'shipping': None, 'handling_fee': None}, 'line_items': [{'line_number': None, 'sku': None, 'description': 'Charge Name: Standard Pro Annual Quantity: 1 Unit Price: $149.90', 'quantity': 1, 'unit_price': 149.9, 'price': None, 'amount': 149.9, 'total': 149.9}]}, extraction_metadata={'invoice_info': {'invoice_date_raw': {'value': '07/29/2020', 'references': ['2212472c-3e6d-4a44-a244-f156da313013']}, 'invoice_date': {'value': '2020-07-29', 'references': ['2212472c-3e6d-4a44-a244-f156da313013']}, 'invoice_number': {'value': 'INV33543191', 'references': ['2212472c-3e6d-4a44-a244-f156da313013']}, 'order_date': {'value': None, 'references': []}, 'po_number': {'value': '', 'references': ['9aed0e25-1736-4bfd-8bff-0ad112c3f20c']}, 'status': {'value': None, 'references': []}}, 'customer_info': {'sold_to_name': {'value': 'Abaxys Tech LLC', 'references': ['2212472c-3e6d-4a44-a244-f156da313013']}, 'sold_to_address': {'value': '1061 Midvale Ave, Morrisville, North Carolina 27560 United States', 'references': ['2212472c-3e6d-4a44-a244-f156da313013']}, 'customer_email': {'value': 'leo.charles@outlook.com', 'references': ['2212472c-3e6d-4a44-a244-f156da313013']}}, 'company_info': {'supplier_name': {'value': 'Zoom Video Communications Inc.', 'references': ['dd80af68-b3ca-4001-a459-a2f2cc9c0550']}, 'supplier_address': {'value': '55 Almaden Blvd, 6th Floor San Jose, CA 95113', 'references': ['dd80af68-b3ca-4001-a459-a2f2cc9c0550']}, 'representative': {'value': None, 'references': []}, 'email': {'value': 'billing@zoom.us', 'references': ['dd80af68-b3ca-4001-a459-a2f2cc9c0550']}, 'phone': {'value': None, 'references': []}, 'gstin': {'value': None, 'references': []}, 'pan': {'value': None, 'references': []}}, 'order_details': {'payment_terms': {'value': 'Due Upon Receipt', 'references': ['2212472c-3e6d-4a44-a244-f156da313013']}, 'ship_via': {'value': None, 'references': []}, 'ship_date': {'value': None, 'references': []}, 'tracking_number': {'value': None, 'references': []}}, 'totals_summary': {'currency': {'value': 'USD', 'references': ['2212472c-3e6d-4a44-a244-f156da313013']}, 'total_due_raw': {'value': '$149.90', 'references': ['0-l']}, 'total_due': {'value': 149.9, 'references': ['0-l']}, 'subtotal': {'value': 149.9, 'references': ['0-j']}, 'tax': {'value': 0, 'references': ['0-x']}, 'shipping': {'value': None, 'references': []}, 'handling_fee': {'value': None, 'references': []}}, 'line_items': [{'line_number': {'value': None, 'references': []}, 'sku': {'value': None, 'references': []}, 'description': {'value': 'Charge Name: Standard Pro Annual Quantity: 1 Unit Price: $149.90', 'references': ['0-8']}, 'quantity': {'value': 1, 'references': ['0-8']}, 'unit_price': {'value': 149.9, 'references': ['0-8']}, 'price': {'value': None, 'references': []}, 'amount': {'value': 149.9, 'references': ['0-a']}, 'total': {'value': 149.9, 'references': ['0-c']}}]}, metadata=Metadata(credit_usage=1.7, duration_ms=9401, filename='upload', job_id='smdxzgilp5x29mm9g3i5j9yxt', org_id='u3z0u1hn4acl', version='extract-20250930'))),
#  (ParseResponse(chunks=[Chunk(id='00c1108c-2a02-4ebd-ae63-b366b6afc7cd', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.1374884843826294, left=0.02234107255935669, right=0.33442193269729614, top=0.040314625948667526), page=0), markdown="<a id='00c1108c-2a02-4ebd-ae63-b366b6afc7cd'></a>\n\nCUSTOM ELECTRIC & PLUMBING, INC.\nPO Box 533\nSummerfield, NC 27358\n336.701.5589\nMat@CustomEandP.com\nwww.ElectricianOrPlumber.com", type='text'), Chunk(id='75522ab8-1aed-4388-bdc6-9bef9911c2eb', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.18766160309314728, left=0.6994085907936096, right=0.9696045517921448, top=0.038081660866737366), page=0), markdown='<a id=\'75522ab8-1aed-4388-bdc6-9bef9911c2eb\'></a>\n\n<::logo: Custom Electric & Plumbing, Inc.\nCUSTOM ELECTRIC & PLUMBING, INC.\nThe logo features a stylized "C" and "P" with "CUSTOM ELECTRIC" above a pipe-like element that spells "PLUMBING, INC.", and a lightbulb icon replacing the "U" in "CUSTOM".::>', type='logo'), Chunk(id='4a071eef-e9da-4811-94f5-55e06c7b625f', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.24203406274318695, left=0.023272253572940826, right=0.12188955396413803, top=0.21905489265918732), page=0), markdown="<a id='4a071eef-e9da-4811-94f5-55e06c7b625f'></a>\n\nINVOICE", type='text'), Chunk(id='730ab534-1394-4759-85f1-209fb5acc59f', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.3138732314109802, left=0.0227242112159729, right=0.21225789189338684, top=0.2492464780807495), page=0), markdown="<a id='730ab534-1394-4759-85f1-209fb5acc59f'></a>\n\nBILL TO\nLeo Vincent\n1000 Sarah Dr\nSummerfield, NC 27358 USA", type='text'), Chunk(id='6d76de3b-615b-4f02-911b-eed2dda89d81', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.3005737066268921, left=0.6557497978210449, right=0.8742927312850952, top=0.24799035489559174), page=0), markdown="<a id='6d76de3b-615b-4f02-911b-eed2dda89d81'></a>\n\nINVOICE: 52255\n\nDATE: 10/03/2022\n\nDUE DATE: 11/01/2022", type='text'), Chunk(id='d46d9316-31d3-49be-8599-e955707b9882', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.36012789607048035, left=0.023406073451042175, right=0.10722202062606812, top=0.3280051648616791), page=0), markdown="<a id='d46d9316-31d3-49be-8599-e955707b9882'></a>\n\nSALES REP\nMathew", type='text'), Chunk(id='6748667f-068d-477a-bcd9-6363b24b5e0e', grounding=ChunkGrounding(box=ChunkGroundingBox(bottom=0.7787612676620483, left=0.02458798885345459, right=0.9765719175338745, top=0.3710770606994629), page=0), markdown='<a id=\'6748667f-068d-477a-bcd9-6363b24b5e0e\'></a>\n\n<table id="0-1">\n<tr><td id="0-2">DESCRIPTION</td><td id="0-3">QTY</td><td id="0-4">RATE</td><td id="0-5">AMOUNT</td></tr>\n<tr><td id="0-6">Provide and install new 60 Amp 240Vac breaker and 6/2 Copper SE cable feeding new Tesla Wall connector. Install new customer supplied Tesla wall connector. Note: drywall may need to be cut to facilitate work. No drywall repairs or painting are included in this quote.</td><td id="0-7">1</td><td id="0-8">1,400.00</td><td id="0-9">1,400.00</td></tr>\n<tr><td id="0-a">Permit and inspection fees</td><td id="0-b">1</td><td id="0-c">150.00</td><td id="0-d">150.00</td></tr>\n<tr><td id="0-e">Payment Terms: by Cash or Check, All sales final. $750.00 deposit at acceptance of contract balance due upon substantial completion of work. Agreement to include conditions of agreement addendum Clarifications: It is agreed that during the performance of the work drywall will/may be cut at the discretion of the contractor, this quotation does not include any drywall or painting repair or touchup. Parking to be provided onsite for all working personnel. Work will be completed during normal hours from 8:00 AM to 5:00 PM Monday thru Friday, unless approved otherwise. No additional components will be installed outside the scope of work enclosed. All fixtures and lamps are to be furnished on-site by others. Excluded from Bid: Repairs or corrections to existing plumbing, gas, or electrical s ...
#   ExtractResponse(extraction={'invoice_info': {'invoice_date_raw': '10/03/2022', 'invoice_date': '2022-10-03', 'invoice_number': '52255', 'order_date': None, 'po_number': None, 'status': None}, 'customer_info': {'sold_to_name': 'Leo Vincent', 'sold_to_address': '1000 Sarah Dr\nSummerfield, NC 27358 USA', 'customer_email': None}, 'company_info': {'supplier_name': 'CUSTOM ELECTRIC & PLUMBING, INC.', 'supplier_address': 'PO Box 533\nSummerfield, NC 27358', 'representative': 'Mathew', 'email': 'Mat@CustomEandP.com', 'phone': '336.701.5589', 'gstin': None, 'pan': None}, 'order_details': {'payment_terms': 'by Cash or Check, All sales final. $750.00 deposit at acceptance of contract balance due upon substantial completion of work. Agreement to include conditions of agreement addendum Clarifications: It is agreed that during the performance of the work drywall will/may be cut at the discretion of the contractor, this quotation does not include any drywall or painting repair or touchup. Parking to be provided onsite for all working personnel. Work will be completed during normal hours from 8:00 AM to 5:00 PM Monday thru Friday, unless approved otherwise. No additional components will be installed outside the scope of work enclosed. All fixtures and lamps are to be furnished on-site by others. Excluded from Bid: Repairs or corrections to existing plumbing, gas, or electrical system deficiencies or code violations. Repairs to any underground utilities (such as sprinkler lines, electrical lines, cable, etc.) not located and clearly marked prior to arrival on-site. Engineered drawings Utility power consumption.', 'ship_via': None, 'ship_date': None, 'tracking_number': None}, 'totals_summary': {'currency': None, 'total_due_raw': '$1,550.00', 'total_due': 1550, 'subtotal': 1550, 'tax': 0, 'shipping': None, 'handling_fee': None}, 'line_items': [{'line_number': None, 'sku': None, 'description': 'Provide and install new 60 Amp 240Vac breaker and 6/2 Copper SE cable feeding new Tesla Wall connector. Install new customer supplied Tesla wall connector. Note: drywall may need to be cut to facilitate work. No drywall repairs or painting are included in this quote.', 'quantity': 1, 'unit_price': 1400, 'price': None, 'amount': 1400, 'total': None}, {'line_number': None, 'sku': None, 'description': 'Permit and inspection fees', 'quantity': 1, 'unit_price': 150, 'price': None, 'amount': 150, 'total': None}, {'line_number': None, 'sku': None, 'description': 'Payment Terms: by Cash or Check, All sales final. $750.00 deposit at acceptance of contract balance due upon substantial completion of work. Agreement to include conditions of agreement addendum Clarifications: It is agreed that during the performance of the work drywall will/may be cut at the discretion of the contractor, this quotation does not include any drywall or painting repair or touchup. Parking to be provided onsite for all working personnel. Work will be completed during normal hours from 8:00 AM to 5:00 PM Monday thru Friday, unless approved otherwise. No additional components will be installed outside the scope of work enclosed. All fixtures and lamps are to be furnished on-site by others. Excluded from Bid: Repairs or corrections to existing plumbing, gas, or electrical system deficiencies or code violations. Repairs to any underground utilities (such as sprinkler lines, electrical lines, cable, etc.) not located and clearly marked prior to arrival on-site. Engineered drawings Utility power consumption.', 'quantity': 1, 'unit_price': 0, 'price': None, 'amount': 0, 'total': None}]}, extraction_metadata={'invoice_info': {'invoice_date_raw': {'value': '10/03/2022', 'references': ['6d76de3b-615b-4f02-911b-eed2dda89d81']}, 'invoice_date': {'value': '2022-10-03', 'references': ['6d76de3b-615b-4f02-911b-eed2dda89d81']}, 'invoice_number': {'value': '52255', 'references': ['6d76de3b-615b-4f02-911b-eed2dda89d81']}, 'order_date': {'value': None, 'references': []}, 'po_number': {'value': None, 'ref ...

# %% [markdown]
# ## 📊 Organizing Results into Summary Tables
#
# After parsing and extracting all documents, we'll organize the data into **4 normalized DataFrames** that match a typical database schema:
#
# ### 1. **Markdown Table** - Full Document Text
# - One row per invoice
# - Contains the complete markdown output from parsing
# - Useful for full-text search and debugging
#
# ### 2. **Chunks Table** - Document Regions with Coordinates
# - One row per chunk (text region, table, logo, etc.)
# - Includes bounding box coordinates (left, top, right, bottom)
# - Shows page number where chunk appears
# - Links back to invoice via `INVOICE_UUID`
# - **Use case**: Visualizing where data was found, audit trails
#
# ### 3. **Invoice Main Table** - One Row Per Invoice
# - Flattened structure with all top-level invoice fields
# - Contains invoice info, customer, supplier, order details, totals
# - Primary table for reporting and analytics
# - Linked by `INVOICE_UUID` to other tables
#
# ### 4. **Line Items Table** - Multiple Rows Per Invoice
# - One row for each product/service line item
# - Contains SKU, description, quantity, price, amount
# - Linked to parent invoice via `INVOICE_UUID`
# - **Use case**: Product-level analytics, inventory tracking
#
# All tables share common keys:
# - `RUN_ID`: Identifies this batch processing run
# - `INVOICE_UUID`: Unique identifier for each invoice
# - `DOCUMENT_NAME`: Original filename
# - `AGENTIC_DOC_VERSION`: ADE engine version used
#
# This normalized structure makes it easy to insert into databases like Snowflake, PostgreSQL, or BigQuery.

# %%
# Convert the batch results into 4 normalized DataFrames
# Function located in invoice_utilities.py
# Takes the list of (parse_result, extract_result) tuples and creates structured tables

invoice_summaries = create_invoice_summary_tables(results_summary)

# %% [markdown]
# ## 📝 Table 1: Markdown - Full Document Text per Invoice

# %%
# Display the markdown table
# One row per invoice with full document text
invoice_markdown = invoice_summaries[0]
invoice_markdown
# Out:
#                                  RUN_ID                          INVOICE_UUID  \
# 0  0499dbd8-4971-4903-ad2f-cb6a0af4285a  82d35867-787d-40cc-8d05-b6e86239ce06
# 1  0499dbd8-4971-4903-ad2f-cb6a0af4285a  42c1cd0e-907e-4258-af34-a93519a33cdc
# 2  0499dbd8-4971-4903-ad2f-cb6a0af4285a  ddd6244c-9be3-411a-9f56-bf4a0325aaa7
#
#    DOCUMENT_NAME AGENTIC_DOC_VERSION  \
# 0  invoice_2.pdf      dpt-2-20250919
# 1  invoice_1.pdf      dpt-2-20250919
# 2  invoice_3.pdf      dpt-2-20250919
#
#                                             MARKDOWN
# 0  <a id='5e627a04-6af2-4ca1-b7d7-24a9edea248d'><...
# 1  <a id='163da434-a2a8-4ac9-8cd0-559a3d6b3a78'><...
# 2  <a id='00c1108c-2a02-4ebd-ae63-b366b6afc7cd'><...

# %% [markdown]
# ## 🧩 Table 2: Chunks - Document Regions with Bounding Boxes
#
# Each chunk represents a distinct region in the document (paragraph, table, logo, etc.) with its location coordinates. This is useful for:
# - **Visual grounding**: See exactly where each piece of text was found
# - **Audit trails**: Verify extraction accuracy by reviewing source chunks
# - **Layout analysis**: Understand document structure

# %%
# Display the chunks table
# One row per chunk with bounding box coordinates (box_l, box_t, box_r, box_b)
# Coordinates are normalized 0-1 relative to page dimensions
invoice_chunks = invoice_summaries[1]
invoice_chunks
# Out:
#                                   RUN_ID  \
# 0   0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 1   0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 2   0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 3   0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 4   0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 5   0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 6   0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 7   0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 8   0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 9   0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 10  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 11  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 12  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 13  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 14  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 15  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 16  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 17  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 18  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 19  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 20  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 21  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 22  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 23  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 24  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 25  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 26  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 27  0499dbd8-4971-4903-ad2f-cb6a0af4285a
# 28  0499dbd8-4971-4903-ad2f-cb6a0af4285a
#
#                             INVOICE_UUID  DOCUMENT_NAME  \
# 0   82d35867-787d-40cc-8d05-b6e86239ce06  invoice_2.pdf
# 1   82d35867-787d-40cc-8d05-b6e86239ce06  invoice_2.pdf
# 2   82d35867-787d-40cc-8d05-b6e86239ce06  invoice_2.pdf
# 3   82d35867-787d-40cc-8d05-b6e86239ce06  invoice_2.pdf
# 4   82d35867-787d-40cc-8d05-b6e86239ce06  invoice_2.pdf
# 5   82d35867-787d-40cc-8d05-b6e86239ce06  invoice_2.pdf
# 6   82d35867-787d-40cc-8d05-b6e86239ce06  invoice_2.pdf
# 7   82d35867-787d-40cc-8d05-b6e86239ce06  invoice_2.pdf
# 8   82d35867-787d-40cc-8d05-b6e86239ce06  invoice_2.pdf
# 9   82d35867-787d-40cc-8d05-b6e86239ce06  invoice_2.pdf
# 10  42c1cd0e-907e-4258-af34-a93519a33cdc  invoice_1.pdf
# 11  42c1cd0e-907e-4258-af34-a93519a33cdc  invoice_1.pdf
# 12  42c1cd0e-907e-4258-af34-a93519a33cdc  invoice_1.pdf
# 13  42c1cd0e-907e-4258-af34-a93519a33cdc  invoice_1.pdf
# 14  42c1cd0e-907e-4258-af34-a93519a33cdc  invoice_1.pdf
# 15  42c1cd0e-907e-4258-af34-a93519a33cdc  invoice_1.pdf
# 16  42c1cd0e-907e-4258-af34-a93519a33cdc  invoice_1.pdf
# 17  42c1cd0e-907e-4258-af34-a93519a33cdc  invoice_1.pdf
# 18  42c1cd0e-907e-4258-af34-a93519a33cdc  invoice_1.pdf
# 19  ddd6244c-9be3-411a-9f56-bf4a0325aaa7  invoice_3.pdf
# 20  ddd6244c-9be3-411a-9f56-bf4a0325aaa7  invoice_3.pdf
# 21  ddd6244c-9be3-411a-9f56-bf4a0325aaa7  invoice_3.pdf
# 22  ddd6244c-9be3-411a-9f56-bf4a0325aaa7  invoice_3.pdf
# 23  ddd6244c-9be3-411a-9f56-bf4a0325aaa7  invoice_3.pdf
# 24  ddd6244c-9be3-411a-9f56-bf4a0325aaa7  invoice_3.pdf
# 25  ddd6244c-9be3-411a-9f56-bf4a0325aaa7  invoice_3.pdf
# 26  ddd6244c-9be3-411a-9f56-bf4a0325aaa7  invoice_3.pdf
# 27  ddd6244c-9be3-411a-9f56-bf4a0325aaa7  invoice_3.pdf
# 28  ddd6244c-9be3-411a-9f56-bf4a0325aaa7  invoice_3.pdf
#
#                                 chunk_id  chunk_type  \
# 0   5e627a04-6af2-4ca1-b7d7-24a9edea248d        logo
# 1   9e6635a3-de58-4fe2-956e-787713d5bca7        text
# 2   3d4edaa6-d809-4408-aa77-edc4baee0bc0        text
# 3   4218c1aa-560b-476b-8f2e-ec9508896069        text
# 4   65fbe8ff-f266-49cf-b951-4abb97fa3ac2        text
# 5   72cdd2d9-6f2a-4450-a82b-8ec4009a1eef        text
# 6   2b891183-123d-4ee0-b61a-a6631ee7f205        text
# 7   3bf54dcf-f6a8-478f-94b7-342f9689568a       table
# 8   2702091f-6a0d-43f3-ae65-eeaf5e5da24d        text
# 9   a331fa69-2369-42c9-b672-5b4d30e70c47        text
# 10  163da434-a2a8-4ac9-8cd0-559a3d6b3a78        logo
# 11  bf2d2f02-1e8c-4aeb-8533-90457ae2e841  marginalia
# 12  dd80af68-b3ca-4001-a459-a2f2cc9c0550        text
# 13  2212472c-3e6d-4a44-a244-f156da313013        text
# 14  9aed0e25-1736-4bfd-8bff-0ad112c3f20c        text
# 15  6d456466-8829-49e4-8a26-b5ea6c7d6f17       table
# 16  dd84e4e1-ee27-4d11-9cf4-51149c31c870       table
# 17  eb0d17d1-18b6-43c5-a118-d029b713a56c       table
# 18  2c374b4a-4f64-486f-9c3e-205ddb828386       table
# 19  00c1108c-2a02-4ebd-ae63-b366b6afc7cd        text
# 20  75522ab8-1aed-4388-bdc6-9bef9911c2eb        logo
# 21  4a071eef-e9da-4811-94f5-55e06c7b625f        text
# 22  730ab534-1394-4759-85f1-209fb5acc59f        text
# 23  6d76de3b-615b-4f02-911b-eed2dda89d81        text
# 24  d46d9316-31d3-49be-8599-e955707b9882        text
# 25  6748667f-068d-477a-bcd9-6363b24b5e0e       table
# 26  df2a3514-317a-4ff3-a76b-0c1f1dcf7175        text
# 27  30994a72-a6eb-482d-9108-c08ff513cb50       table
# 28  d544f667-4b06-46f5-bf44-f7005fd7af2c  marginalia
#
#                                                  text  page     box_l  \
# 0   <a id='5e627a04-6af2-4ca1-b7d7-24a9edea248d'><...     0  0.072008
# 1   <a id='9e6635a3-de58-4fe2-956e-787713d5bca7'><...     0  0.498373
# 2   <a id='3d4edaa6-d809-4408-aa77-edc4baee0bc0'><...     0  0.722577
# 3   <a id='4218c1aa-560b-476b-8f2e-ec9508896069'><...     0  0.053898
# 4   <a id='65fbe8ff-f266-49cf-b951-4abb97fa3ac2'><...     0  0.319150
# 5   <a id='72cdd2d9-6f2a-4450-a82b-8ec4009a1eef'><...     0  0.498381
# 6   <a id='2b891183-123d-4ee0-b61a-a6631ee7f205'><...     0  0.733910
# 7   <a id='3bf54dcf-f6a8-478f-94b7-342f9689568a'><...     0  0.053954
# 8   <a id='2702091f-6a0d-43f3-ae65-eeaf5e5da24d'><...     0  0.053102
# 9   <a id='a331fa69-2369-42c9-b672-5b4d30e70c47'><...     0  0.053190
# 10  <a id='163da434-a2a8-4ac9-8cd0-559a3d6b3a78'><...     0  0.080266
# 11  <a id='bf2d2f02-1e8c-4aeb-8533-90457ae2e841'><...     0  0.792007
# 12  <a id='dd80af68-b3ca-4001-a459-a2f2cc9c0550'><...     0  0.080417
# 13  <a id='2212472c-3e6d-4a44-a244-f156da313013'><...     0  0.487995
# 14  <a id='9aed0e25-1736-4bfd-8bff-0ad112c3f20c'><...     0  0.080247
# 15  <a id='6d456466-8829-49e4-8a26-b5ea6c7d6f17'><...     0  0.073529
# 16  <a id='dd84e4e1-ee27-4d11-9cf4-51149c31c870'><...     0  0.073451
# 17  <a id='eb0d17d1-18b6-43c5-a118-d029b713a56c'><...     0  0.074607
# 18  <a id='2c374b4a-4f64-486f-9c3e-205ddb828386'><...     0  0.074015
# 19  <a id='00c1108c-2a02-4ebd-ae63-b366b6afc7cd'><...     0  0.022341
# 20  <a id='75522ab8-1aed-4388-bdc6-9bef9911c2eb'><...     0  0.699409
# 21  <a id='4a071eef-e9da-4811-94f5-55e06c7b625f'><...     0  0.023272
# 22  <a id='730ab534-1394-4759-85f1-209fb5acc59f'><...     0  0.022724
# 23  <a id='6d76de3b-615b-4f02-911b-eed2dda89d81'><...     0  0.655750
# 24  <a id='d46d9316-31d3-49be-8599-e955707b9882'><...     0  0.023406
# 25  <a id='6748667f-068d-477a-bcd9-6363b24b5e0e'><...     0  0.024588
# 26  <a id='df2a3514-317a-4ff3-a76b-0c1f1dcf7175'><...     0  0.025146
# 27  <a id='30994a72-a6eb-482d-9108-c08ff513cb50'><...     0  0.476337
# 28  <a id='d544f667-4b06-46f5-bf44-f7005fd7af2c'><...     0  0.465622
#
#        box_t     box_r     box_b
# 0   0.052074  0.420828  0.221977
# 1   0.042543  0.710104  0.084313
# 2   0.044637  0.948281  0.117790
# 3   0.279113  0.276529  0.369774
# 4   0.279771  0.435022  0.374348
# 5   0.277921  0.667920  0.377318
# 6   0.278069  0.947393  0.338912
# 7   0.436618  0.948443  0.681845
# 8   0.720391  0.149619  0.766105
# 9   0.802936  0.557620  0.853752
# 10  0.019251  0.223726  0.057947
# 11  0.027498  0.887368  0.050593
# 12  0.114021  0.291070  0.171778
# 13  0.114385  0.830832  0.261494
# 14  0.243914  0.242688  0.325429
# 15  0.348236  0.926118  0.488154
# 16  0.517988  0.925794  0.644868
# 17  0.653802  0.922956  0.731455
# 18  0.761784  0.924711  0.899134
# 19  0.040315  0.334422  0.137488
# 20  0.038082  0.969605  0.187662
# 21  0.219055  0.121890  0.242034
# 22  0.249246  0.212258  0.313873
# 23  0.247990  0.874293  0.300574
# 24  0.328005  0.107222  0.360128
# 25  0.371077  0.976572  0.778761
# 26  0.795333  0.441758  0.891987
# 27  0.791963  0.977187  0.906056
# 28  0.966764  0.535718  0.984346

# %% [markdown]
# ## 📄 Table 3: Invoice Main - Flattened Invoice-Level Fields
#
# This is the primary table for analytics and reporting. Each row contains all extracted invoice fields flattened into a single record.

# %%
# Display the main invoice table
# One row per invoice with all extracted fields (31 columns total)
# Includes: invoice info, customer, supplier, order details, financial totals
invoice_main = invoice_summaries[2]
invoice_main.head(10)
# Out:
#                                  RUN_ID                          INVOICE_UUID  \
# 0  0499dbd8-4971-4903-ad2f-cb6a0af4285a  82d35867-787d-40cc-8d05-b6e86239ce06
# 1  0499dbd8-4971-4903-ad2f-cb6a0af4285a  42c1cd0e-907e-4258-af34-a93519a33cdc
# 2  0499dbd8-4971-4903-ad2f-cb6a0af4285a  ddd6244c-9be3-411a-9f56-bf4a0325aaa7
#
#    DOCUMENT_NAME AGENTIC_DOC_VERSION INVOICE_DATE_RAW INVOICE_DATE  \
# 0  invoice_2.pdf      dpt-2-20250919       01/29/2020   2020-01-29
# 1  invoice_1.pdf      dpt-2-20250919       07/29/2020   2020-07-29
# 2  invoice_3.pdf      dpt-2-20250919       10/03/2022   2022-10-03
#
#   INVOICE_NUMBER ORDER_DATE PO_NUMBER STATUS  ... SHIP_VIA SHIP_DATE  \
# 0        0001131       None      None   None  ...     None      None
# 1    INV33543191       None             None  ...     None      None
# 2          52255       None      None   None  ...     None      None
#
#   TRACKING_NUMBER CURRENCY TOTAL_DUE_RAW TOTAL_DUE SUBTOTAL TAX SHIPPING  \
# 0            None      USD     $2,650.00    2650.0   2650.0   0     None
# 1            None      USD       $149.90     149.9    149.9   0     None
# 2            None     None     $1,550.00    1550.0   1550.0   0     None
#
#   HANDLING_FEE
# 0         None
# 1         None
# 2         None
#
# [3 rows x 31 columns]

# %% [markdown]
# ## 🛒 Table 4: Line Items - Product/Service Details
#
# This table contains the individual line items from each invoice. Multiple rows per invoice for invoices with multiple products/services.

# %%
# Display the line items table
# Multiple rows per invoice, one for each purchased product/service
# Contains: line number, SKU, description, quantity, pricing details
invoice_items = invoice_summaries[3]
invoice_items.head(10)
# Out:
#                                  RUN_ID                          INVOICE_UUID  \
# 0  0499dbd8-4971-4903-ad2f-cb6a0af4285a  82d35867-787d-40cc-8d05-b6e86239ce06
# 1  0499dbd8-4971-4903-ad2f-cb6a0af4285a  42c1cd0e-907e-4258-af34-a93519a33cdc
# 2  0499dbd8-4971-4903-ad2f-cb6a0af4285a  ddd6244c-9be3-411a-9f56-bf4a0325aaa7
# 3  0499dbd8-4971-4903-ad2f-cb6a0af4285a  ddd6244c-9be3-411a-9f56-bf4a0325aaa7
# 4  0499dbd8-4971-4903-ad2f-cb6a0af4285a  ddd6244c-9be3-411a-9f56-bf4a0325aaa7
#
#    DOCUMENT_NAME AGENTIC_DOC_VERSION  LINE_INDEX LINE_NUMBER   SKU  \
# 0  invoice_2.pdf      dpt-2-20250919           0        None  None
# 1  invoice_1.pdf      dpt-2-20250919           0        None  None
# 2  invoice_3.pdf      dpt-2-20250919           0        None  None
# 3  invoice_3.pdf      dpt-2-20250919           1        None  None
# 4  invoice_3.pdf      dpt-2-20250919           2        None  None
#
#                                          DESCRIPTION  QUANTITY  UNIT_PRICE  \
# 0                                 Replace HVAC Unit.         1      2650.0
# 1  Charge Name: Standard Pro Annual Quantity: 1 U...         1       149.9
# 2  Provide and install new 60 Amp 240Vac breaker ...         1      1400.0
# 3                         Permit and inspection fees         1       150.0
# 4  Payment Terms: by Cash or Check, All sales fin...         1         0.0
#
#   PRICE  AMOUNT   TOTAL
# 0  None  2650.0  2650.0
# 1  None   149.9   149.9
# 2  None  1400.0     NaN
# 3  None   150.0     NaN
# 4  None     0.0     NaN

# %% [markdown]
# ## 💾 Save Structured Results
#
# Save the four summary tables to CSV files. These could also be inserted into a database like Snowflake, PostgreSQL, or used for downstream analytics.

# %%
# Save all four DataFrames to CSV files in the results_folder
# Files created:
#   - invoice_markdown.csv
#   - invoice_chunks.csv
#   - invoice_main.csv
#   - invoice_items.csv

invoice_markdown.to_csv(results_folder / "invoice_markdown.csv", index=False)
invoice_chunks.to_csv(results_folder / "invoice_chunks.csv", index=False)
invoice_main.to_csv(results_folder / "invoice_main.csv", index=False)
invoice_items.to_csv(results_folder / "invoice_items.csv", index=False)

print(f"✅ Saved 4 CSV files to {results_folder}")
# Out:
# ✅ Saved 4 CSV files to /Users/andreakropp/Documents/Github/andrea-kropp/ade_demos/Invoices/results_folder

# %% [markdown]
# ## ✅ Wrap-Up
#
# You’ve now used LandingAI’s ADE to:
# - Parse and extract data from invoices, whether the originals are images or PDFs.
# - Define custom fields using a `pydantic` schema.
# - Run Agentic Document Extraction on a batch of documents and save the results.
# - Save the extracted results and as structured data.
#
# To learn more, visit the [LandingAI Documentation](https://docs.landing.ai/ade/ade-overview).
