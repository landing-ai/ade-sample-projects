# %% [markdown]
# # 💡 Fast, Accurate Parsing of Utility Bills with LandingAI
#
# This notebook demonstrates how to use the `landingai-ade` Python package to extract structured information from documents using LandingAI's Agentic Document Extraction (ADE) service. It uses electric bills collected from major utility providers across the United States.
#
# We'll walk through:
# - Parsing documents with Agentic Document Extraction. (ADE)
# - Defining a custom schema using JSON
# - Viewing structured field extractions and metadata.
# - Saving results to CSV
#
#
#
# This notebook demonstrates how to use the `agentic_doc` Python package to extract structured information from utility bills using LandingAI's Agentic Document Extraction (ADE) service. It uses electric bills collected from major utility providers across the United States.
#
# We'll walk through:
# - Parsing documents with Agentic Document Extraction.
# - Defining a custom schema for use with utility bills using `pydantic` or `JSON`.
# - Viewing structured field extractions and metadata.
# - Not covered:
#     - Connecting to upstream document sources.
#     - Inserting parse() and extract() results into structured tables.
#     - Optimizing pipeline throughput.

# %%
# ---
# Title: Fast, Accurate Parsing of Utility Bills with LandingAI
# Author: Andrea Kropp
# Description: How to apply a custom extraction schema to pull fields out of photos and PDFs of utility bills.
# Target Audience: Developers, Product Managers
# Content Type: How-To
# Change Log:
#   - v1.0: 2025-09-22 Initial version
#   - v2.0: Updated 2026-01-16 Switch to using landingai-ade library
# ---

# %% [markdown]
# ### Thumbnails for the Electric Bills in the Demo
#
# Notice that there are 3 photos and 6 PDFs. The extraction process shown here works for both without any modifications.
#
# <img src="images/electric-bills-to-parse-PDF-and-image.png" width="80%" alt="Electric bill image preview">

# %% [markdown]
# ## 📦 Setup & Imports
#
# Import necessary packages and utility functions. Ensure you have installed the required dependencies:
#
# ```bash
# pip install landingai-ade python-dotenv pandas
# ```
#
# Obtain your API Key from the Visual Playground at https://va.landing.ai/settings/api-key
#
# Read about options for setting your API at https://docs.landing.ai/ade/ade-python
#
# This notebook uses a `.env` file in the same directory to store the API key.

# %%
# Standard libraries
import os
import json
from datetime import date
from pathlib import Path
from dotenv import load_dotenv

# Agentic Document Extraction from LandingAI
from landingai_ade import LandingAIADE
from landingai_ade.lib import pydantic_to_json_schema

# Print library version
import landingai_ade
print(f"📦 landingai-ade version: {landingai_ade.__version__}")
# Out:
# 📦 landingai-ade version: 1.4.0

# %%
# Initialize the ADE client (uses VISION_AGENT_API_KEY environment variable)
# See options at https://docs.landing.ai/ade/agentic-api-key

# Load environment variables from .env file
load_dotenv()

# Initialize the client (it will automatically use VISION_AGENT_API_KEY from environment)
client = LandingAIADE()
print("✅ Authenticated client initialized")
# Out:
# ✅ Authenticated client initialized

# %% [markdown]
# ## 📁 Define Input and Output Directories
#
# Specify where your documents are located and where results will be saved.

# %%
# Define input and output directory paths
base_dir = Path(os.getcwd())
input_folder = base_dir / "input_folder"
results_folder = base_dir / "results_folder"

# Create output folders if they don't exist
input_folder.mkdir(parents=True, exist_ok=True)
results_folder.mkdir(parents=True, exist_ok=True)

# %%
# Collect all files to be processed
# Check official documentation for all supported filetypes https://docs.landing.ai/ade/ade-file-types

file_paths = [
    p for p in input_folder.iterdir()
    if p.suffix.lower() in [".pdf", ".png", ".jpg", ".jpeg", ".doc", ".docx", ".odt", ".ppt", ".pptx", ".odp"]
]

print(f"📄 Found {len(file_paths)} documents to process")
for i, path in enumerate(file_paths[:10], 1):
    print(f"  {i}. {path.name}")
# Out:
# 📄 Found 9 documents to process
#   1. electric_C.jpg
#   2. electric_B.jpg
#   3. electric_A.jpg
#   4. electric2.pdf
#   5. electric3.pdf
#   6. electric1.pdf
#   7. electric4.pdf
#   8. electric5.pdf
#   9. electric6.pdf

# %% [markdown]
# ## 📑 Define Custom Schema for Field Extraction
#
# The schema to extract specific fields from utility bills is defined in JSON and saved in a separate file named utility_bill.json
#
# See https://docs.landing.ai/ade/ade-python#extraction-with-json-schema-file for more details.

# %%
# Load schema from JSON file and print it to view the contents
with open("utility_bill.json", "r") as f:
    schema_utility = f.read()

print(schema_utility)
# Out:
# {
#   "type": "object",
#   "title": "Utility Bill Extraction Schema",
#   "description": "Schema for extracting key fields from diverse utility bills.",
#   "required": [
#     "provider_info",
#     "account_info",
#     "billing_summary",
#     "gas_charges",
#     "electric_charges"
#   ],
#   "properties": {
#     "provider_info": {
#       "type": "object",
#       "title": "Provider Information",
#       "required": [
#         "provider",
#         "phone_number",
#         "website",
#         "usage_bar_chart"
#       ],
#       "properties": {
#         "provider": {
#           "type": "string",
#           "title": "Utility Name",
#           "description": "The name of the utility providing the service and issuing the bill."
#         },
#         "phone_number": {
#           "type": "string",
#           "title": "Customer Service Phone Number",
#           "description": "The customer service phone number for the utility formatted XXX-XXX-XXXX."
#         },
#         "website": {
#           "type": "string",
#           "title": "Website",
#           "description": "Official website for account management and payments."
#         },
#         "usage_bar_chart": {
#           "type": "boolean",
#           "description": "Does the utility bill include a chart depicting usage trends over time?"
#         }
#       },
#       "description": "Key energy provider details."
#     },
#     "account_info": {
#       "type": "object",
#       "title": "Account Information",
#       "required": [
#         "account_holder",
#         "account_number",
#         "service_address"
#       ],
#       "properties": {
#         "account_holder": {
#           "type": "string",
#           "title": "Account Holder Name",
#           "description": "Full name of the account holder. This may be a person or organization."
#         },
#         "account_number": {
#           "type": "string",
#           "title": "Account Number",
#           "description": "Unique identifier for the customer account."
#         },
#         "service_address": {
#           "type": "string",
#           "title": "Service Address",
#           "description": "The address for the property where utility service is provided. This may or may not be the same as the billing address. Remove new line characters and replace with a space."
#         },
#         "service_address_primary": {
#             "type": "string",
#             "description": "The primary street address for the property where utility service is provided including building or house number, predirectionals, street name, postdirectionals, and street suffix. This may or may not be the same as the billing address. Remove new line characters and replace with a space."
#         },
#         "service_address_city": {
#             "type": "string",
#             "description": "The city for the address where utility service is provided."
#         },
#         "service_address_state": {
#             "type": "string",
#             "description": "The 2 letter state abbreviation for the address where utility service is provided."
#         },
#         "service_address_zip": {
#             "type": "string",
#             "description": "The 5-digit Zip Code for the address where utility service is provided."
#         }
#       },
#       "description": "Key account and customer identifiers."
#     },
#     "billing_summary": {
#       "type": "object",
#       "title": "Billing Summary",
#       "required": [
#         "due_date",
#         "bill_date",
#         "service_start_date",
#         "service_end_date",
#         "total_amount_due"
#       ],
#       "properties": {
#         "due_date": {
#           "type": "string",
#           "title": "Due Date",
#           "description": "Date by which payment is due, in YYYY-MM-DD format."
#         },
#         "bill_date": {
#           "type": "string",
#           "title": "Bill Date",
#           "description": "Date the bill was issued, in YYYY-MM-DD format."
#         },
#         "service_start_date": {
#           "type": "string",
#           "description": "The starting date for the period of service covered by the utility bill.",
#           "format": "MM-DD-YYYY"
#         },
#         "service_end_date": {
#           "type": "string",
#           "description": "The ending date for the period of service covered by the utility bill.",
#           "format": "MM-DD-YYYY"
#         },
#         "total_amount_due": {
#           "type": "string",
#           "title": "Total Amount Due",
#           "description": "Total amount due for the current bill, including currency symbol."
#         }
#       },
#       "description": "Summary of charges and due dates."
#     },
#     "electric_charges": {
#       "type": "object",
#       "title": "Electric Charges",
#       "required": [
#         "meter_number",
#         "usage_kwh",
#         "total_electric_charges"
#       ],
#       "properties": {
#          "meter_number": {
#           "type": "string",
#           "title": "Electric Meter Number",
#           "description": "Identifier for the electric meter. Blank if this bill does not inlcude electric service."
#         },
#         "usage_kwh": {
#           "type": "string",
#           "title": "Electric Usage (kWh)",
#           "description": "Total electric used in kilowatt-hours for the billing period. Zero if this bill does not inlcude electric service."
#         },
#         "total_electric_charges": {
#           "type": "string",
#           "title": "Total Electric Charges",
#           "description": "Total electric charges for the billing period, including currency symbol. Zero if this bill does not inlcude electric service."
#         }
#       },
#       "description": "Details of electric usage and charges for the billing period."
#     },
#       "gas_charges": {
#       "type": "object",
#       "title": "Gas Charges",
#       "required": [
#         "meter_number",
#         "usage_therms",
#         "total_gas_charges"
#       ],
#       "properties": {
#         "meter_number": {
#           "type": "string",
#           "title": "Gas Meter Number",
#           "description": "Identifier for the gas meter. Blank if this bill does not inlcude gas service."
#         },
#         "usage_therms": {
#           "type": "string",
#           "title": "Gas Usage (Therms)",
#           "description": "Total gas used in therms for the billing period. Zero if this bill does not inlcude gas service."
#         },
#         "total_gas_charges": {
#           "type": "string",
#           "title": "Total Gas Charges",
#           "description": "Total gas charges for the billing period, including currency symbol. Zero if this bill does not inlcude gas service."
#         }
#       },
#       "description": "Details of gas usage and charges for the billing period."
#     }
#   }
# }

# %% [markdown]
# ## 📄 Single Document Example
#
# Let's start with a single document to understand the workflow.
#
# ### Two-Step Process: Parse → Extract
#
# **Step 1: Parse**
# The `parse()` method converts the document into structured markdown and chunks with grounding information.
#
# **Step 2: Extract**
# The `extract()` method applies your custom schema to pull specific fields from the markdown.

# %% [markdown]
# ### Step 1: Parse a Single Document

# %%
from landingai_ade.types import ParseResponse, ExtractResponse

if len(file_paths) > 0:
    # Parse the first document
    single_doc = file_paths[0]
    print(f"🔍 Parsing: {single_doc.name}")

    single_parse_result: ParseResponse = client.parse(
        document=single_doc,
        model="dpt-2-latest"
    )

    # Explore the parse result
    print(f"✅ Parse complete!")

    print(f"Markdown length: {len(single_parse_result.markdown)} characters")
    print(f"Chunks: {len(single_parse_result.chunks)}")
    
    print(f"Parsing metadata: {single_parse_result.metadata}")
    print(f"Grounding details: {single_parse_result.grounding}")

    print(f"\n📝 Markdown preview (first 200 chars):")
    print(single_parse_result.markdown[:200] + "...")
# Out:
# 🔍 Parsing: electric_C.jpg
# ✅ Parse complete!
# Markdown length: 4392 characters
# Chunks: 25
# Parsing metadata: ParseMetadata(credit_usage=3.0, duration_ms=6108, filename='electric_C.jpg', job_id='910f07899e2540f5805fe11f3a5a88d2', org_id='u3z0u1hn4acl', page_count=1, version='dpt-2-20251103', failed_pages=[])
# Grounding details: {'d19cd262-30cf-4190-9eff-36550c6a5c3d': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.039192840456962585, left=0.6765761971473694, right=0.9236930012702942, top=0.014950261451303959), page=0, type='chunkMarginalia'), 'e2140f7a-8aca-4160-b2dc-4906a9a4bd07': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.12159416079521179, left=0.08390103280544281, right=0.3306434750556946, top=0.06359539926052094), page=0, type='chunkLogo'), '8fd68cba-9804-432a-8a56-bfce7906c3e5': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.1371183842420578, left=0.47135013341903687, right=0.9220030903816223, top=0.0429876446723938), page=0, type='chunkText'), 'b4badc46-91ef-4eb3-9c5f-976bedb484e4': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.18655483424663544, left=0.077561154961586, right=0.45045971870422363, top=0.12955926358699799), page=0, type='chunkText'), '8e8ea6f2-571c-4504-b82a-a01ea57f84a0': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.17779578268527985, left=0.4763250946998596, right=0.8144863247871399, top=0.14167101681232452), page=0, type='chunkText'), '9037176a-cdd5-45ad-8fd8-a137fb8f1e44': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.33087360858917236, left=0.08316846191883087, right=0.45760130882263184, top=0.19434142112731934), page=0, type='chunkText'), 'ff50a4be-0af4-4de4-b5ae-2d9bc5cb120b': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.36135134100914, left=0.08547700941562653, right=0.4596870541572571, top=0.335122674703598), page=0, type='chunkText'), '1aca79f3-71e4-4088-99bc-11f059b03987': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.4005107879638672, left=0.08097130060195923, right=0.4605668783187866, top=0.3630608320236206), page=0, type='chunkText'), '9b12280f-63f7-4bf5-beae-806aecb29e5c': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.441291481256485, left=0.07018981128931046, right=0.308034747838974, top=0.4178977310657501), page=0, type='chunkText'), 'd12c045b-2235-4667-a9c1-012ddeeb3d3f': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.6203818321228027, left=0.05352377891540527, right=0.4619123339653015, top=0.4459122121334076), page=0, type='chunkText'), '6e078d99-b096-497e-9343-efa3899c4ef9': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.17812132835388184, left=0.4760188162326813, right=0.8150986433029175, top=0.1417558789253235), page=0, type='chunkText'), 'e508699a-1f8c-4986-80ef-081e40c9df24': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.2678360342979431, left=0.4768083095550537, right=0.866148829460144, top=0.18580669164657593), page=0, type='chunkText'), 'ae09301f-72ba-46de-a7b0-f625f4e08710': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.41654008626937866, left=0.5022051334381104, right=0.9137459993362427, top=0.3160105347633362), page=0, type='chunkText'), 'f2cee041-9ee5-47b4-af2d-1305ace23516': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.5642014741897583, left=0.5156453847885132, right=0.9201442003250122, top=0.4231199026107788), page=0, type='chunkText'), '1762c19f-fc26-4937-b14b-79ff1b16c535': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.5919811129570007, left=0.5286940336227417, right=0.862450122833252, top=0.565545380115509), page=0, type='chunkText'), 'a6c529e0-46ab-43a1-81fd-5f0656f8527c': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.625781238079071, left=0.7852920889854431, right=0.8708265423774719, top=0.6043347716331482), page=0, type='chunkMarginalia'), 'ff2af25e-6dac-4d5c-8bba-8eb7afb50201': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.6817501783370972, left=0.059453219175338745, right=0.1977120041847229, top=0.6499001979827881), page=0, type='chunkLogo'), 'e33d12c2-fdee-4822-8e20-9d8c58ac5a44': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.6989490985870361, left=0.5791857838630676 ...
#
# 📝 Markdown preview (first 200 chars):
# <a id='d19cd262-30cf-4190-9eff-36550c6a5c3d'></a>
#
# ia.pxpsg.j10b0s01.ipsgbill 202506 102152.csv-272055-000009640
#
# <a id='e2140f7a-8aca-4160-b2dc-4906a9a4bd07'></a>
#
# <::logo: PSEG
# PSEG
# An orange sun-li...

# %% [markdown]
# ### Step 2: Extract Structured Fields

# %%
if len(file_paths) > 0:

     # Extract structured data using the schema
    single_extraction_result: ExtractResponse = client.extract(
        markdown=single_parse_result.markdown,  # send the markdown from the parsing step
        schema=schema_utility
    )

    # View the extracted CME data

    print(f"✅ Extraction complete!")
    
    print(f"\n📦 Extracted fields:")
    print(single_extraction_result.extraction)

    print(f"\n📦 Extracted field metadata:")
    print(single_extraction_result.extraction_metadata)

    print(f"\n📦 Extraction process details:")
    print(single_extraction_result.metadata)
# Out:
# ✅ Extraction complete!
#
# 📦 Extracted fields:
# {'provider_info': {'provider': 'PSEG', 'phone_number': '1-800-436-7734', 'website': 'pseg.com/myaccount', 'usage_bar_chart': True}, 'account_info': {'account_holder': 'ARISLEIDY BAEZ NUNEZ', 'account_number': '7491381707', 'service_address': '1146 N 31ST ST CAMDEN CITY NJ 08105-4118', 'service_address_primary': '1146 N 31ST ST', 'service_address_city': 'CAMDEN CITY', 'service_address_state': 'NJ', 'service_address_zip': '08105'}, 'billing_summary': {'due_date': '2025-06-26', 'bill_date': '2025-06-11', 'service_start_date': '05-09-2025', 'service_end_date': '06-09-2025', 'total_amount_due': '$1,467.77'}, 'electric_charges': {'meter_number': None, 'usage_kwh': None, 'total_electric_charges': None}, 'gas_charges': {'meter_number': None, 'usage_therms': None, 'total_gas_charges': None}}
#
# 📦 Extracted field metadata:
# {'provider_info': {'provider': {'value': 'PSEG', 'references': ['e2140f7a-8aca-4160-b2dc-4906a9a4bd07']}, 'phone_number': {'value': '1-800-436-7734', 'references': ['d12c045b-2235-4667-a9c1-012ddeeb3d3f']}, 'website': {'value': 'pseg.com/myaccount', 'references': ['d12c045b-2235-4667-a9c1-012ddeeb3d3f']}, 'usage_bar_chart': {'value': True, 'references': ['f2cee041-9ee5-47b4-af2d-1305ace23516']}}, 'account_info': {'account_holder': {'value': 'ARISLEIDY BAEZ NUNEZ', 'references': ['e508699a-1f8c-4986-80ef-081e40c9df24']}, 'account_number': {'value': '7491381707', 'references': ['e508699a-1f8c-4986-80ef-081e40c9df24']}, 'service_address': {'value': '1146 N 31ST ST CAMDEN CITY NJ 08105-4118', 'references': ['e508699a-1f8c-4986-80ef-081e40c9df24']}, 'service_address_primary': {'value': '1146 N 31ST ST', 'references': ['e508699a-1f8c-4986-80ef-081e40c9df24']}, 'service_address_city': {'value': 'CAMDEN CITY', 'references': ['e508699a-1f8c-4986-80ef-081e40c9df24']}, 'service_address_state': {'value': 'NJ', 'references': ['e508699a-1f8c-4986-80ef-081e40c9df24']}, 'service_address_zip': {'value': '08105', 'references': ['e508699a-1f8c-4986-80ef-081e40c9df24']}}, 'billing_summary': {'due_date': {'value': '2025-06-26', 'references': ['ae09301f-72ba-46de-a7b0-f625f4e08710']}, 'bill_date': {'value': '2025-06-11', 'references': ['8e8ea6f2-571c-4504-b82a-a01ea57f84a0']}, 'service_start_date': {'value': '05-09-2025', 'references': ['8e8ea6f2-571c-4504-b82a-a01ea57f84a0']}, 'service_end_date': {'value': '06-09-2025', 'references': ['8e8ea6f2-571c-4504-b82a-a01ea57f84a0']}, 'total_amount_due': {'value': '$1,467.77', 'references': ['ae09301f-72ba-46de-a7b0-f625f4e08710']}}, 'electric_charges': {'meter_number': {'value': None, 'references': []}, 'usage_kwh': {'value': None, 'references': []}, 'total_electric_charges': {'value': None, 'references': []}}, 'gas_charges': {'meter_number': {'value': None, 'references': []}, 'usage_therms': {'value': None, 'references': []}, 'total_gas_charges': {'value': None, 'references': []}}}
#
# 📦 Extraction process details:
# Metadata(credit_usage=1.6714, duration_ms=20852, filename='upload.md', job_id='5eee7d4ca7cd403da7c34a57075d15cd', org_id='u3z0u1hn4acl', version='extract-20251024', fallback_model_version=None, schema_violation_error="Extracted data does not completely conform to the requested schema. See below error for details.\nNone is not of type 'string'\n\nFailed validating 'type' in schema['properties']['electric_charges']['properties']['meter_number']:\n    {'type': 'string',\n     'title': 'Electric Meter Number',\n     'description': 'Identifier for the electric meter. Blank if this bill '\n                    'does not inlcude electric service.'}\n\nOn instance['electric_charges']['meter_number']:\n    None\nPlease read our documentation for more information: https://docs.landing.ai/ade/ade-extract-troubleshoot")

# %% [markdown]
# ## 🚀 Run ADE Parse + Extract for All Input Files
#
# Parse all documents in the input folder and save outputs:
# - **Parse JSON** (`{filename}_parse.json`): Full parse response with markdown, chunks, grounding, and metadata
# - **Markdown** (`{filename}.md`): Just the extracted text content
# - **Extract JSON** (`{filename}_extract.json`): Structured extraction results with field metadata
#
# Each output file is named after the input file for easy reference.

# %%
# Optional dictionary to store document types and parse results
results = {}

# Process each document in the folder
for input_file in input_folder.glob("*"):
    if input_file.suffix.lower() not in [".pdf", ".png", ".jpg", ".jpeg"]:
        continue
        
    doc_name = input_file.stem
    print(f"Processing document: {input_file.name}")
    
    # Step 1: Parse the document to extract layout and content
    parse_result: ParseResponse = client.parse(
        document=input_file,
        model="dpt-2-latest"
    )
    print("  ✅ Parsing completed.")
    
    # Save parse results
    parse_json_path = results_folder / f"{doc_name}_parse.json"
    markdown_path = results_folder / f"{doc_name}.md"
    
    with open(parse_json_path, 'w', encoding='utf-8') as f:
        json.dump(parse_result.model_dump(), f, indent=2, ensure_ascii=False, default=str)
    
    with open(markdown_path, 'w', encoding='utf-8') as f:
        f.write(parse_result.markdown)
    
    print(f"  💾 Saved parse JSON and markdown")
   
    # Step 2: Extract document type using the previously loaded schema
    print("  🎯 Running extraction...")
    extraction_result: ExtractResponse = client.extract(
        schema=schema_utility,
        markdown=parse_result.markdown
    )
    print("  ✅ Extraction completed.")
    
    # Save extraction results
    extract_json_path = results_folder / f"{doc_name}_extract.json"
    with open(extract_json_path, 'w', encoding='utf-8') as f:
        json.dump(extraction_result.model_dump(), f, indent=2, ensure_ascii=False, default=str)
    
    print(f"  💾 Saved extraction JSON\n")

    # Store in results dictionary. This will be used later to create a summary dataframe
    results[doc_name] = {
        "parse_result": parse_result,
        "extraction_result": extraction_result
    }

print(f"✅ Processed {len(results)} documents")
# Out:
# Processing document: electric_C.jpg
#   ✅ Parsing completed.
#   💾 Saved parse JSON and markdown
#   🎯 Running extraction...
#   ✅ Extraction completed.
#   💾 Saved extraction JSON
#
# Processing document: electric_B.jpg
#   ✅ Parsing completed.
#   💾 Saved parse JSON and markdown
#   🎯 Running extraction...
#   ✅ Extraction completed.
#   💾 Saved extraction JSON
#
# Processing document: electric_A.jpg
#   ✅ Parsing completed.
#   💾 Saved parse JSON and markdown
#   🎯 Running extraction...
#   ✅ Extraction completed.
#   💾 Saved extraction JSON
#
# Processing document: electric2.pdf
#   ✅ Parsing completed.
#   💾 Saved parse JSON and markdown
#   🎯 Running extraction...
#   ✅ Extraction completed.
#   💾 Saved extraction JSON
#
# Processing document: electric3.pdf
#   ✅ Parsing completed.
#   💾 Saved parse JSON and markdown
#   🎯 Running extraction...
#   ✅ Extraction completed.
#   💾 Saved extraction JSON
#
# Processing document: electric1.pdf
#   ✅ Parsing completed.
#   💾 Saved parse JSON and markdown
#   🎯 Running extraction...
#   ✅ Extraction completed.
#   💾 Saved extraction JSON
#
# Processing document: electric4.pdf
#   ✅ Parsing completed.
#   💾 Saved parse JSON and markdown
#   🎯 Running extraction...
#   ✅ Extraction completed.
#   💾 Saved extraction JSON
#
# Processing document: electric5.pdf
#   ✅ Parsing completed.
#   💾 Saved parse JSON and markdown
#   🎯 Running extraction...
#   ✅ Extraction completed.
#   💾 Saved extraction JSON
#
# Processing document: electric6.pdf
#   ✅ Parsing completed.
#   💾 Saved parse JSON and markdown
#   🎯 Running extraction...
#   ✅ Extraction completed.
#   💾 Saved extraction JSON
#
# ✅ Processed 9 documents

# %%
results
# Out:
# {'electric_C': {'parse_result': ParseResponse(chunks=[Chunk(id='94d75a84-7b0b-4996-ba56-4661863a2fe9', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.039192840456962585, left=0.6765761971473694, right=0.9236930012702942, top=0.014950261451303959), page=0), markdown="<a id='94d75a84-7b0b-4996-ba56-4661863a2fe9'></a>\n\nia.pxpsg.j10b0s01.ipsgbill 202506 102152.csv-272055-000009640", type='marginalia'), Chunk(id='d81276b6-2ab2-4870-aefa-0e0d1e92e2a6', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.12159416079521179, left=0.08390103280544281, right=0.3306434750556946, top=0.06359539926052094), page=0), markdown="<a id='d81276b6-2ab2-4870-aefa-0e0d1e92e2a6'></a>\n\n<::logo: PSEG\nPSEG\nAn orange sun-like symbol with rays emanating from the center, next to the company name in dark gray text.::>", type='logo'), Chunk(id='f7a7b5b1-744f-4a08-8daf-15b04ba077b0', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.1371183842420578, left=0.47135013341903687, right=0.9220030903816223, top=0.0429876446723938), page=0), markdown="<a id='f7a7b5b1-744f-4a08-8daf-15b04ba077b0'></a>\n\n✔Shut-off notice $1,467.77\nTotal amount due\nSee shut-off notice below for payment details", type='text'), Chunk(id='d0e7f6ca-5cca-4998-a6ba-6d4f631cbf3e', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.18655483424663544, left=0.077561154961586, right=0.45045971870422363, top=0.12955926358699799), page=0), markdown="<a id='d0e7f6ca-5cca-4998-a6ba-6d4f631cbf3e'></a>\n\nYour energy bill", type='text'), Chunk(id='38c2c2cb-c2ea-4ac2-a12a-cfb2fe663142', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.17779578268527985, left=0.4763250946998596, right=0.8144863247871399, top=0.14167101681232452), page=0), markdown="<a id='38c2c2cb-c2ea-4ac2-a12a-cfb2fe663142'></a>\n\nBill date: June 11, 2025\nFor the period: May 09, 2025 to June 09, 2025", type='text'), Chunk(id='50a9bda7-8221-44ab-91d8-394e7be0fdc4', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.33087360858917236, left=0.08316846191883087, right=0.45760130882263184, top=0.19434142112731934), page=0), markdown="<a id='50a9bda7-8221-44ab-91d8-394e7be0fdc4'></a>\n\n! Message Center\n\n**SHUT-OFF NOTICE**\n1-800-357-2262 (Mon-Fri, 7:30 AM - 8:00 PM)\n\nYour service is currently in danger of being shut off. $1,130.86 is due\nimmediately. Note further that an additional $159.80 is now past due\nand must be paid by 6/26/2025 or $1,290.66 will be required to avoid\nshut off. A statement of customer rights and fees is shown on the\nreverse side.", type='text'), Chunk(id='64d37001-0dc3-4752-98d7-10889909fc53', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.36135134100914, left=0.08547700941562653, right=0.4596870541572571, top=0.335122674703598), page=0), markdown="<a id='64d37001-0dc3-4752-98d7-10889909fc53'></a>\n\nSi en el futuro usted desea recibir la notificación de desconexión de\nservicio en español, por favor llame al 1-800-357-2262", type='text'), Chunk(id='0741a995-d53a-45b4-8f1c-68db98c03b24', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.4005107879638672, left=0.08097130060195923, right=0.4605668783187866, top=0.3630608320236206), page=0), markdown="<a id='0741a995-d53a-45b4-8f1c-68db98c03b24'></a>\n\nIf you or any member of your household rely on electricity to\noperate life sustaining equipment, please notify PSE&G. For more\ninformation, visit pseg.com/life or call 1-800-436-PSEG.", type='text'), Chunk(id='64d45b22-73fc-4f82-9627-d184edd41208', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.441291481256485, left=0.07018981128931046, right=0.308034747838974, top=0.4178977310657501), page=0), markdown="<a id='64d45b22-73fc-4f82-9627-d184edd41208'></a>\n\nNEXT METER READING July 9, 2025", type='text'), Chunk(id='85335fae-2ef7-4c9f-911c-dc4293e43b88', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.6203818321228027, left=0.05352377891540527, right=0.4619123339653015, top=0.4459122121334076), page=0), markdown="<a id='85335fae-2ef7-4c9 ...
#   'extraction_result': ExtractResponse(extraction={'provider_info': {'provider': 'PSEG', 'phone_number': '1-800-436-7734', 'website': 'pseg.com/myaccount', 'usage_bar_chart': True}, 'account_info': {'account_holder': 'ARISLEIDY BAEZ NUNEZ', 'account_number': '7491381707', 'service_address': '1146 N 31ST ST CAMDEN CITY NJ 08105-4118', 'service_address_primary': '1146 N 31ST ST', 'service_address_city': 'CAMDEN CITY', 'service_address_state': 'NJ', 'service_address_zip': '08105'}, 'billing_summary': {'due_date': '2025-06-26', 'bill_date': '2025-06-11', 'service_start_date': '05-09-2025', 'service_end_date': '06-09-2025', 'total_amount_due': '$1,467.77'}, 'electric_charges': {'meter_number': None, 'usage_kwh': None, 'total_electric_charges': None}, 'gas_charges': {'meter_number': None, 'usage_therms': None, 'total_gas_charges': None}}, extraction_metadata={'provider_info': {'provider': {'value': 'PSEG', 'references': ['d81276b6-2ab2-4870-aefa-0e0d1e92e2a6']}, 'phone_number': {'value': '1-800-436-7734', 'references': ['85335fae-2ef7-4c9f-911c-dc4293e43b88']}, 'website': {'value': 'pseg.com/myaccount', 'references': ['85335fae-2ef7-4c9f-911c-dc4293e43b88']}, 'usage_bar_chart': {'value': True, 'references': ['05bc726e-6753-4d1b-a308-27f8192e539b']}}, 'account_info': {'account_holder': {'value': 'ARISLEIDY BAEZ NUNEZ', 'references': ['34494d9c-7c74-41f6-9f0c-d8f4e2ab6733']}, 'account_number': {'value': '7491381707', 'references': ['34494d9c-7c74-41f6-9f0c-d8f4e2ab6733']}, 'service_address': {'value': '1146 N 31ST ST CAMDEN CITY NJ 08105-4118', 'references': ['34494d9c-7c74-41f6-9f0c-d8f4e2ab6733']}, 'service_address_primary': {'value': '1146 N 31ST ST', 'references': ['34494d9c-7c74-41f6-9f0c-d8f4e2ab6733']}, 'service_address_city': {'value': 'CAMDEN CITY', 'references': ['34494d9c-7c74-41f6-9f0c-d8f4e2ab6733']}, 'service_address_state': {'value': 'NJ', 'references': ['34494d9c-7c74-41f6-9f0c-d8f4e2ab6733']}, 'service_address_zip': {'value': '08105', 'references': ['34494d9c-7c74-41f6-9f0c-d8f4e2ab6733']}}, 'billing_summary': {'due_date': {'value': '2025-06-26', 'references': ['32b5da15-95d2-4467-8970-428c62930bd3']}, 'bill_date': {'value': '2025-06-11', 'references': ['38c2c2cb-c2ea-4ac2-a12a-cfb2fe663142']}, 'service_start_date': {'value': '05-09-2025', 'references': ['38c2c2cb-c2ea-4ac2-a12a-cfb2fe663142']}, 'service_end_date': {'value': '06-09-2025', 'references': ['38c2c2cb-c2ea-4ac2-a12a-cfb2fe663142']}, 'total_amount_due': {'value': '$1,467.77', 'references': ['32b5da15-95d2-4467-8970-428c62930bd3']}}, 'electric_charges': {'meter_number': {'value': None, 'references': []}, 'usage_kwh': {'value': None, 'references': []}, 'total_electric_charges': {'value': None, 'references': []}}, 'gas_charges': {'meter_number': {'value': None, 'references': []}, 'usage_therms': {'value': None, 'references': []}, 'total_gas_charges': {'value': None, 'references': []}}}, metadata=Metadata(credit_usage=1.6714, duration_ms=20986, filename='upload.md', job_id='e694e83f7b1c49df8254647549efd833', org_id='u3z0u1hn4acl', version='extract-20251024', fallback_model_version=None, schema_violation_error="Extracted data does not completely conform to the requested schema. See below error for details.\nNone is not of type 'string'\n\nFailed validating 'type' in schema['properties']['electric_charges']['properties']['meter_number']:\n    {'type': 'string',\n     'title': 'Electric Meter Number',\n     'description': 'Identifier for the electric meter. Blank if this bill '\n                    'does not inlcude electric service.'}\n\nOn instance['electric_charges']['meter_number']:\n    None\nPlease read our documentation for more information: https://docs.landing.ai/ade/ade-extract-troubleshoot"))},
#  'electric_B': {'parse_result': ParseResponse(chunks=[Chunk(id='5d59ad95-f0f7-495f-beee-dcce54199267', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.025401795282959938, left=0.8139773607254028, right=0.8772212266921997, top=0.013639694079756737), page=0), markdown="<a id='5d59ad95-f0f7-495f-beee-dcce54199267'></a>\n\nPage 1 of 2", type='marginalia'), Chunk(id='044ca166-863f-4083-bd6d-9b9749c49711', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.10929616540670395, left=0.10006590932607651, right=0.33289745450019836, top=0.07568278163671494), page=0), markdown="<a id='044ca166-863f-4083-bd6d-9b9749c49711'></a>\n\nAlabama Power\nCustom\nERIKA", type='text'), Chunk(id='0cb2152c-6cbf-49a3-90f9-efda90d76051', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.10209380835294724, left=0.2952597141265869, right=0.3916469216346741, top=0.07138029485940933), page=0), markdown="<a id='0cb2152c-6cbf-49a3-90f9-efda90d76051'></a>\n\nCustomer Name\nERIKA J ZAPATA", type='marginalia'), Chunk(id='bbcdef9e-1960-425c-ac23-9d4585805b09', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.09374885261058807, left=0.4985082149505615, right=0.592002272605896, top=0.06110765039920807), page=0), markdown="<a id='bbcdef9e-1960-425c-ac23-9d4585805b09'></a>\n\nAccount Number\n96762-33381", type='text'), Chunk(id='4d52e5e5-9fe8-4331-ad3a-0f205ff4d208', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.08368653059005737, left=0.6060515642166138, right=0.89872145652771, top=0.024941686540842056), page=0), markdown='<a id=\'4d52e5e5-9fe8-4331-ad3a-0f205ff4d208\'></a>\n\n<table id="0-1">\n<tr><td id="0-2">Please Pay By</td><td id="0-3">Jul 1, 2024</td></tr>\n<tr><td id="0-4">Total Due</td><td id="0-5">$176.51</td></tr>\n</table>', type='table'), Chunk(id='b89614f1-21dd-4bd4-a9c0-921bb44ab558', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.1540311723947525, left=0.09695074707269669, right=0.2316340208053589, top=0.12600181996822357), page=0), markdown="<a id='b89614f1-21dd-4bd4-a9c0-921bb44ab558'></a>\n\nService Address\n703 RALEIGH CT APT A", type='text'), Chunk(id='fe143fe6-815a-467e-9d1f-3798bffe4e0a', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.1458771973848343, left=0.43040353059768677, right=0.5962339043617249, top=0.1106887012720108), page=0), markdown="<a id='fe143fe6-815a-467e-9d1f-3798bffe4e0a'></a>\n\nService Period\nMay 16, 2024 - June 17, 2024", type='text'), Chunk(id='0ecaac0c-e0be-4afa-8785-5d89d1de14ee', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.23590470850467682, left=0.09601292014122009, right=0.6027888059616089, top=0.16341529786586761), page=0), markdown="<a id='0ecaac0c-e0be-4afa-8785-5d89d1de14ee'></a>\n\n## Billing Summary\n\nPrevious Bill Amount $129.29\nPayment Received On 05/29/24 -129.29\nCurrent Electric Service +176.51\n\nThank You!\n\nTotal Due $176.51", type='text'), Chunk(id='4a66d199-cd34-4861-937f-d08294c4c1e2', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.29051530361175537, left=0.09510871767997742, right=0.43343237042427063, top=0.24115878343582153), page=0), markdown="<a id='4a66d199-cd34-4861-937f-d08294c4c1e2'></a>\n\nElectric service balances unpaid after 07/12/2024 are\nsubject to a late charge of 1.5% of the amount due or $2.00,\nwhichever is greater.", type='text'), Chunk(id='ba539b3e-65c7-406f-9a36-b2790a107b0b', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.5958438515663147, left=0.08968272805213928, right=0.6306895017623901, top=0.48114651441574097), page=0), markdown="<a id='ba539b3e-65c7-406f-9a36-b2790a107b0b'></a>\n\nElectronic Home Energy Reports, or eHERs, help you better understand your home's\nenergy usage. Each month, you will receive an emailed report that compares your\nhome's energy usage over time, provides energy insights based on your usage and\ncharacteristics and shares tips and recommendations designed to help you save\nenergy and money. Enroll now to receive your free monthly report at\nehers.alabamapowerpro ...
#   'extraction_result': ExtractResponse(extraction={'provider_info': {'provider': 'Alabama Power', 'phone_number': '800-245-2244', 'website': 'AlabamaPower.com', 'usage_bar_chart': True}, 'account_info': {'account_holder': 'ERIKA J ZAPATA', 'account_number': '96762-33381', 'service_address': '703 RALEIGH CT APT A BIRMINGHAM AL 35209', 'service_address_primary': '703 RALEIGH CT APT A', 'service_address_city': 'BIRMINGHAM', 'service_address_state': 'AL', 'service_address_zip': '35209'}, 'billing_summary': {'due_date': '2024-07-01', 'bill_date': None, 'service_start_date': '05-16-2024', 'service_end_date': '06-17-2024', 'total_amount_due': '$176.51'}, 'electric_charges': {'meter_number': None, 'usage_kwh': '935', 'total_electric_charges': '$176.51'}, 'gas_charges': {'meter_number': None, 'usage_therms': '0', 'total_gas_charges': '$0.00'}}, extraction_metadata={'provider_info': {'provider': {'value': 'Alabama Power', 'references': ['044ca166-863f-4083-bd6d-9b9749c49711']}, 'phone_number': {'value': '800-245-2244', 'references': ['7acbd63c-f7a4-4a85-9a1c-ad256c951514']}, 'website': {'value': 'AlabamaPower.com', 'references': ['7acbd63c-f7a4-4a85-9a1c-ad256c951514']}, 'usage_bar_chart': {'value': True, 'references': ['f676505e-6d00-41cd-a117-d64123e5039e']}}, 'account_info': {'account_holder': {'value': 'ERIKA J ZAPATA', 'references': ['0cb2152c-6cbf-49a3-90f9-efda90d76051']}, 'account_number': {'value': '96762-33381', 'references': ['bbcdef9e-1960-425c-ac23-9d4585805b09']}, 'service_address': {'value': '703 RALEIGH CT APT A BIRMINGHAM AL 35209', 'references': ['b89614f1-21dd-4bd4-a9c0-921bb44ab558', '1333aa48-fae2-4e82-832e-1ef5d71d783d']}, 'service_address_primary': {'value': '703 RALEIGH CT APT A', 'references': ['b89614f1-21dd-4bd4-a9c0-921bb44ab558', '1333aa48-fae2-4e82-832e-1ef5d71d783d']}, 'service_address_city': {'value': 'BIRMINGHAM', 'references': ['1333aa48-fae2-4e82-832e-1ef5d71d783d']}, 'service_address_state': {'value': 'AL', 'references': ['1333aa48-fae2-4e82-832e-1ef5d71d783d']}, 'service_address_zip': {'value': '35209', 'references': ['1333aa48-fae2-4e82-832e-1ef5d71d783d']}}, 'billing_summary': {'due_date': {'value': '2024-07-01', 'references': ['0-3', '4d52e5e5-9fe8-4331-ad3a-0f205ff4d208']}, 'bill_date': {'value': None, 'references': []}, 'service_start_date': {'value': '05-16-2024', 'references': ['fe143fe6-815a-467e-9d1f-3798bffe4e0a']}, 'service_end_date': {'value': '06-17-2024', 'references': ['fe143fe6-815a-467e-9d1f-3798bffe4e0a']}, 'total_amount_due': {'value': '$176.51', 'references': ['0-5', '4d52e5e5-9fe8-4331-ad3a-0f205ff4d208', '0ecaac0c-e0be-4afa-8785-5d89d1de14ee']}}, 'electric_charges': {'meter_number': {'value': None, 'references': []}, 'usage_kwh': {'value': '935', 'references': ['f676505e-6d00-41cd-a117-d64123e5039e', '0-D', '87bb4ed6-5f9e-4eb3-b82f-3195b7d5476c']}, 'total_electric_charges': {'value': '$176.51', 'references': ['0ecaac0c-e0be-4afa-8785-5d89d1de14ee']}}, 'gas_charges': {'meter_number': {'value': None, 'references': []}, 'usage_therms': {'value': '0', 'references': []}, 'total_gas_charges': {'value': '$0.00', 'references': []}}}, metadata=Metadata(credit_usage=1.9632, duration_ms=13987, filename='upload.md', job_id='255d4c3cf58c470abadeb37b93ddc869', org_id='u3z0u1hn4acl', version='extract-20251024', fallback_model_version=None, schema_violation_error="Extracted data does not completely conform to the requested schema. See below error for details.\nNone is not of type 'string'\n\nFailed validating 'type' in schema['properties']['billing_summary']['properties']['bill_date']:\n    {'type': 'string',\n     'title': 'Bill Date',\n     'description': 'Date the bill was issued, in YYYY-MM-DD format.'}\n\nOn instance['billing_summary']['bill_date']:\n    None\nPlease read our documentation for more information: https://docs.landing.ai/ade/ade-extract-troubleshoot"))},
#  'electric_A': {'parse_result': ParseResponse(chunks=[Chunk(id='b96142e0-360c-47ee-9826-f25a6797943d', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.0866183489561081, left=0.008466199040412903, right=0.19443316757678986, top=0.00622066855430603), page=0), markdown="<a id='b96142e0-360c-47ee-9826-f25a6797943d'></a>\n\n<::logo: Mid-Carolina Electric Cooperative\nMid-Carolina\nELECTRIC COOPERATIVE\nA square logo with a blue top half and green bottom half, featuring three vertical white lines resembling utility poles or towers.::>", type='logo'), Chunk(id='244bf43a-8fdc-4da5-85ef-77bf64c32489', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.06928987801074982, left=0.21957814693450928, right=0.40932220220565796, top=0.028687383979558945), page=0), markdown="<a id='244bf43a-8fdc-4da5-85ef-77bf64c32489'></a>\n\nPO Box 669\nLexington, SC 29071", type='marginalia'), Chunk(id='8924a1cf-f149-41a5-bb6c-78d60e2ca867', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.12420663237571716, left=0.5232272148132324, right=0.9696310758590698, top=0.000874008983373642), page=0), markdown='<a id=\'8924a1cf-f149-41a5-bb6c-78d60e2ca867\'></a>\n\n<table id="0-1">\n<tr><td id="0-2">Account Number: 7700000024 Member: CARL P TERRY</td><td id="0-3" rowspan="2">Amount Due</td></tr>\n<tr><td id="0-4">PREVIOUS BALANCE $168.00</td></tr>\n<tr><td id="0-5">LATE PAYMENT CHARGE $4.00</td><td id="0-6">$393.00</td></tr>\n<tr><td id="0-7">TOTAL PAYMENTS $0.00</td><td id="0-8">Due Date</td></tr>\n<tr><td id="0-9">PAST DUE - DUE IMMEDIATELY $172.00</td><td id="0-a">10/25/22</td></tr>\n<tr><td id="0-b">CURRENT MONTH CHARGES $221.00</td><td id="0-c">(gray rectangle)</td></tr>\n</table>', type='table'), Chunk(id='a7980eac-d250-43b9-a8f0-9b3676e4748a', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.18456898629665375, left=0.05402754247188568, right=0.4595688581466675, top=0.11847545206546783), page=0), markdown="<a id='a7980eac-d250-43b9-a8f0-9b3676e4748a'></a>\n\nOffice Hours: 8 a.m. to 5 p.m. Monday - Friday\nTelephone: (803) 749-6400 Toll-Free: (888) 813-8000\nEasy Pay: (803) 749-6500 or (888) 850-6770\nVisit us online at www.mcecoop.com", type='text'), Chunk(id='ed534d61-1366-4e12-9f20-9b1d56a4c29b', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.22328472137451172, left=0.5250804424285889, right=0.9720995426177979, top=0.12459484487771988), page=0), markdown="<a id='ed534d61-1366-4e12-9f20-9b1d56a4c29b'></a>\n\n## Messages from MCEC\n\n*   **PAST DUE** Our records indicate a Past Due Balance of $172.00 has not been paid. Please remit payment ASAP to avoid interruption of service and additional charges for reconnection.\n*   The Summer On-Peak hours are 4-7 pm through October 31st.", type='text'), Chunk(id='706be5e6-eb94-40eb-aee8-04a94f28bdb3', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.24646347761154175, left=0.03668013960123062, right=0.27047207951545715, top=0.19562938809394836), page=0), markdown="<a id='706be5e6-eb94-40eb-aee8-04a94f28bdb3'></a>\n\n115 1 AV 0.455\nCARL P TERRY\n134 LAND OF LAKES CIR\nLEXINGTON SC 29073-7702", type='text'), Chunk(id='99b53440-5fc1-41cf-be84-1bf577e51c09', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.22547703981399536, left=0.3660748302936554, right=0.4257791340351105, top=0.19756931066513062), page=0), markdown="<a id='99b53440-5fc1-41cf-be84-1bf577e51c09'></a>\n\n5 115\nC-1", type='text'), Chunk(id='9a9d9709-d41d-49c7-83e5-582dea3d792a', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.290543794631958, left=0.04450850188732147, right=0.4016433358192444, top=0.2624337077140808), page=0), markdown="<a id='9a9d9709-d41d-49c7-83e5-582dea3d792a'></a>\n\n<::scan_code: Barcode\n\nThis barcode is composed of black vertical lines of varying widths and heights on a gray background, with no apparent quality issues.:>", type='scan_code'), Chunk(id='310555fb-5ed7-4257-99cc-d8836c92a4aa', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.40932536125183105, left=0.0 ...
#   'extraction_result': ExtractResponse(extraction={'provider_info': {'provider': 'Mid-Carolina Electric Cooperative', 'phone_number': '803-749-6400', 'website': 'www.mcecoop.com', 'usage_bar_chart': None}, 'account_info': {'account_holder': 'CARL P TERRY', 'account_number': '7700000024', 'service_address': '134 LAND OF LAKES CIR LEXINGTON, SC 29073-7702', 'service_address_primary': '134 LAND OF LAKES CIR', 'service_address_city': 'LEXINGTON', 'service_address_state': 'SC', 'service_address_zip': '29073-7702'}, 'billing_summary': {'due_date': '2022-10-25', 'bill_date': '2022-10-05', 'service_start_date': '09-01-2022', 'service_end_date': '10-01-2022', 'total_amount_due': '$393.00'}, 'electric_charges': {'meter_number': '71123288', 'usage_kwh': '1025', 'total_electric_charges': '$221.00'}, 'gas_charges': {'meter_number': None, 'usage_therms': None, 'total_gas_charges': None}}, extraction_metadata={'provider_info': {'provider': {'value': 'Mid-Carolina Electric Cooperative', 'references': ['b96142e0-360c-47ee-9826-f25a6797943d']}, 'phone_number': {'value': '803-749-6400', 'references': ['a7980eac-d250-43b9-a8f0-9b3676e4748a']}, 'website': {'value': 'www.mcecoop.com', 'references': ['a7980eac-d250-43b9-a8f0-9b3676e4748a']}, 'usage_bar_chart': {'value': None, 'references': []}}, 'account_info': {'account_holder': {'value': 'CARL P TERRY', 'references': ['0-2', '706be5e6-eb94-40eb-aee8-04a94f28bdb3', '9c7053ae-b333-4d76-8190-da65a5454e28']}, 'account_number': {'value': '7700000024', 'references': ['0-2', 'dfb4a2a7-7781-4284-a167-b64baaef3c16', '0-M']}, 'service_address': {'value': '134 LAND OF LAKES CIR LEXINGTON, SC 29073-7702', 'references': ['706be5e6-eb94-40eb-aee8-04a94f28bdb3', '9c7053ae-b333-4d76-8190-da65a5454e28']}, 'service_address_primary': {'value': '134 LAND OF LAKES CIR', 'references': ['706be5e6-eb94-40eb-aee8-04a94f28bdb3', '4357c327-99ce-471b-b6f8-a541e35e9533', '9c7053ae-b333-4d76-8190-da65a5454e28']}, 'service_address_city': {'value': 'LEXINGTON', 'references': ['706be5e6-eb94-40eb-aee8-04a94f28bdb3', '9c7053ae-b333-4d76-8190-da65a5454e28']}, 'service_address_state': {'value': 'SC', 'references': ['706be5e6-eb94-40eb-aee8-04a94f28bdb3', '9c7053ae-b333-4d76-8190-da65a5454e28']}, 'service_address_zip': {'value': '29073-7702', 'references': ['706be5e6-eb94-40eb-aee8-04a94f28bdb3']}}, 'billing_summary': {'due_date': {'value': '2022-10-25', 'references': ['0-a', '0-Q']}, 'bill_date': {'value': '2022-10-05', 'references': ['0-s', '9c7053ae-b333-4d76-8190-da65a5454e28']}, 'service_start_date': {'value': '09-01-2022', 'references': ['0-n', '0-s']}, 'service_end_date': {'value': '10-01-2022', 'references': ['0-n', '0-s']}, 'total_amount_due': {'value': '$393.00', 'references': ['0-6', '0-O']}}, 'electric_charges': {'meter_number': {'value': '71123288', 'references': ['0-k']}, 'usage_kwh': {'value': '1025', 'references': ['0-o', '0-x']}, 'total_electric_charges': {'value': '$221.00', 'references': ['0-b', '0-K']}}, 'gas_charges': {'meter_number': {'value': None, 'references': []}, 'usage_therms': {'value': None, 'references': []}, 'total_gas_charges': {'value': None, 'references': []}}}, metadata=Metadata(credit_usage=1.8422, duration_ms=12200, filename='upload.md', job_id='bf16d10a00dd47a695009905923c268a', org_id='u3z0u1hn4acl', version='extract-20251024', fallback_model_version=None, schema_violation_error="Extracted data does not completely conform to the requested schema. See below error for details.\nNone is not of type 'boolean'\n\nFailed validating 'type' in schema['properties']['provider_info']['properties']['usage_bar_chart']:\n    {'type': 'boolean',\n     'description': 'Does the utility bill include a chart depicting usage '\n                    'trends over time?'}\n\nOn instance['provider_info']['usage_bar_chart']:\n    None\nPlease read our documentation for more information: https://docs.landing.ai/ade/ade-extract-troubleshoot"))},
#  'electric2': {'parse_result': ParseResponse(chunks=[Chunk(id='a1e91599-5c0c-40d3-a4b3-205f24b35b84', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.08154604583978653, left=0.06509038805961609, right=0.32531294226646423, top=0.02584625594317913), page=0), markdown="<a id='a1e91599-5c0c-40d3-a4b3-205f24b35b84'></a>\n\n<::logo: PSEG\nPSEG\nWe make things work for you.\nA red circle with white lines radiating from the center, resembling a sun or an abstract gear, next to the company name in black text.::>", type='logo'), Chunk(id='3408b619-83e7-4332-b86e-894c3b174810', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.09081268310546875, left=0.5111335515975952, right=0.9774810075759888, top=0.024810966104269028), page=0), markdown="<a id='3408b619-83e7-4332-b86e-894c3b174810'></a>\n\nTotal amount due: $67.09\nPlease pay by: July 6, 2020", type='text'), Chunk(id='2aa0ce5a-3432-4736-a264-1d9a096b0961', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.16149583458900452, left=0.0635320246219635, right=0.4743800461292267, top=0.10880040377378464), page=0), markdown="<a id='2aa0ce5a-3432-4736-a264-1d9a096b0961'></a>\n\nYour energy bill", type='text'), Chunk(id='1c277f6e-83a4-4172-ab04-d1dacc1a972f', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.1616801768541336, left=0.5096191763877869, right=0.8686372637748718, top=0.12228239327669144), page=0), markdown="<a id='1c277f6e-83a4-4172-ab04-d1dacc1a972f'></a>\n\nBill date: June 19, 2020\nFor the period: May 19, 2020 to June 17, 2020", type='text'), Chunk(id='a5b38363-2d88-4549-88cc-87c2413caf95', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.32851535081863403, left=0.06256496906280518, right=0.4775884747505188, top=0.1697021871805191), page=0), markdown="<a id='a5b38363-2d88-4549-88cc-87c2413caf95'></a>\n\n☑ Message Center\n\nThis bill reflects changes in the Supply and Delivery portions of\nyour bill, effective June 1, 2020. The change in the Supply portion of\nyour bill is a result of the statewide supply auction that was approved\nby the BPU on February 5, 2020. The change in the Delivery portion of\nyour bill is a result of a small decrease to the Non-Utility Generation\nCharge. As a result of these changes, a typical residential customer who\nreceives electric supply from PSE&G and uses 6,920 kilowatt-hours per\nyear will see an average monthly increase of $5.57 or 4.1%. Tariff\ninformation may also be found by visiting pseg.com.", type='text'), Chunk(id='765c7aef-4d79-4fdf-b737-58bf1f65df39', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.3912030756473541, left=0.06381601095199585, right=0.4625553488731384, top=0.3312937915325165), page=0), markdown="<a id='765c7aef-4d79-4fdf-b737-58bf1f65df39'></a>\n\nYour safety is our top priority. Know what to do if you smell gas.\nNatural gas smells like rotten eggs. If you smell gas, leave the area immediately, and call 911 or PSE&G at 800-880-PSEG. Learn more at pseg.com/gassafety.", type='text'), Chunk(id='927846dd-2058-49e4-a69a-1aa0870d565e', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.46834859251976013, left=0.06396134197711945, right=0.31990474462509155, top=0.4414866268634796), page=0), markdown="<a id='927846dd-2058-49e4-a69a-1aa0870d565e'></a>\n\nNEXT METER READING July 17, 2020", type='text'), Chunk(id='7ac5adfe-e743-4215-8b47-307b5ab30e17', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.6692503094673157, left=0.0649729073047638, right=0.47690531611442566, top=0.47347480058670044), page=0), markdown="<a id='7ac5adfe-e743-4215-8b47-307b5ab30e17'></a>\n\n## How to contact us\n\n1-800-436-PSEG (7734)\nCustomer Service: 7am to 8pm Mon-Fri, 7am to 5pm Sat\nEmergencies / Outages / WorryFree Services: 24/7\nTTY for the hearing impaired: 1-800-225-0072\n\nVisit pseg.com/myaccount to access your account anytime\n\nText us. Register for MyAlerts by texting **REG** to 4PSEG(47734)\n> Text **OUT** to report an outage.\n\nfacebook.com/pseg\ntwitter.com/psegdelivers", type='tex ...
#   'extraction_result': ExtractResponse(extraction={'provider_info': {'provider': 'PSEG', 'phone_number': '800-436-7734', 'website': 'pseg.com', 'usage_bar_chart': True}, 'account_info': {'account_holder': 'EDITH AVELLA', 'account_number': '7002365118', 'service_address': '214 KIPP AVE APT C HASBROUCK HEIGHTS NJ 07604-1932', 'service_address_primary': '214 KIPP AVE APT C', 'service_address_city': 'HASBROUCK HEIGHTS', 'service_address_state': 'NJ', 'service_address_zip': '07604'}, 'billing_summary': {'due_date': '2020-07-06', 'bill_date': '2020-06-19', 'service_start_date': '05-19-2020', 'service_end_date': '06-17-2020', 'total_amount_due': '$67.09'}, 'electric_charges': {'meter_number': '127292249', 'usage_kwh': '238', 'total_electric_charges': '$46.42'}, 'gas_charges': {'meter_number': '3113676', 'usage_therms': '17.806', 'total_gas_charges': '$20.67'}}, extraction_metadata={'provider_info': {'provider': {'value': 'PSEG', 'references': ['a1e91599-5c0c-40d3-a4b3-205f24b35b84']}, 'phone_number': {'value': '800-436-7734', 'references': ['7ac5adfe-e743-4215-8b47-307b5ab30e17']}, 'website': {'value': 'pseg.com', 'references': ['7ac5adfe-e743-4215-8b47-307b5ab30e17']}, 'usage_bar_chart': {'value': True, 'references': ['c9f857f1-b671-405a-ad1c-7c2d8c0da78e', 'b15aba09-0b2a-436a-aee3-699b7f3702f6']}}, 'account_info': {'account_holder': {'value': 'EDITH AVELLA', 'references': ['f8837e6b-234e-4c6a-950a-7bec60762401']}, 'account_number': {'value': '7002365118', 'references': ['f8837e6b-234e-4c6a-950a-7bec60762401']}, 'service_address': {'value': '214 KIPP AVE APT C HASBROUCK HEIGHTS NJ 07604-1932', 'references': ['f8837e6b-234e-4c6a-950a-7bec60762401']}, 'service_address_primary': {'value': '214 KIPP AVE APT C', 'references': ['f8837e6b-234e-4c6a-950a-7bec60762401']}, 'service_address_city': {'value': 'HASBROUCK HEIGHTS', 'references': ['f8837e6b-234e-4c6a-950a-7bec60762401']}, 'service_address_state': {'value': 'NJ', 'references': ['f8837e6b-234e-4c6a-950a-7bec60762401']}, 'service_address_zip': {'value': '07604', 'references': ['f8837e6b-234e-4c6a-950a-7bec60762401']}}, 'billing_summary': {'due_date': {'value': '2020-07-06', 'references': ['3408b619-83e7-4332-b86e-894c3b174810']}, 'bill_date': {'value': '2020-06-19', 'references': ['1c277f6e-83a4-4172-ab04-d1dacc1a972f']}, 'service_start_date': {'value': '05-19-2020', 'references': ['1c277f6e-83a4-4172-ab04-d1dacc1a972f']}, 'service_end_date': {'value': '06-17-2020', 'references': ['1c277f6e-83a4-4172-ab04-d1dacc1a972f']}, 'total_amount_due': {'value': '$67.09', 'references': ['3408b619-83e7-4332-b86e-894c3b174810']}}, 'electric_charges': {'meter_number': {'value': '127292249', 'references': ['c659be1f-9fe0-4a53-8927-5a22df303932']}, 'usage_kwh': {'value': '238', 'references': ['c659be1f-9fe0-4a53-8927-5a22df303932']}, 'total_electric_charges': {'value': '$46.42', 'references': ['ed886210-6bdf-441c-9591-5f3d2f98addd', '3-r']}}, 'gas_charges': {'meter_number': {'value': '3113676', 'references': ['238bbaac-96ec-4f42-8f3d-5cb7402eae48', '2-2']}, 'usage_therms': {'value': '17.806', 'references': ['238bbaac-96ec-4f42-8f3d-5cb7402eae48', '2-g']}, 'total_gas_charges': {'value': '$20.67', 'references': ['3933b2e9-aaf3-4be4-a340-fac91c62221a', '2-H']}}}, metadata=Metadata(credit_usage=4.0649999999999995, duration_ms=16637, filename='upload.md', job_id='3a1ce4acfadf44848782a4a8be8092f5', org_id='u3z0u1hn4acl', version='extract-20251024', fallback_model_version=None, schema_violation_error=None))},
#  'electric3': {'parse_result': ParseResponse(chunks=[Chunk(id='dd552f2b-a968-45f9-83ad-acc583f05edd', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.023859739303588867, left=0.8962572813034058, right=0.9661511182785034, top=0.010778900235891342), page=0), markdown="<a id='dd552f2b-a968-45f9-83ad-acc583f05edd'></a>\n\nPage 1 of 2", type='marginalia'), Chunk(id='1448bc3f-e2e5-47d4-bbf8-f2de5d22ead1', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.08426233381032944, left=0.03184845298528671, right=0.24334311485290527, top=0.04662599414587021), page=0), markdown="<a id='1448bc3f-e2e5-47d4-bbf8-f2de5d22ead1'></a>\n\n<::conEdison logo::>", type='figure'), Chunk(id='9ed1ee03-796c-4116-bba4-381da6a256c2', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.10471095144748688, left=0.5111027359962463, right=0.9711217284202576, top=0.02658100053668022), page=0), markdown="<a id='9ed1ee03-796c-4116-bba4-381da6a256c2'></a>\n\n<::logo: N/A\nCurrent balance due\n$44.89\nDirect Pay\n04/07/23\nA rectangular blue box divided into two sections, with white text.::>", type='logo'), Chunk(id='4eb5d041-4e39-46e8-b66b-84e3f1fab7d5', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.16640596091747284, left=0.029276207089424133, right=0.3203607201576233, top=0.13005881011486053), page=0), markdown="<a id='4eb5d041-4e39-46e8-b66b-84e3f1fab7d5'></a>\n\nMITCHELL JOHNSON\nAccount Number: 44-6011-0985-0021-7", type='text'), Chunk(id='58d7c260-b000-42fc-baa4-2186b12f1172', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.4050769507884979, left=0.02578568458557129, right=0.4902293086051941, top=0.16870149970054626), page=0), markdown='<a id=\'58d7c260-b000-42fc-baa4-2186b12f1172\'></a>\n\n<table id="0-1">\n<tr><td id="0-2">Your bill breakdown</td><td id="0-3">$ (dollar sign icon)</td></tr>\n<tr><td id="0-4">Last billing period</td><td id="0-5"></td></tr>\n<tr><td id="0-6">Your billing summary as of Mar 28, 2023</td><td id="0-7"></td></tr>\n<tr><td id="0-8">Your previous charges and payments</td><td id="0-9"></td></tr>\n<tr><td id="0-a">Total charges from your last bill</td><td id="0-b">$46.16</td></tr>\n<tr><td id="0-c">Payments through Mar 24, thank you</td><td id="0-d">-$46.16</td></tr>\n<tr><td id="0-e">Balance from previous bill</td><td id="0-f">None</td></tr>\n<tr><td id="0-g">Your new charges</td><td id="0-h"></td></tr>\n<tr><td id="0-i">Billing period: Feb 24, 2023 to Mar 27, 2023</td><td id="0-j"></td></tr>\n<tr><td id="0-k">Electricity charges - for 31 days</td><td id="0-l">$44.89</td></tr>\n<tr><td id="0-m">Total from this billing period</td><td id="0-n">$44.89</td></tr>\n<tr><td id="0-o">Total amount due</td><td id="0-p">$44.89</td></tr>\n<tr><td id="0-q" colspan="2">Direct Payment Plan - The amount of $44.89 will be automatically deducted from your bank on Apr 7, 2023.</td></tr>\n</table>', type='table'), Chunk(id='2888268d-e66e-4627-9e78-f4c429777438', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.30566707253456116, left=0.5111544132232666, right=0.9751741886138916, top=0.13070884346961975), page=0), markdown="<a id='2888268d-e66e-4627-9e78-f4c429777438'></a>\n\nService delivered to: 435 W 57 STRE 2H\nNext billing date: Tuesday, Apr 25, 2023\nYour average daily electric usage\n<::bar and line chart::>\n2.87 kWh\n\nBar chart (electric usage):\nLeft Y-axis: kWh, with values 0, 3.75, 7.5, 11.25, 15.\nX-axis: Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dec, Jan, Feb, Mar.\nBars (approximate kWh):\nMar: 5\nApr: 5\nMay: 6\nJun: 10\nJul: 12\nAug: 13\nSep: 10\nOct: 3\nNov: 2\nDec: 4\nJan: 3\nFeb: 2\nMar: 3\n\nLine chart (temperature):\nRight Y-axis: temp*, with values 0, 25, 50, 75, 100.\nLine points (approximate temp*):\nMar: 70\nApr: 75\nMay: 85\nJun: 95\nJul: 100\nAug: 95\nSep: 85\nOct: 60\nNov: 50\nDec: 55\nJan: 50\nFeb: 60\nMar: 65\n<::>", type='figure'), Chunk(id='58b09a6f-833b-488b-be20-2f78f09445d5', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.5701218843460083, left=0.030055731534957886, r ...
#   'extraction_result': ExtractResponse(extraction={'provider_info': {'provider': 'conEdison', 'phone_number': '800-752-6633', 'website': 'conEd.com/MyAccount', 'usage_bar_chart': True}, 'account_info': {'account_holder': 'MITCHELL JOHNSON', 'account_number': '44-6011-0985-0021-7', 'service_address': '435 W 57 STRE 2H', 'service_address_primary': '435 W 57 STRE 2H', 'service_address_city': 'NEW YORK', 'service_address_state': 'NY', 'service_address_zip': '10019'}, 'billing_summary': {'due_date': '2023-04-07', 'bill_date': '2023-03-28', 'service_start_date': '02-24-2023', 'service_end_date': '03-27-2023', 'total_amount_due': '$44.89'}, 'electric_charges': {'meter_number': '013641924', 'usage_kwh': '89', 'total_electric_charges': '$44.89'}, 'gas_charges': {'meter_number': None, 'usage_therms': None, 'total_gas_charges': None}}, extraction_metadata={'provider_info': {'provider': {'value': 'conEdison', 'references': ['1448bc3f-e2e5-47d4-bbf8-f2de5d22ead1']}, 'phone_number': {'value': '800-752-6633', 'references': ['758b3d0b-94f8-4c5c-b63b-3956f276e409', '0ec5e95c-b4f2-4b4c-9322-643b90ff4ef0', 'c98a1ed5-684c-4935-ba49-2e274c45a041']}, 'website': {'value': 'conEd.com/MyAccount', 'references': ['5864d2bf-3ba2-497e-9aec-c3fb06d5b43c', '4a5812d4-94d1-4bc3-832f-66322f597d95', 'c514e390-5e0b-44e6-a0f0-e754c31f147d']}, 'usage_bar_chart': {'value': True, 'references': ['2888268d-e66e-4627-9e78-f4c429777438']}}, 'account_info': {'account_holder': {'value': 'MITCHELL JOHNSON', 'references': ['4eb5d041-4e39-46e8-b66b-84e3f1fab7d5', '59103170-bc7b-46e9-b985-128c9864e178', '73098002-fe45-4d55-973b-dd329be76321']}, 'account_number': {'value': '44-6011-0985-0021-7', 'references': ['4eb5d041-4e39-46e8-b66b-84e3f1fab7d5', '3a4b4f15-1d69-4ce3-ab6c-c2b6fe5d1ff5', 'a525aa42-b3b6-4b9b-9bc1-8c82ac6dc85f']}, 'service_address': {'value': '435 W 57 STRE 2H', 'references': ['2888268d-e66e-4627-9e78-f4c429777438']}, 'service_address_primary': {'value': '435 W 57 STRE 2H', 'references': ['2888268d-e66e-4627-9e78-f4c429777438']}, 'service_address_city': {'value': 'NEW YORK', 'references': ['59103170-bc7b-46e9-b985-128c9864e178']}, 'service_address_state': {'value': 'NY', 'references': ['59103170-bc7b-46e9-b985-128c9864e178']}, 'service_address_zip': {'value': '10019', 'references': ['59103170-bc7b-46e9-b985-128c9864e178']}}, 'billing_summary': {'due_date': {'value': '2023-04-07', 'references': ['9ed1ee03-796c-4116-bba4-381da6a256c2', '0-q']}, 'bill_date': {'value': '2023-03-28', 'references': ['0-6']}, 'service_start_date': {'value': '02-24-2023', 'references': ['0-i', '1-5']}, 'service_end_date': {'value': '03-27-2023', 'references': ['0-i', '1-5']}, 'total_amount_due': {'value': '$44.89', 'references': ['9ed1ee03-796c-4116-bba4-381da6a256c2', '0-p', '3a4b4f15-1d69-4ce3-ab6c-c2b6fe5d1ff5', '09503432-2f71-43bb-819b-a33209d59a11']}}, 'electric_charges': {'meter_number': {'value': '013641924', 'references': ['1-g']}, 'usage_kwh': {'value': '89', 'references': ['1-o', '88c7401c-4a93-42f3-af42-ca7f24b22b7a']}, 'total_electric_charges': {'value': '$44.89', 'references': ['1-H']}}, 'gas_charges': {'meter_number': {'value': None, 'references': []}, 'usage_therms': {'value': None, 'references': []}, 'total_gas_charges': {'value': None, 'references': []}}}, metadata=Metadata(credit_usage=2.8866, duration_ms=17173, filename='upload.md', job_id='30ce534257cc4e4ca3ccb72ed3080d58', org_id='u3z0u1hn4acl', version='extract-20251024', fallback_model_version=None, schema_violation_error="Extracted data does not completely conform to the requested schema. See below error for details.\nNone is not of type 'string'\n\nFailed validating 'type' in schema['properties']['gas_charges']['properties']['meter_number']:\n    {'type': 'string',\n     'title': 'Gas Meter Number',\n     'description': 'Identifier for the gas meter. Blank if this bill does '\n                    'not inlcude gas service.'}\n\nOn instance['gas_charges']['meter_number']:\n    None\nPlease read our documentation  ...
#  'electric1': {'parse_result': ParseResponse(chunks=[Chunk(id='adafffa2-2cac-4cd6-b1cd-d5841c3b9819', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.08407563716173172, left=0.042976126074790955, right=0.27973705530166626, top=0.0015134811401367188), page=0), markdown='<a id=\'adafffa2-2cac-4cd6-b1cd-d5841c3b9819\'></a>\n\nNNNN\n<::logo of Mountain View Electric Association, Inc. The logo features a stylized depiction of blue mountains with white caps. Below the mountains, it reads "A Member-Owned Cooperative" in smaller text, followed by "MOUNTAIN VIEW ELECTRIC ASSOCIATION, INC." in large, bold, dark blue letters. Below this, it says "Your Touchstone Energy® Cooperative" with the Touchstone Energy logo (three stylized human figures in red, green, and blue) to the right.\n: logo::>', type='figure'), Chunk(id='c74cf314-497e-4f8f-8f4b-4836b0f0884c', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.07591709494590759, left=0.5305263996124268, right=0.9425454139709473, top=0.019552763551473618), page=0), markdown="<a id='c74cf314-497e-4f8f-8f4b-4836b0f0884c'></a>\n\nLocal. Trusted. Serving You.\nFalcon | Limon | Monument | 1-800-388-9881\nOutage: 1-800-388-9881 Automated Pay-By-Phone: 1-877-999-3415\nWebsite: www.mvea.coop Office Hours: 7 a.m. - 5:30 p.m. M - Th", type='text'), Chunk(id='531aa430-5dd0-4542-a7be-64e6ec50f972', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.21725192666053772, left=0.04564163088798523, right=0.3763396143913269, top=0.08893797546625137), page=0), markdown='<a id=\'531aa430-5dd0-4542-a7be-64e6ec50f972\'></a>\n\nMVEA Monthly Message Board\n\nImportant COVID-19 Update: While keeping the lights on is our priority, serving our co-op members — our friends and neighbors — is equally as important. Stay in the know about MVEA\'s services during Colorado\'s "Safer-At-Home" COVID-19 Executive Order by following us on Facebook or Twitter and visiting www.mvea.coop/covid-19-response.', type='text'), Chunk(id='5b3e2318-ff07-486c-8077-45308b6165eb', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.26847463846206665, left=0.3780117630958557, right=0.6415330767631531, top=0.06819424033164978), page=0), markdown="<a id='5b3e2318-ff07-486c-8077-45308b6165eb'></a>\n\nwebsite. www.\n\n<::AMOUNT DUE\n$170.00\nAUTOMATIC PAYMENT\nWILL DRAFT ON\n05/28/2020\n: figure::>\n\n-", type='figure'), Chunk(id='7ab49125-ed87-4cd7-963d-f4d919b034d1', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.17759579420089722, left=0.6448773145675659, right=0.8815743923187256, top=0.07779702544212341), page=0), markdown="<a id='7ab49125-ed87-4cd7-963d-f4d919b034d1'></a>\n\nMember Name RON A BAUMERT\n\n■ Bill Date: 05/13/2020\n■ Account #: 61358805\n■ Member #: 153933\n■ Meter #: 24071\n\n■ Payment Type Bank Draft", type='text'), Chunk(id='2efdfdd1-4751-4aaf-afe5-a63c15404f0d', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.2203434407711029, left=0.6419908404350281, right=0.9508569836616516, top=0.1852426826953888), page=0), markdown="<a id='2efdfdd1-4751-4aaf-afe5-a63c15404f0d'></a>\n\nThank you for your previous payment of $201.00.\nCharge detail found on the back of this page.", type='text'), Chunk(id='e3293829-c88d-4a35-88cb-38430b472a15', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.44481754302978516, left=0.04116952419281006, right=0.6496471166610718, top=0.22204013168811798), page=0), markdown='<a id=\'e3293829-c88d-4a35-88cb-38430b472a15\'></a>\n\nMonthly Energy Use\n04/06/2020 through 05/04/2020 (28 days)\n<::chart: Bar chart showing "Monthly Use" in Kilowatt Hours (left y-axis) and line graphs showing "Monthly High" and "Monthly Low" temperatures (right y-axis) over months from May 2019 to May 2020. \n\nLeft Y-axis: Kilowatt Hours, ranging from 0 to 1750 in increments of 250.\nRight Y-axis: Temp, ranging from 0 to 75 in increments of 15.\nX-axis: Months, labeled May, Jun, Jul, Aug, Sep, Oct, Nov, Dec for 2019, and Jan, Feb, Mar, Apr, May for 2020.\n\nData Series:\nMonthly Use (bars ...
#   'extraction_result': ExtractResponse(extraction={'provider_info': {'provider': 'MOUNTAIN VIEW ELECTRIC ASSOCIATION, INC.', 'phone_number': '1-800-388-9881', 'website': 'www.mvea.coop', 'usage_bar_chart': True}, 'account_info': {'account_holder': 'RON A BAUMERT', 'account_number': '61358805', 'service_address': '935 FLAMING TREE WAY MONUMENT CO 80132-9306', 'service_address_primary': '935 FLAMING TREE WAY', 'service_address_city': 'MONUMENT', 'service_address_state': 'CO', 'service_address_zip': '80132-9306'}, 'billing_summary': {'due_date': '2020-05-28', 'bill_date': '2020-05-13', 'service_start_date': '04-06-2020', 'service_end_date': '05-04-2020', 'total_amount_due': '$170.00'}, 'electric_charges': {'meter_number': '24071', 'usage_kwh': '1255', 'total_electric_charges': '$170.39'}, 'gas_charges': {'meter_number': None, 'usage_therms': None, 'total_gas_charges': None}}, extraction_metadata={'provider_info': {'provider': {'value': 'MOUNTAIN VIEW ELECTRIC ASSOCIATION, INC.', 'references': ['adafffa2-2cac-4cd6-b1cd-d5841c3b9819']}, 'phone_number': {'value': '1-800-388-9881', 'references': ['c74cf314-497e-4f8f-8f4b-4836b0f0884c']}, 'website': {'value': 'www.mvea.coop', 'references': ['c74cf314-497e-4f8f-8f4b-4836b0f0884c']}, 'usage_bar_chart': {'value': True, 'references': ['e3293829-c88d-4a35-88cb-38430b472a15']}}, 'account_info': {'account_holder': {'value': 'RON A BAUMERT', 'references': ['7ab49125-ed87-4cd7-963d-f4d919b034d1']}, 'account_number': {'value': '61358805', 'references': ['7ab49125-ed87-4cd7-963d-f4d919b034d1']}, 'service_address': {'value': '935 FLAMING TREE WAY MONUMENT CO 80132-9306', 'references': ['dca052f6-16be-4fba-90c9-a7124d429734']}, 'service_address_primary': {'value': '935 FLAMING TREE WAY', 'references': ['e410898c-8583-4866-b989-899b5792de62']}, 'service_address_city': {'value': 'MONUMENT', 'references': ['e410898c-8583-4866-b989-899b5792de62']}, 'service_address_state': {'value': 'CO', 'references': ['e410898c-8583-4866-b989-899b5792de62']}, 'service_address_zip': {'value': '80132-9306', 'references': ['dca052f6-16be-4fba-90c9-a7124d429734']}}, 'billing_summary': {'due_date': {'value': '2020-05-28', 'references': ['5b3e2318-ff07-486c-8077-45308b6165eb']}, 'bill_date': {'value': '2020-05-13', 'references': ['7ab49125-ed87-4cd7-963d-f4d919b034d1']}, 'service_start_date': {'value': '04-06-2020', 'references': ['e3293829-c88d-4a35-88cb-38430b472a15']}, 'service_end_date': {'value': '05-04-2020', 'references': ['e3293829-c88d-4a35-88cb-38430b472a15']}, 'total_amount_due': {'value': '$170.00', 'references': ['5b3e2318-ff07-486c-8077-45308b6165eb']}}, 'electric_charges': {'meter_number': {'value': '24071', 'references': ['7ab49125-ed87-4cd7-963d-f4d919b034d1']}, 'usage_kwh': {'value': '1255', 'references': ['e6c716ea-8f2b-4b69-af45-518ffd649e65']}, 'total_electric_charges': {'value': '$170.39', 'references': ['1-d', '1-f']}}, 'gas_charges': {'meter_number': {'value': None, 'references': []}, 'usage_therms': {'value': None, 'references': []}, 'total_gas_charges': {'value': None, 'references': []}}}, metadata=Metadata(credit_usage=2.6658, duration_ms=18366, filename='upload.md', job_id='6bbee946f0be4b18a63600864c89979e', org_id='u3z0u1hn4acl', version='extract-20251024', fallback_model_version=None, schema_violation_error="Extracted data does not completely conform to the requested schema. See below error for details.\nNone is not of type 'string'\n\nFailed validating 'type' in schema['properties']['gas_charges']['properties']['meter_number']:\n    {'type': 'string',\n     'title': 'Gas Meter Number',\n     'description': 'Identifier for the gas meter. Blank if this bill does '\n                    'not inlcude gas service.'}\n\nOn instance['gas_charges']['meter_number']:\n    None\nPlease read our documentation for more information: https://docs.landing.ai/ade/ade-extract-troubleshoot"))},
# ...
#  'electric5': {'parse_result': ParseResponse(chunks=[Chunk(id='b367e4fe-040f-49c8-aeb0-58bf8ff0a93b', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.06198893487453461, left=0.08838754147291183, right=0.2044043242931366, top=0.0057010650634765625), page=0), markdown='<a id=\'b367e4fe-040f-49c8-aeb0-58bf8ff0a93b\'></a>\n\n<::logo: SDG&E\nSDG&E\nBlack and red text with a red stylized line under "SDG" and an upward-pointing red arrow integrated into the "E"::>', type='logo'), Chunk(id='b7ea4058-b020-426c-85dd-742d76fb1d1c', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.04188346490263939, left=0.3195929527282715, right=0.5853434801101685, top=0.013571123592555523), page=0), markdown="<a id='b7ea4058-b020-426c-85dd-742d76fb1d1c'></a>\n\nACCOUNT NUMBER 7397 873 592 9\nFOR", type='text'), Chunk(id='74e2d321-fe73-4fb2-a016-8fea219b37d0', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.040683433413505554, left=0.6550397872924805, right=0.836509108543396, top=0.007679672911763191), page=0), markdown="<a id='74e2d321-fe73-4fb2-a016-8fea219b37d0'></a>\n\nDATE MAILED Jan 17, 2020\nsdge.com", type='text'), Chunk(id='d6d39262-d889-4790-89fd-4a32b5cc72f9', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.09420199692249298, left=0.32300955057144165, right=0.502007782459259, top=0.04881314933300018), page=0), markdown="<a id='d6d39262-d889-4790-89fd-4a32b5cc72f9'></a>\n\nDAINETTE R. WOODS\n568 S 36TH ST\nSAN DIEGO CA 92113", type='text'), Chunk(id='03223da9-b44b-4a72-89ba-fa8354efc995', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.09668746590614319, left=0.6448106169700623, right=0.8863573670387268, top=0.059991855174303055), page=0), markdown="<a id='03223da9-b44b-4a72-89ba-fa8354efc995'></a>\n\nSign up to go Paperless today.\nVisit sdge com/go paperless-today.", type='text'), Chunk(id='4a7308f1-835a-4e6e-9f42-5ea1778b50ba', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.10280529409646988, left=0.025957509875297546, right=0.2699221968650818, top=0.060893572866916656), page=0), markdown="<a id='4a7308f1-835a-4e6e-9f42-5ea1778b50ba'></a>\n\n<::logo: Sempra Energy\nA Sempra Energy utility\nRed stylized figure with an arc, resembling a flame, next to the text in blue.::>", type='logo'), Chunk(id='4bfe6969-8ffc-4471-ad3c-66b6e799a0e8', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.16456468403339386, left=0.01577278971672058, right=0.6150346994400024, top=0.12889479100704193), page=0), markdown="<a id='4bfe6969-8ffc-4471-ad3c-66b6e799a0e8'></a>\n\nHot weather can lead to higher energy bills. To get a more predictable bill each\nmonth, sign up for Level Pay at sdge.com/levelpay.", type='text'), Chunk(id='5b2ac3b4-aac7-4649-932d-ace17e130c7c', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.2170892208814621, left=0.01577785611152649, right=0.5973809957504272, top=0.16711480915546417), page=0), markdown="<a id='5b2ac3b4-aac7-4649-932d-ace17e130c7c'></a>\n\n✔ Bill Discount: You can save 30% or more on your monthly energy bill. Eligibility is based on participation in certain public assistance programs or current household income and the number of people living in your home. To apply, call 1-877-646-5525 or visit sdge.com/CARE.", type='text'), Chunk(id='a6ffcd96-7021-486c-a948-6f00d06a0023', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.27010029554367065, left=0.015726923942565918, right=0.6320852041244507, top=0.2199583351612091), page=0), markdown="<a id='a6ffcd96-7021-486c-a948-6f00d06a0023'></a>\n\n**Descuento en la factura:** Puede ahorrar 30% o más en su factura mensual de energía. Los requisitos del programa se basan en la participación en ciertos programas de asistencia pública, o el ingreso anual y el número de personas que viven en el hogar. Para aplicar, llame al 1-877-646-5525 o visite sdge.com/CARE.", type='text'), Chunk(id='61e88852-fc1b-497f-9ef6-5360ee7d2cf1', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.3236502408981323, left=0.015238314867019653, ...
#   'extraction_result': ExtractResponse(extraction={'provider_info': {'provider': 'SDG&E', 'phone_number': '1-877-646-5525', 'website': 'sdge.com', 'usage_bar_chart': True}, 'account_info': {'account_holder': 'DAINETTE R. WOODS', 'account_number': '7397 873 592 9', 'service_address': '568 S 36TH ST SAN DIEGO CA 92113', 'service_address_primary': '568 S 36TH ST', 'service_address_city': 'SAN DIEGO', 'service_address_state': 'CA', 'service_address_zip': '92113'}, 'billing_summary': {'due_date': '2020-01-25', 'bill_date': '2020-01-17', 'service_start_date': '12-14-2020', 'service_end_date': '01-13-2020', 'total_amount_due': '$22.45'}, 'electric_charges': {'meter_number': None, 'usage_kwh': '143 kWh', 'total_electric_charges': '8.47'}, 'gas_charges': {'meter_number': None, 'usage_therms': '8 Therms', 'total_gas_charges': '13.98'}}, extraction_metadata={'provider_info': {'provider': {'value': 'SDG&E', 'references': ['b367e4fe-040f-49c8-aeb0-58bf8ff0a93b']}, 'phone_number': {'value': '1-877-646-5525', 'references': ['5b2ac3b4-aac7-4649-932d-ace17e130c7c', 'a6ffcd96-7021-486c-a948-6f00d06a0023']}, 'website': {'value': 'sdge.com', 'references': ['74e2d321-fe73-4fb2-a016-8fea219b37d0', '4bfe6969-8ffc-4471-ad3c-66b6e799a0e8', '5b2ac3b4-aac7-4649-932d-ace17e130c7c', 'a6ffcd96-7021-486c-a948-6f00d06a0023', '96b9e32a-59a2-4708-955a-2686fcb73474']}, 'usage_bar_chart': {'value': True, 'references': ['c8281c37-ea44-47e1-9c2d-0b6ed3af05cb', 'c74a9a67-60d8-4fec-bedf-01081446456d']}}, 'account_info': {'account_holder': {'value': 'DAINETTE R. WOODS', 'references': ['d6d39262-d889-4790-89fd-4a32b5cc72f9', '455bec3b-e29b-4578-a760-347471adf7bb']}, 'account_number': {'value': '7397 873 592 9', 'references': ['b7ea4058-b020-426c-85dd-742d76fb1d1c', 'c964ba7c-0f07-4be4-8a96-95a815d77a10']}, 'service_address': {'value': '568 S 36TH ST SAN DIEGO CA 92113', 'references': ['3fc5235b-af16-452c-932e-6ad4f0c67041']}, 'service_address_primary': {'value': '568 S 36TH ST', 'references': ['3fc5235b-af16-452c-932e-6ad4f0c67041']}, 'service_address_city': {'value': 'SAN DIEGO', 'references': ['3fc5235b-af16-452c-932e-6ad4f0c67041']}, 'service_address_state': {'value': 'CA', 'references': ['3fc5235b-af16-452c-932e-6ad4f0c67041']}, 'service_address_zip': {'value': '92113', 'references': ['3fc5235b-af16-452c-932e-6ad4f0c67041']}}, 'billing_summary': {'due_date': {'value': '2020-01-25', 'references': ['85cbb661-6aae-4359-9b9f-f97d92a10bf9', 'd33041ef-9a29-4a4d-b788-3cd1c6d01a84']}, 'bill_date': {'value': '2020-01-17', 'references': ['74e2d321-fe73-4fb2-a016-8fea219b37d0']}, 'service_start_date': {'value': '12-14-2020', 'references': ['0-q', '0-u']}, 'service_end_date': {'value': '01-13-2020', 'references': ['0-q', '0-u']}, 'total_amount_due': {'value': '$22.45', 'references': ['0-j', '85cbb661-6aae-4359-9b9f-f97d92a10bf9', 'd33041ef-9a29-4a4d-b788-3cd1c6d01a84']}}, 'electric_charges': {'meter_number': {'value': None, 'references': []}, 'usage_kwh': {'value': '143 kWh', 'references': ['0-v']}, 'total_electric_charges': {'value': '8.47', 'references': ['0-w']}}, 'gas_charges': {'meter_number': {'value': None, 'references': []}, 'usage_therms': {'value': '8 Therms', 'references': ['0-r']}, 'total_gas_charges': {'value': '13.98', 'references': ['0-s']}}}, metadata=Metadata(credit_usage=2.198, duration_ms=16424, filename='upload.md', job_id='eb1a4b4d011c42b39d6eba9295af5a06', org_id='u3z0u1hn4acl', version='extract-20251024', fallback_model_version=None, schema_violation_error="Extracted data does not completely conform to the requested schema. See below error for details.\nNone is not of type 'string'\n\nFailed validating 'type' in schema['properties']['electric_charges']['properties']['meter_number']:\n    {'type': 'string',\n     'title': 'Electric Meter Number',\n     'description': 'Identifier for the electric meter. Blank if this bill '\n                    'does not inlcude electric service.'}\n\nOn instance['electric_charges']['meter_number']:\n    None\nPlease read ...
#  'electric6': {'parse_result': ParseResponse(chunks=[Chunk(id='58a75335-1fe3-4050-b49c-1ae113887fdc', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.02038857340812683, left=0.8993270397186279, right=0.9695776700973511, top=0.0063499887473881245), page=0), markdown="<a id='58a75335-1fe3-4050-b49c-1ae113887fdc'></a>\n\nPage 1 of2", type='marginalia'), Chunk(id='b3a03410-109c-4762-864d-8a6ae717af29', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.09191612154245377, left=0.07299397140741348, right=0.28804612159729004, top=0.06054220348596573), page=0), markdown="<a id='b3a03410-109c-4762-864d-8a6ae717af29'></a>\n\n<::logo: Mississippi Power\nMississippi Power\nA stylized, colorful triangular symbol with shades of red, blue, and green, resembling a 3D arrow or folded paper shape.::>", type='logo'), Chunk(id='69d1d3a4-b7b9-451d-817c-58eacbf0b274', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.09265308082103729, left=0.2969151735305786, right=0.4371602535247803, top=0.05764295533299446), page=0), markdown="<a id='69d1d3a4-b7b9-451d-817c-58eacbf0b274'></a>\n\nCustomer Name\nWILLIAM A VALENCIA", type='text'), Chunk(id='241c9eee-4700-44ed-bd7f-9e7d4ee65524', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.09283119440078735, left=0.5329606533050537, right=0.6329213380813599, top=0.05763806402683258), page=0), markdown="<a id='241c9eee-4700-44ed-bd7f-9e7d4ee65524'></a>\n\nAccount Number\n09931-83323", type='text'), Chunk(id='63d6310c-4700-4638-a5f9-efd3ea6fc5ee', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.09113442897796631, left=0.6516264081001282, right=0.9745411276817322, top=0.021407920867204666), page=0), markdown='<a id=\'63d6310c-4700-4638-a5f9-efd3ea6fc5ee\'></a>\n\n<table id="0-1">\n<tr><td id="0-2">Delinquent After</td><td id="0-3">Nov 5, 2018</td></tr>\n<tr><td id="0-4">Total Due</td><td id="0-5">$ 86.72</td></tr>\n</table>', type='table'), Chunk(id='3a5c6f00-1fc2-4d63-9de5-f6dcd779fb72', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.15341146290302277, left=0.07309421896934509, right=0.22683992981910706, top=0.120310939848423), page=0), markdown="<a id='3a5c6f00-1fc2-4d63-9de5-f6dcd779fb72'></a>\n\nService Address\n2501 W 7TH ST APT 224", type='text'), Chunk(id='c3c2b5c5-b595-41dd-b001-d077fe9741f6', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.15493424236774445, left=0.4560436010360718, right=0.6329569816589355, top=0.12059874087572098), page=0), markdown="<a id='c3c2b5c5-b595-41dd-b001-d077fe9741f6'></a>\n\nService Period\nSept 24, 2018 - Oct 22, 2018", type='text'), Chunk(id='692e6b8e-3838-4ce7-b5ac-60db3d906327', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.29437148571014404, left=0.07277008891105652, right=0.6331655979156494, top=0.16993898153305054), page=0), markdown="<a id='692e6b8e-3838-4ce7-b5ac-60db3d906327'></a>\n\n**Important Payment Notice**\n\nBecause we value your business, we want to minimize the possibility of a service interruption.\nWe appreciate you paying your bill promptly. If you cannot pay this bill by November 5, 2018,\nplease call us at 1-800-532-1502. If payment is not received by the due date, you may be\nrequired to pay a deposit. Additionally, your service could be disconnected, in which case you\nwill be charged a reconnection fee to restore service. If you have any questions about this bill,\nplease contact us before your payment is due. Thank you for allowing us to serve you.", type='text'), Chunk(id='ef1f68e0-916f-481c-be2a-3b8f0796ef53', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.4103023111820221, left=0.07275334000587463, right=0.6323707103729248, top=0.2994724214076996), page=0), markdown='<a id=\'ef1f68e0-916f-481c-be2a-3b8f0796ef53\'></a>\n\n<table id="0-6">\n<tr><td id="0-7">Billing Summary</td><td id="0-8"></td><td id="0-9"></td><td id="0-a"></td></tr>\n<tr><td id="0-b">Previous Bill Amount</td><td id="0-c"></td><td id="0-d"></td><td id="0-e">$ 99.77</td></tr>\n<tr><td id="0-f">Payment Received  ...
#   'extraction_result': ExtractResponse(extraction={'provider_info': {'provider': 'Mississippi Power', 'phone_number': '1-800-532-1502', 'website': 'mississippipower.com', 'usage_bar_chart': True}, 'account_info': {'account_holder': 'WILLIAM A VALENCIA', 'account_number': '09931-83323', 'service_address': '2501 W 7TH ST APT 224 HATTIESBURG MS 39401', 'service_address_primary': '2501 W 7TH ST APT 224', 'service_address_city': 'HATTIESBURG', 'service_address_state': 'MS', 'service_address_zip': '39401'}, 'billing_summary': {'due_date': '2018-11-05', 'bill_date': None, 'service_start_date': '09-24-2018', 'service_end_date': '10-22-2018', 'total_amount_due': '$ 86.72'}, 'electric_charges': {'meter_number': '173691', 'usage_kwh': '539', 'total_electric_charges': '$86.72'}, 'gas_charges': {'meter_number': None, 'usage_therms': None, 'total_gas_charges': None}}, extraction_metadata={'provider_info': {'provider': {'value': 'Mississippi Power', 'references': ['b3a03410-109c-4762-864d-8a6ae717af29']}, 'phone_number': {'value': '1-800-532-1502', 'references': ['3f57de1d-3e76-4e13-848c-a6277c7e480f']}, 'website': {'value': 'mississippipower.com', 'references': ['3f57de1d-3e76-4e13-848c-a6277c7e480f']}, 'usage_bar_chart': {'value': True, 'references': ['882eed53-adac-4d5c-be0e-5fa3ee214ed2']}}, 'account_info': {'account_holder': {'value': 'WILLIAM A VALENCIA', 'references': ['69d1d3a4-b7b9-451d-817c-58eacbf0b274']}, 'account_number': {'value': '09931-83323', 'references': ['241c9eee-4700-44ed-bd7f-9e7d4ee65524']}, 'service_address': {'value': '2501 W 7TH ST APT 224 HATTIESBURG MS 39401', 'references': ['3a5c6f00-1fc2-4d63-9de5-f6dcd779fb72', '8d79fd3b-66a0-44af-a74c-6521817b6e92']}, 'service_address_primary': {'value': '2501 W 7TH ST APT 224', 'references': ['3a5c6f00-1fc2-4d63-9de5-f6dcd779fb72']}, 'service_address_city': {'value': 'HATTIESBURG', 'references': ['8d79fd3b-66a0-44af-a74c-6521817b6e92']}, 'service_address_state': {'value': 'MS', 'references': ['8d79fd3b-66a0-44af-a74c-6521817b6e92']}, 'service_address_zip': {'value': '39401', 'references': ['8d79fd3b-66a0-44af-a74c-6521817b6e92']}}, 'billing_summary': {'due_date': {'value': '2018-11-05', 'references': ['0-3']}, 'bill_date': {'value': None, 'references': []}, 'service_start_date': {'value': '09-24-2018', 'references': ['c3c2b5c5-b595-41dd-b001-d077fe9741f6']}, 'service_end_date': {'value': '10-22-2018', 'references': ['c3c2b5c5-b595-41dd-b001-d077fe9741f6']}, 'total_amount_due': {'value': '$ 86.72', 'references': ['0-5']}}, 'electric_charges': {'meter_number': {'value': '173691', 'references': ['1-j']}, 'usage_kwh': {'value': '539', 'references': ['1-p']}, 'total_electric_charges': {'value': '$86.72', 'references': ['55fb8094-af35-4a03-8805-6e73ff5d8916']}}, 'gas_charges': {'meter_number': {'value': None, 'references': []}, 'usage_therms': {'value': None, 'references': []}, 'total_gas_charges': {'value': None, 'references': []}}}, metadata=Metadata(credit_usage=2.9086, duration_ms=10787, filename='upload.md', job_id='4439f5edd22147cab6c24970b0a27161', org_id='u3z0u1hn4acl', version='extract-20251024', fallback_model_version=None, schema_violation_error="Extracted data does not completely conform to the requested schema. See below error for details.\nNone is not of type 'string'\n\nFailed validating 'type' in schema['properties']['billing_summary']['properties']['bill_date']:\n    {'type': 'string',\n     'title': 'Bill Date',\n     'description': 'Date the bill was issued, in YYYY-MM-DD format.'}\n\nOn instance['billing_summary']['bill_date']:\n    None\nPlease read our documentation for more information: https://docs.landing.ai/ade/ade-extract-troubleshoot"))}}

# %% [markdown]
# ## 📊 Define Helper Functions
#
# Helper functions to flatten nested dictionaries and create a summary DataFrame from extraction results.

# %%
# Define helper functions that flattens arbitrarily nested dicts and lists into flat, DataFrame-friendly key/value pairs.

import pandas as pd
from typing import Any, Dict, List, Tuple

def flatten_dict(
    data: Dict[str, Any],
    parent_key: str = "",
    sep: str = "_"
) -> Dict[str, Any]:
    items = {}
    for k, v in data.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k

        if isinstance(v, dict):
            items.update(flatten_dict(v, new_key, sep))
        elif isinstance(v, list):
            items[new_key] = str(v)  # lists → string for DataFrame safety
        else:
            items[new_key] = v

    return items


def flatten_metadata(
    metadata: Dict[str, Any],
    parent_key: str = "",
    sep: str = "_"
) -> Dict[str, Any]:
    """Flatten nested metadata and extract chunk references."""
    items = {}
    
    for k, v in metadata.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        
        if isinstance(v, dict):
            # Check if this is a leaf node with 'value' and 'references'
            if 'references' in v:
                items[f"{new_key}_chunks"] = str(v['references'])
            else:
                # Recurse into nested metadata
                items.update(flatten_metadata(v, new_key, sep))
        elif isinstance(v, list):
            items[f"{new_key}_chunks"] = str(v)
        else:
            items[f"{new_key}_chunks"] = str(v)
    
    return items


def create_summary_dataframe(
    extraction_results: List[Tuple[Any, Any, str]]
) -> pd.DataFrame:
    records = []

    for _, extract_result, doc_name in extraction_results:
        extraction = extract_result.extraction or {}
        metadata = extract_result.extraction_metadata or {}

        # Flatten extraction fields
        flat_extraction = flatten_dict(extraction)
        
        # Flatten metadata to get chunk references
        flat_metadata = flatten_metadata(metadata)

        record = {
            "document_name": doc_name,
            **flat_extraction,
            **flat_metadata
        }

        records.append(record)

    return pd.DataFrame(records)

# %% [markdown]
# ## 💾 Convert to Table and Save
#
# Convert the field extractions to a pandas dataframe. Save it to the results folder created earlier.

# %%
print("\n📊 Creating summary DataFrame...")

# Convert results dictionary to the format expected by create_summary_dataframe
extraction_results = [
    (result["parse_result"], result["extraction_result"], doc_name)
    for doc_name, result in results.items()
]

df = create_summary_dataframe(extraction_results)

df
# Out:
# 📊 Creating summary DataFrame...
#   document_name                    provider_info_provider  \
# 0    electric_C                                      PSEG
# 1    electric_B                             Alabama Power
# 2    electric_A         Mid-Carolina Electric Cooperative
# 3     electric2                                      PSEG
# 4     electric3                                 conEdison
# 5     electric1  MOUNTAIN VIEW ELECTRIC ASSOCIATION, INC.
# 6     electric4                               Duke Energy
# 7     electric5                                     SDG&E
# 8     electric6                         Mississippi Power
#
#   provider_info_phone_number provider_info_website  \
# 0             1-800-436-7734    pseg.com/myaccount
# 1               800-245-2244      AlabamaPower.com
# 2               803-749-6400       www.mcecoop.com
# 3               800-436-7734              pseg.com
# 4               800-752-6633   conEd.com/MyAccount
# 5             1-800-388-9881         www.mvea.coop
# 6               800-700-8744       duke-energy.com
# 7             1-877-646-5525              sdge.com
# 8             1-800-532-1502  mississippipower.com
#
#   provider_info_usage_bar_chart account_info_account_holder  \
# 0                          True        ARISLEIDY BAEZ NUNEZ
# 1                          True              ERIKA J ZAPATA
# 2                          None                CARL P TERRY
# 3                          True                EDITH AVELLA
# 4                          True            MITCHELL JOHNSON
# 5                          True               RON A BAUMERT
# 6                         False               KAREN G PEREZ
# 7                          True           DAINETTE R. WOODS
# 8                          True          WILLIAM A VALENCIA
#
#   account_info_account_number  \
# 0                  7491381707
# 1                 96762-33381
# 2                  7700000024
# 3                  7002365118
# 4         44-6011-0985-0021-7
# 5                    61358805
# 6              9100 7883 2561
# 7              7397 873 592 9
# 8                 09931-83323
#
#                         account_info_service_address  \
# 0           1146 N 31ST ST CAMDEN CITY NJ 08105-4118
# 1           703 RALEIGH CT APT A BIRMINGHAM AL 35209
# 2     134 LAND OF LAKES CIR LEXINGTON, SC 29073-7702
# 3  214 KIPP AVE APT C HASBROUCK HEIGHTS NJ 07604-...
# 4                                   435 W 57 STRE 2H
# 5        935 FLAMING TREE WAY MONUMENT CO 80132-9306
# 6      13619 TORTONA LN APT 3121 WINDERMERE FL 34786
# 7                   568 S 36TH ST SAN DIEGO CA 92113
# 8         2501 W 7TH ST APT 224 HATTIESBURG MS 39401
#
#   account_info_service_address_primary account_info_service_address_city  ...  \
# 0                       1146 N 31ST ST                       CAMDEN CITY  ...
# 1                 703 RALEIGH CT APT A                        BIRMINGHAM  ...
# 2                134 LAND OF LAKES CIR                         LEXINGTON  ...
# 3                   214 KIPP AVE APT C                 HASBROUCK HEIGHTS  ...
# 4                     435 W 57 STRE 2H                          NEW YORK  ...
# 5                 935 FLAMING TREE WAY                          MONUMENT  ...
# 6            13619 TORTONA LN APT 3121                        WINDERMERE  ...
# 7                        568 S 36TH ST                         SAN DIEGO  ...
# 8                2501 W 7TH ST APT 224                       HATTIESBURG  ...
#
#                   billing_summary_bill_date_chunks  \
# 0         ['38c2c2cb-c2ea-4ac2-a12a-cfb2fe663142']
# 1                                               []
# 2  ['0-s', '9c7053ae-b333-4d76-8190-da65a5454e28']
# 3         ['1c277f6e-83a4-4172-ab04-d1dacc1a972f']
# 4                                          ['0-6']
# 5         ['7ab49125-ed87-4cd7-963d-f4d919b034d1']
# 6         ['2eb96aa1-51cc-44b6-878a-b8379f534a89']
# 7         ['74e2d321-fe73-4fb2-a016-8fea219b37d0']
# 8                                               []
#
#   billing_summary_service_start_date_chunks  \
# 0  ['38c2c2cb-c2ea-4ac2-a12a-cfb2fe663142']
# 1  ['fe143fe6-815a-467e-9d1f-3798bffe4e0a']
# 2                            ['0-n', '0-s']
# 3  ['1c277f6e-83a4-4172-ab04-d1dacc1a972f']
# 4                            ['0-i', '1-5']
# 5  ['e3293829-c88d-4a35-88cb-38430b472a15']
# 6  ['2eb96aa1-51cc-44b6-878a-b8379f534a89']
# 7                            ['0-q', '0-u']
# 8  ['c3c2b5c5-b595-41dd-b001-d077fe9741f6']
#
#     billing_summary_service_end_date_chunks  \
# 0  ['38c2c2cb-c2ea-4ac2-a12a-cfb2fe663142']
# 1  ['fe143fe6-815a-467e-9d1f-3798bffe4e0a']
# 2                            ['0-n', '0-s']
# 3  ['1c277f6e-83a4-4172-ab04-d1dacc1a972f']
# 4                            ['0-i', '1-5']
# 5  ['e3293829-c88d-4a35-88cb-38430b472a15']
# 6  ['2eb96aa1-51cc-44b6-878a-b8379f534a89']
# 7                            ['0-q', '0-u']
# 8  ['c3c2b5c5-b595-41dd-b001-d077fe9741f6']
#
#              billing_summary_total_amount_due_chunks  \
# 0           ['32b5da15-95d2-4467-8970-428c62930bd3']
# 1  ['0-5', '4d52e5e5-9fe8-4331-ad3a-0f205ff4d208'...
# 2                                     ['0-6', '0-O']
# 3           ['3408b619-83e7-4332-b86e-894c3b174810']
# 4  ['9ed1ee03-796c-4116-bba4-381da6a256c2', '0-p'...
# 5           ['5b3e2318-ff07-486c-8077-45308b6165eb']
# 6                                            ['0-b']
# 7  ['0-j', '85cbb661-6aae-4359-9b9f-f97d92a10bf9'...
# 8                                            ['0-5']
#
#        electric_charges_meter_number_chunks  \
# 0                                        []
# 1                                        []
# 2                                   ['0-k']
# 3  ['c659be1f-9fe0-4a53-8927-5a22df303932']
# 4                                   ['1-g']
# 5  ['7ab49125-ed87-4cd7-963d-f4d919b034d1']
# 6                                   ['2-2']
# 7                                        []
# 8                                   ['1-j']
#
#                    electric_charges_usage_kwh_chunks  \
# 0                                                 []
# 1  ['f676505e-6d00-41cd-a117-d64123e5039e', '0-D'...
# 2                                     ['0-o', '0-x']
# 3           ['c659be1f-9fe0-4a53-8927-5a22df303932']
# 4    ['1-o', '88c7401c-4a93-42f3-af42-ca7f24b22b7a']
# 5           ['e6c716ea-8f2b-4b69-af45-518ffd649e65']
# 6                                            ['2-8']
# 7                                            ['0-v']
# 8                                            ['1-p']
#
#     electric_charges_total_electric_charges_chunks  \
# 0                                               []
# 1         ['0ecaac0c-e0be-4afa-8785-5d89d1de14ee']
# 2                                   ['0-b', '0-K']
# 3  ['ed886210-6bdf-441c-9591-5f3d2f98addd', '3-r']
# 4                                          ['1-H']
# 5                                   ['1-d', '1-f']
# 6                                          ['0-7']
# 7                                          ['0-w']
# 8         ['55fb8094-af35-4a03-8805-6e73ff5d8916']
#
#                    gas_charges_meter_number_chunks  \
# 0                                               []
# 1                                               []
# 2                                               []
# 3  ['238bbaac-96ec-4f42-8f3d-5cb7402eae48', '2-2']
# 4                                               []
# 5                                               []
# 6                                               []
# 7                                               []
# 8                                               []
#
#                    gas_charges_usage_therms_chunks  \
# 0                                               []
# 1                                               []
# 2                                               []
# 3  ['238bbaac-96ec-4f42-8f3d-5cb7402eae48', '2-g']
# 4                                               []
# 5                                               []
# 6                                               []
# 7                                          ['0-r']
# 8                                               []
#
#               gas_charges_total_gas_charges_chunks
# 0                                               []
# 1                                               []
# 2                                               []
# 3  ['3933b2e9-aaf3-4be4-a340-fac91c62221a', '2-H']
# 4                                               []
# 5                                               []
# 6                                               []
# 7                                          ['0-s']
# 8                                               []
#
# [9 rows x 45 columns]

# %%
# Save the DataFrame to a CSV file inside the results_folder
csv_path = results_folder / "utility_output.csv"
df.to_csv(csv_path, index=False)

# %% [markdown]
# ## ✅ Wrap-Up
#
# You’ve now used LandingAI’s ADE to:
# - Define custom extrcation fields using a JSON schema
# - Parse and extract data from images and PDFs
# - Export structured results to a table
#
# To learn more, visit the [LandingAI Documentation](https://docs.landing.ai/ade/ade-overview).
