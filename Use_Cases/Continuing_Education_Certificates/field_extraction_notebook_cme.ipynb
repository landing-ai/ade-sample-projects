# %% [markdown]
# # 🧠 Agentic Document Extraction with LandingAI
#
# This notebook demonstrates how to use the `landingai-ade` Python package to extract structured information from documents using LandingAI's Agentic Document Extraction (ADE) service.
#
# We'll walk through:
# - Parsing documents with ADE
# - Defining a custom schema using `pydantic`
# - Viewing structured field extractions
# - Saving results to CSV

# %% [markdown]
# ## 📦 Setup & Imports
#
# Import necessary packages and utility functions. Ensure you have installed the required dependencies:
#
# ```bash
# pip install landingai-ade python-dotenv pandas
# ```
#
# Obtain your API Key from the Visual Playground at https://va.landing.ai/settings/api-key
#
# Read about options for setting your API at https://docs.landing.ai/ade/ade-python
#
# This notebook uses a `.env` file in the same directory to store the API key.

# %%
# Standard libraries
import os
import json
from datetime import date
from pathlib import Path
from dotenv import load_dotenv

# Agentic Document Extraction from LandingAI
from landingai_ade import LandingAIADE
from landingai_ade.lib import pydantic_to_json_schema

# Print library version
import landingai_ade
print(f"📦 landingai-ade version: {landingai_ade.__version__}")
# Out:
# 📦 landingai-ade version: 1.4.0

# %%
# Initialize the ADE client (uses VISION_AGENT_API_KEY environment variable)
# See options at https://docs.landing.ai/ade/agentic-api-key

# Load environment variables from .env file
load_dotenv()

# Initialize the client (it will automatically use VISION_AGENT_API_KEY from environment)
client = LandingAIADE()
print("✅ Authenticated client initialized")
# Out:
# ✅ Authenticated client initialized

# %% [markdown]
# ## 📁 Define Input and Output Directories
#
# Specify where your documents are located and where results will be saved.

# %%
# Define input and output directory paths
base_dir = Path(os.getcwd())
input_folder = base_dir / "input_folder"
results_folder = base_dir / "results_folder"

# Create output folders if they don't exist
input_folder.mkdir(parents=True, exist_ok=True)
results_folder.mkdir(parents=True, exist_ok=True)

# %%
# Collect all files to be processed
# Check official documentation for all supported filetypes https://docs.landing.ai/ade/ade-file-types

file_paths = [
    p for p in input_folder.iterdir()
    if p.suffix.lower() in [".pdf", ".png", ".jpg", ".jpeg", ".doc", ".docx", ".odt", ".ppt", ".pptx", ".odp"]
]

print(f"📄 Found {len(file_paths)} documents to process")
for i, path in enumerate(file_paths[:10], 1):
    print(f"  {i}. {path.name}")
# Out:
# 📄 Found 5 documents to process
#   1. CME_Mendez_ex5.png
#   2. CME_Mendez_ex4.png
#   3. CME_Mendez_ex1.png
#   4. CME_Mendez_ex3.png
#   5. CME_Mendez_ex2.png

# %% [markdown]
# ## 📑 Define Custom Schema for Field Extraction
#
# Using `pydantic`, we define a schema to extract specific fields (e.g., recipient name, issuing organization, credits) from the CME certificates.
#
# See https://docs.landing.ai/ade/ade-python#extract%3A-getting-started for more details.

# %%
# Import pydantic for schema definition
from pydantic import BaseModel, Field

# Define schema for structured extraction
class CME(BaseModel):
    recipient_name: str = Field(description="Full name of the individual who received the certificate. Only the name. Remove any prefixes such as Mr. Mrs. or Dr. Also remove any credentials that may appear after the name such as BS, MD, DDS, RN")
    issuing_org: str = Field(description="Full name of the organization issuing the certificate.")
    activity_title: str = Field(description="Title of the CME activity or material completed by the recipient.")
    date_awarded: date = Field(description="Date when the certificate or credit was awarded.")
    credit_awarded: str = Field(description="Amount and type of CME credit awarded to the recipient.")
    credit_numeric: float = Field(description="Amount of CME credit awarded.")
    ama_pra_cat1: bool = Field(description="True if the CME credits awarded qualify for AMA PRA Category 1.")
    ama_pra_cat2: bool = Field(description="True if the CME credits awarded qualify for AMA PRA Category 2.")

# Convert Pydantic model to JSON schema
cme_schema = pydantic_to_json_schema(CME)

# %% [markdown]
# ## 📄 Single Document Example
#
# Let's start with a single document to understand the workflow.
#
# ### Two-Step Process: Parse → Extract
#
# **Step 1: Parse**
# The `parse()` method converts the document into structured markdown and chunks with grounding information.
#
# **Step 2: Extract**
# The `extract()` method applies your custom schema to pull specific fields from the markdown.

# %% [markdown]
# ### Step 1: Parse a Single Document

# %%
from landingai_ade.types import ParseResponse, ExtractResponse

if len(file_paths) > 0:
    # Parse the first document
    single_doc = file_paths[0]
    print(f"🔍 Parsing: {single_doc.name}")

    single_parse_result: ParseResponse = client.parse(
        document=single_doc,
        model="dpt-2-latest"
    )

    # Explore the parse result
    print(f"✅ Parse complete!")

    print(f"Markdown length: {len(single_parse_result.markdown)} characters")
    print(f"Chunks: {len(single_parse_result.chunks)}")
    
    print(f"Parsing metadata: {single_parse_result.metadata}")
    print(f"Grounding details: {single_parse_result.grounding}")

    print(f"\n📝 Markdown preview (first 200 chars):")
    print(single_parse_result.markdown[:200] + "...")
# Out:
# 🔍 Parsing: CME_Mendez_ex5.png
# ✅ Parse complete!
# Markdown length: 1090 characters
# Chunks: 7
# Parsing metadata: ParseMetadata(credit_usage=3.0, duration_ms=3151, filename='CME_Mendez_ex5.png', job_id='f169f3c03db344f7b5f7f8fdde90a836', org_id='u3z0u1hn4acl', page_count=1, version='dpt-2-20251103', failed_pages=[])
# Grounding details: {'509bfc0a-6159-4fcb-8630-8101c9be7594': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.13180823624134064, left=0.18170011043548584, right=0.8152531385421753, top=0.0686657726764679), page=0, type='chunkText'), '1f47c7ca-2a8d-4ce5-8eac-a092bc6664da': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.2988176643848419, left=0.3912568986415863, right=0.5997633934020996, top=0.159275621175766), page=0, type='chunkText'), 'e2d834f1-fb00-44e5-b608-8582c4dd8006': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.4080730974674225, left=0.2980690598487854, right=0.6993106603622437, top=0.3120444715023041), page=0, type='chunkText'), 'e9fed24b-5bc4-4d24-bc15-751dbcb65096': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.470710813999176, left=0.11617323756217957, right=0.8805303573608398, top=0.41580647230148315), page=0, type='chunkText'), '61fd0bc4-0df3-46bb-94b4-a30cea846c9f': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.580985426902771, left=0.25879448652267456, right=0.7369762659072876, top=0.48088768124580383), page=0, type='chunkText'), 'f57185ac-f018-47ab-aa99-994e54aa0b31': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.7114155888557434, left=0.0856696367263794, right=0.911274254322052, top=0.5910574793815613), page=0, type='chunkText'), 'a4611f46-36dd-4ab2-819e-0f1337a749e1': GroundingParseResponseGrounding(box=ParseGroundingBox(bottom=0.9686391949653625, left=0.39319151639938354, right=0.6027660369873047, top=0.7362688183784485), page=0, type='chunkLogo')}
#
# 📝 Markdown preview (first 200 chars):
# <a id='509bfc0a-6159-4fcb-8630-8101c9be7594'></a>
#
# ***CONTINUING MEDICAL EDUCATION CERTIFICATE***
#
# <a id='1f47c7ca-2a8d-4ce5-8eac-a092bc6664da'></a>
#
# Medscape
# certifies that
#
# <a id='e2d834f1-fb00-44e5...

# %% [markdown]
# ### Step 2: Extract Structured Fields

# %%
if len(file_paths) > 0:

     # Extract structured data using the schema
    single_extraction_result: ExtractResponse = client.extract(
        markdown=single_parse_result.markdown,  # send the markdown from the parsing step
        schema=cme_schema
    )

    # View the extracted CME data

    print(f"✅ Extraction complete!")
    
    print(f"\n📦 Extracted fields:")
    print(single_extraction_result.extraction)

    print(f"\n📦 Extracted field metadata:")
    print(single_extraction_result.extraction_metadata)

    print(f"\n📦 Extraction process details:")
    print(single_extraction_result.metadata)

# %% [markdown]
# ## 🚀 Run ADE Parse + Extract for All Input Files
#
# Parse all documents in the input folder and save outputs:
# - **Parse JSON** (`{filename}_parse.json`): Full parse response with markdown, chunks, grounding, and metadata
# - **Markdown** (`{filename}.md`): Just the extracted text content
# - **Extract JSON** (`{filename}_extract.json`): Structured extraction results with field metadata
#
# Each output file is named after the input file for easy reference.

# %%
# Optional dictionary to store document types and parse results
results = {}

# Process each document in the folder
for input_file in input_folder.glob("*"):
    if input_file.suffix.lower() not in [".pdf", ".png", ".jpg", ".jpeg"]:
        continue
        
    doc_name = input_file.stem
    print(f"Processing document: {input_file.name}")
    
    # Step 1: Parse the document to extract layout and content
    parse_result: ParseResponse = client.parse(
        document=input_file,
        model="dpt-2-latest"
    )
    print("  ✅ Parsing completed.")
    
    # Save parse results
    parse_json_path = results_folder / f"{doc_name}_parse.json"
    markdown_path = results_folder / f"{doc_name}.md"
    
    with open(parse_json_path, 'w', encoding='utf-8') as f:
        json.dump(parse_result.model_dump(), f, indent=2, ensure_ascii=False, default=str)
    
    with open(markdown_path, 'w', encoding='utf-8') as f:
        f.write(parse_result.markdown)
    
    print(f"  💾 Saved parse JSON and markdown")
   
    # Step 2: Extract document type using the previously loaded schema
    print("  🎯 Running extraction...")
    extraction_result: ExtractResponse = client.extract(
        schema=cme_schema,
        markdown=parse_result.markdown
    )
    print("  ✅ Extraction completed.")
    
    # Save extraction results
    extract_json_path = results_folder / f"{doc_name}_extract.json"
    with open(extract_json_path, 'w', encoding='utf-8') as f:
        json.dump(extraction_result.model_dump(), f, indent=2, ensure_ascii=False, default=str)
    
    print(f"  💾 Saved extraction JSON\n")

    # Store in results dictionary. This will be used later to create a summary dataframe
    results[doc_name] = {
        "parse_result": parse_result,
        "extraction_result": extraction_result
    }

print(f"✅ Processed {len(results)} documents")
# Out:
# Processing document: CME_Mendez_ex5.png
#   ✅ Parsing completed.
#   💾 Saved parse JSON and markdown
#   🎯 Running extraction...
#   ✅ Extraction completed.
#   💾 Saved extraction JSON
#
# Processing document: CME_Mendez_ex4.png
#   ✅ Parsing completed.
#   💾 Saved parse JSON and markdown
#   🎯 Running extraction...
#   ✅ Extraction completed.
#   💾 Saved extraction JSON
#
# Processing document: CME_Mendez_ex1.png
#   ✅ Parsing completed.
#   💾 Saved parse JSON and markdown
#   🎯 Running extraction...
#   ✅ Extraction completed.
#   💾 Saved extraction JSON
#
# Processing document: CME_Mendez_ex3.png
#   ✅ Parsing completed.
#   💾 Saved parse JSON and markdown
#   🎯 Running extraction...
#   ✅ Extraction completed.
#   💾 Saved extraction JSON
#
# Processing document: CME_Mendez_ex2.png
#   ✅ Parsing completed.
#   💾 Saved parse JSON and markdown
#   🎯 Running extraction...
#   ✅ Extraction completed.
#   💾 Saved extraction JSON
#
# ✅ Processed 5 documents

# %%
results
# Out:
# {'CME_Mendez_ex5': {'parse_result': ParseResponse(chunks=[Chunk(id='23fd5471-0717-4ab5-b701-b7414298066a', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.13180823624134064, left=0.18170011043548584, right=0.8152531385421753, top=0.0686657726764679), page=0), markdown="<a id='23fd5471-0717-4ab5-b701-b7414298066a'></a>\n\n***CONTINUING MEDICAL EDUCATION CERTIFICATE***", type='text'), Chunk(id='332c09ab-40b2-4266-a4f4-2880d3c6c95a', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.2988176643848419, left=0.3912568986415863, right=0.5997633934020996, top=0.159275621175766), page=0), markdown="<a id='332c09ab-40b2-4266-a4f4-2880d3c6c95a'></a>\n\nMedscape\ncertifies that", type='text'), Chunk(id='891aab28-5f0c-4574-be29-34952a9e785d', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.4080730974674225, left=0.2980690598487854, right=0.6993106603622437, top=0.3120444715023041), page=0), markdown="<a id='891aab28-5f0c-4574-be29-34952a9e785d'></a>\n\nManoel Cortes Mendez\nhas participated in the enduring material titled", type='text'), Chunk(id='5d546a77-822b-4c1a-a327-5fcd5630ee70', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.470710813999176, left=0.11617323756217957, right=0.8805303573608398, top=0.41580647230148315), page=0), markdown="<a id='5d546a77-822b-4c1a-a327-5fcd5630ee70'></a>\n\nPatient Case: To Screen or Not to Screen for Chronic Kidney Disease", type='text'), Chunk(id='6974c665-2168-489a-946d-075c6c2dccd8', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.580985426902771, left=0.25879448652267456, right=0.7369762659072876, top=0.48088768124580383), page=0), markdown="<a id='6974c665-2168-489a-946d-075c6c2dccd8'></a>\n\nOctober 18, 2022\nand is awarded 0.25 AMA PRA Category 1 Credit(s)™.", type='text'), Chunk(id='9d67a4f3-d933-4c64-a9bd-37cb5f1ce8db', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.7114155888557434, left=0.0856696367263794, right=0.911274254322052, top=0.5910574793815613), page=0), markdown="<a id='9d67a4f3-d933-4c64-a9bd-37cb5f1ce8db'></a>\n\nMedscape, LLC designates this enduring material for a maximum of **0.25** AMA PRA Category 1 Credit(s)™. Physicians should claim only the credit commensurate with the extent of their participation in the activity.", type='text'), Chunk(id='cc3f2237-e3ad-4b04-8011-8cad30775ba2', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.9686391949653625, left=0.39319151639938354, right=0.6027660369873047, top=0.7362688183784485), page=0), markdown="<a id='cc3f2237-e3ad-4b04-8011-8cad30775ba2'></a>\n\n<::logo: Jointly Accredited Provider\nJOINTLY ACCREDITED PROVIDER\nWITH COMMENDATION\nINTERPROFESSIONAL CONTINUING EDUCATION\nThis logo features a circular emblem with a stylized 'A' shape, surrounded by a laurel wreath, with text below.::>", type='logo')], markdown="<a id='23fd5471-0717-4ab5-b701-b7414298066a'></a>\n\n***CONTINUING MEDICAL EDUCATION CERTIFICATE***\n\n<a id='332c09ab-40b2-4266-a4f4-2880d3c6c95a'></a>\n\nMedscape\ncertifies that\n\n<a id='891aab28-5f0c-4574-be29-34952a9e785d'></a>\n\nManoel Cortes Mendez\nhas participated in the enduring material titled\n\n<a id='5d546a77-822b-4c1a-a327-5fcd5630ee70'></a>\n\nPatient Case: To Screen or Not to Screen for Chronic Kidney Disease\n\n<a id='6974c665-2168-489a-946d-075c6c2dccd8'></a>\n\nOctober 18, 2022\nand is awarded 0.25 AMA PRA Category 1 Credit(s)™.\n\n<a id='9d67a4f3-d933-4c64-a9bd-37cb5f1ce8db'></a>\n\nMedscape, LLC designates this enduring material for a maximum of **0.25** AMA PRA Category 1 Credit(s)™. Physicians should claim only the credit commensurate with the extent of their participation in the activity.\n\n<a id='cc3f2237-e3ad-4b04-8011-8cad30775ba2'></a>\n\n<::logo: Jointly Accredited Provider\nJOINTLY ACCREDITED PROVIDER\nWITH COMMENDATION\nINTERPROFESSIONAL CONTINUING EDUCATION\nThis logo features a circular emblem with a stylized 'A' shape, surrounded by a laurel wreath, with text below.::>", metadata=ParseMetadata(credit_usage=3.0, duration_ms=3272, ...
#   'extraction_result': ExtractResponse(extraction={'recipient_name': 'Manoel Cortes Mendez', 'issuing_org': 'Medscape, LLC', 'activity_title': 'Patient Case: To Screen or Not to Screen for Chronic Kidney Disease', 'date_awarded': '2022-10-18', 'credit_awarded': '0.25 AMA PRA Category 1 Credit(s)™', 'credit_numeric': 0.25, 'ama_pra_cat1': True, 'ama_pra_cat2': None}, extraction_metadata={'recipient_name': {'value': 'Manoel Cortes Mendez', 'references': ['891aab28-5f0c-4574-be29-34952a9e785d']}, 'issuing_org': {'value': 'Medscape, LLC', 'references': ['332c09ab-40b2-4266-a4f4-2880d3c6c95a', '9d67a4f3-d933-4c64-a9bd-37cb5f1ce8db']}, 'activity_title': {'value': 'Patient Case: To Screen or Not to Screen for Chronic Kidney Disease', 'references': ['5d546a77-822b-4c1a-a327-5fcd5630ee70']}, 'date_awarded': {'value': '2022-10-18', 'references': ['6974c665-2168-489a-946d-075c6c2dccd8']}, 'credit_awarded': {'value': '0.25 AMA PRA Category 1 Credit(s)™', 'references': ['6974c665-2168-489a-946d-075c6c2dccd8']}, 'credit_numeric': {'value': 0.25, 'references': ['6974c665-2168-489a-946d-075c6c2dccd8', '9d67a4f3-d933-4c64-a9bd-37cb5f1ce8db']}, 'ama_pra_cat1': {'value': True, 'references': ['6974c665-2168-489a-946d-075c6c2dccd8', '9d67a4f3-d933-4c64-a9bd-37cb5f1ce8db']}, 'ama_pra_cat2': {'value': None, 'references': []}}, metadata=Metadata(credit_usage=0.54, duration_ms=6242, filename='upload.md', job_id='35685c6d1e704412ae44f79dfb7162ba', org_id='u3z0u1hn4acl', version='extract-20251024', fallback_model_version=None, schema_violation_error="Extracted data does not completely conform to the requested schema. See below error for details.\nNone is not of type 'boolean'\n\nFailed validating 'type' in schema['properties']['ama_pra_cat2']:\n    {'description': 'True if the CME credits awarded qualify for AMA PRA '\n                    'Category 2.',\n     'title': 'Ama Pra Cat2',\n     'type': 'boolean'}\n\nOn instance['ama_pra_cat2']:\n    None\nPlease read our documentation for more information: https://docs.landing.ai/ade/ade-extract-troubleshoot"))},
#  'CME_Mendez_ex4': {'parse_result': ParseResponse(chunks=[Chunk(id='853255b3-7ffe-44f9-8fe1-0a21b2df0fb3', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.1577368527650833, left=0.25559332966804504, right=0.7508285045623779, top=0.07179759442806244), page=0), markdown="<a id='853255b3-7ffe-44f9-8fe1-0a21b2df0fb3'></a>\n\n**CERTIFICATE OF ATTENDANCE** from The University of Texas MD Anderson Cancer Center", type='text'), Chunk(id='0df7409d-2070-40d4-b216-cce320b3df17', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.22899194061756134, left=0.36421719193458557, right=0.6440703868865967, top=0.19447140395641327), page=0), markdown="<a id='0df7409d-2070-40d4-b216-cce320b3df17'></a>\n\n***Manoel Cortes Mendez, BS***", type='text'), Chunk(id='46b2a353-bb84-4a24-a6e9-9a810644b759', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.299086332321167, left=0.30389147996902466, right=0.7031760811805725, top=0.2664341330528259), page=0), markdown="<a id='46b2a353-bb84-4a24-a6e9-9a810644b759'></a>\n\nhas participated in the enduring material titled", type='text'), Chunk(id='6f049e31-2054-4816-8e8b-077ec3a46574', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.3680264949798584, left=0.20013782382011414, right=0.8046188354492188, top=0.3138744831085205), page=0), markdown="<a id='6f049e31-2054-4816-8e8b-077ec3a46574'></a>\n\nCancer Survivorship Series: Module 1 - Overview of Survivorship\non October 18, 2022.", type='text'), Chunk(id='5be2a9fc-2bf6-43a2-9c9e-bacf8cef989d', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.42003554105758667, left=0.12031584978103638, right=0.8831924796104431, top=0.3836681842803955), page=0), markdown="<a id='5be2a9fc-2bf6-43a2-9c9e-bacf8cef989d'></a>\n\nManoel Cortes Mendez, BS is awarded a total of 0.75 AMA PRA Category 1 Credit(s)™.", type='text'), Chunk(id='4de421c5-9105-4c1f-a78e-51889690d18d', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.5120536684989929, left=0.17448946833610535, right=0.831977128982544, top=0.4320273995399475), page=0), markdown="<a id='4de421c5-9105-4c1f-a78e-51889690d18d'></a>\n\nThe University of Texas MD Anderson Cancer Center is accredited by the\nAccreditation Council for Continuing Medical Education (ACCME) to provide\ncontinuing medical education for physicians.", type='text'), Chunk(id='397e9eba-0805-4009-abbb-a0d72618d3e1', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.6551883816719055, left=0.10279756784439087, right=0.9053316712379456, top=0.572975218296051), page=0), markdown="<a id='397e9eba-0805-4009-abbb-a0d72618d3e1'></a>\n\nThe University of Texas MD Anderson Cancer Center designates this enduring material for a maxiumum of 0.75 AMA PRA Category 1 Credit(s)™. Physicians should claim only the credit commensurate with the extent of their participation in the activity.", type='text'), Chunk(id='f21e01a9-998d-4968-81d5-acbf80f82291', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.7396552562713623, left=0.34248048067092896, right=0.6634277701377869, top=0.7119081020355225), page=0), markdown="<a id='f21e01a9-998d-4968-81d5-acbf80f82291'></a>\n\nPlease retain this document for your records.", type='text'), Chunk(id='08df4a50-2886-442e-9fa6-badaa63490d8', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.9807330369949341, left=0.33835405111312866, right=0.6704689860343933, top=0.7986842393875122), page=0), markdown='<a id=\'08df4a50-2886-442e-9fa6-badaa63490d8\'></a>\n\n<::logo: The University of Texas MD Anderson Cancer Center\nTHE UNIVERSITY OF TEXAS\nMD Anderson\nCancer Center\nMaking Cancer History\nIt features a red line striking through the word "Cancer" in "Cancer Center."::>', type='logo')], markdown='<a id=\'853255b3-7ffe-44f9-8fe1-0a21b2df0fb3\'></a>\n\n**CERTIFICATE OF ATTENDANCE** from The University of Texas MD Anderson Cancer Center\n\n<a id=\'0df7409d-2070-40d4-b216-cce320b3df17\'></a>\n\n***Manoel Cortes Mendez, BS***\n\n<a id=\'46b2a353-bb84-4a24-a6e9-9a810644b759\'></a>\n\nhas participa ...
#   'extraction_result': ExtractResponse(extraction={'recipient_name': 'Manoel Cortes Mendez', 'issuing_org': 'The University of Texas MD Anderson Cancer Center', 'activity_title': 'Cancer Survivorship Series: Module 1 - Overview of Survivorship', 'date_awarded': '2022-10-18', 'credit_awarded': '0.75 AMA PRA Category 1 Credit(s)™', 'credit_numeric': 0.75, 'ama_pra_cat1': True, 'ama_pra_cat2': None}, extraction_metadata={'recipient_name': {'value': 'Manoel Cortes Mendez', 'references': ['0df7409d-2070-40d4-b216-cce320b3df17']}, 'issuing_org': {'value': 'The University of Texas MD Anderson Cancer Center', 'references': ['853255b3-7ffe-44f9-8fe1-0a21b2df0fb3']}, 'activity_title': {'value': 'Cancer Survivorship Series: Module 1 - Overview of Survivorship', 'references': ['6f049e31-2054-4816-8e8b-077ec3a46574']}, 'date_awarded': {'value': '2022-10-18', 'references': ['6f049e31-2054-4816-8e8b-077ec3a46574']}, 'credit_awarded': {'value': '0.75 AMA PRA Category 1 Credit(s)™', 'references': ['5be2a9fc-2bf6-43a2-9c9e-bacf8cef989d']}, 'credit_numeric': {'value': 0.75, 'references': ['5be2a9fc-2bf6-43a2-9c9e-bacf8cef989d']}, 'ama_pra_cat1': {'value': True, 'references': ['5be2a9fc-2bf6-43a2-9c9e-bacf8cef989d', '397e9eba-0805-4009-abbb-a0d72618d3e1']}, 'ama_pra_cat2': {'value': None, 'references': []}}, metadata=Metadata(credit_usage=0.6528, duration_ms=4658, filename='upload.md', job_id='dcf8baa6ac2148c6a9637e6a6f68dbc0', org_id='u3z0u1hn4acl', version='extract-20251024', fallback_model_version=None, schema_violation_error="Extracted data does not completely conform to the requested schema. See below error for details.\nNone is not of type 'boolean'\n\nFailed validating 'type' in schema['properties']['ama_pra_cat2']:\n    {'description': 'True if the CME credits awarded qualify for AMA PRA '\n                    'Category 2.',\n     'title': 'Ama Pra Cat2',\n     'type': 'boolean'}\n\nOn instance['ama_pra_cat2']:\n    None\nPlease read our documentation for more information: https://docs.landing.ai/ade/ade-extract-troubleshoot"))},
#  'CME_Mendez_ex1': {'parse_result': ParseResponse(chunks=[Chunk(id='4d4a7cf6-e3bf-4ce6-8c14-bb63ead659b7', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.21501287817955017, left=0.3817287087440491, right=0.6136975288391113, top=0.06890808790922165), page=0), markdown="<a id='4d4a7cf6-e3bf-4ce6-8c14-bb63ead659b7'></a>\n\n<::logo: The Warren Alpert Medical School of Brown University\nTHE WARREN ALPERT\nMedical School\nBROWN UNIVERSITY\nA coat of arms with a griffin and a shield with books, accompanied by text in brown and black.::>", type='logo'), Chunk(id='553fcade-4964-4f4d-bec2-22300923abae', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.2632497251033783, left=0.37047290802001953, right=0.632434606552124, top=0.2250184416770935), page=0), markdown="<a id='553fcade-4964-4f4d-bec2-22300923abae'></a>\n\nWarren Alpert Medical School certifies that", type='text'), Chunk(id='768937c9-ed87-4c4c-9696-6086564077d4', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.33767786622047424, left=0.3942425847053528, right=0.6059193015098572, top=0.28994664549827576), page=0), markdown="<a id='768937c9-ed87-4c4c-9696-6086564077d4'></a>\n\nManoel Cortes Mendez", type='text'), Chunk(id='4d2ae783-408c-4a2c-aec9-5450e66c6846', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.40556076169013977, left=0.32773664593696594, right=0.674296498298645, top=0.3651076853275299), page=0), markdown="<a id='4d2ae783-408c-4a2c-aec9-5450e66c6846'></a>\n\nhas participated in the enduring educational activity titled", type='text'), Chunk(id='58f86398-f8cd-4001-834b-7c6110d233fa', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.5048971772193909, left=0.0871066153049469, right=0.9101028442382812, top=0.4427395761013031), page=0), markdown="<a id='58f86398-f8cd-4001-834b-7c6110d233fa'></a>\n\nFears, Bias and Discrimination - Substance Use Disorder Patient Care", type='text'), Chunk(id='f56ec3a7-513b-4b3c-afbe-5e54f59c5733', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.5863127112388611, left=0.4380836486816406, right=0.5635405778884888, top=0.5485950112342834), page=0), markdown="<a id='f56ec3a7-513b-4b3c-afbe-5e54f59c5733'></a>\n\nOn August 19, 2022", type='text'), Chunk(id='2b4e046e-7165-40c1-97f5-ffafd63627da', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.6428968906402588, left=0.34447264671325684, right=0.6571701765060425, top=0.6016234159469604), page=0), markdown="<a id='2b4e046e-7165-40c1-97f5-ffafd63627da'></a>\n\nand is awarded 1.00 AMA PRA Category 1 Credits™", type='text'), Chunk(id='f60c8b35-e155-477a-944d-00520e273697', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.7176735997200012, left=0.05493450164794922, right=0.9431998133659363, top=0.6540207266807556), page=0), markdown="<a id='f60c8b35-e155-477a-944d-00520e273697'></a>\n\nThis program qualifies for 1.0 hours CME Credit in Opioid Pain Management/Chronic Pain Management, one of the required areas of section 6.0; 6.2.1 RI CME re-licensure requirements.", type='text'), Chunk(id='12a9c395-a989-400f-a17d-0c85105c211a', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.7685748338699341, left=0.08363807201385498, right=0.9081079363822937, top=0.7304924726486206), page=0), markdown="<a id='12a9c395-a989-400f-a17d-0c85105c211a'></a>\n\nThe Warren Alpert Medical School of Brown University is accredited by the Accreditation Council for Continuing Medical Education to provide continuing medical education for physicians.", type='text'), Chunk(id='57200aa8-d3a6-4e4c-ab20-af89f806bf06', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.8867032527923584, left=0.37671706080436707, right=0.6195620894432068, top=0.7788004875183105), page=0), markdown='<a id=\'57200aa8-d3a6-4e4c-ab20-af89f806bf06\'></a>\n\n<::attestation: Signature\nSigned\nSignature: legible\nMaria Sullivan\nDirector, Continuing Medical Education\nA black handwritten signature "Maria Sullivan" is positioned above the printed text "Director, Continuing Medical Education" ...
#   'extraction_result': ExtractResponse(extraction={'recipient_name': 'Manoel Cortes Mendez', 'issuing_org': 'The Warren Alpert Medical School of Brown University', 'activity_title': 'Fears, Bias and Discrimination - Substance Use Disorder Patient Care', 'date_awarded': '2022-08-19', 'credit_awarded': '1.00 AMA PRA Category 1 Credits™', 'credit_numeric': 1.0, 'ama_pra_cat1': True, 'ama_pra_cat2': None}, extraction_metadata={'recipient_name': {'value': 'Manoel Cortes Mendez', 'references': ['768937c9-ed87-4c4c-9696-6086564077d4']}, 'issuing_org': {'value': 'The Warren Alpert Medical School of Brown University', 'references': ['4d4a7cf6-e3bf-4ce6-8c14-bb63ead659b7', '553fcade-4964-4f4d-bec2-22300923abae']}, 'activity_title': {'value': 'Fears, Bias and Discrimination - Substance Use Disorder Patient Care', 'references': ['58f86398-f8cd-4001-834b-7c6110d233fa']}, 'date_awarded': {'value': '2022-08-19', 'references': ['f56ec3a7-513b-4b3c-afbe-5e54f59c5733']}, 'credit_awarded': {'value': '1.00 AMA PRA Category 1 Credits™', 'references': ['2b4e046e-7165-40c1-97f5-ffafd63627da']}, 'credit_numeric': {'value': 1.0, 'references': ['2b4e046e-7165-40c1-97f5-ffafd63627da']}, 'ama_pra_cat1': {'value': True, 'references': ['2b4e046e-7165-40c1-97f5-ffafd63627da']}, 'ama_pra_cat2': {'value': None, 'references': []}}, metadata=Metadata(credit_usage=0.7245999999999999, duration_ms=6602, filename='upload.md', job_id='a3e5198b440546f9a74fe2eabe8c4db9', org_id='u3z0u1hn4acl', version='extract-20251024', fallback_model_version=None, schema_violation_error="Extracted data does not completely conform to the requested schema. See below error for details.\nNone is not of type 'boolean'\n\nFailed validating 'type' in schema['properties']['ama_pra_cat2']:\n    {'description': 'True if the CME credits awarded qualify for AMA PRA '\n                    'Category 2.',\n     'title': 'Ama Pra Cat2',\n     'type': 'boolean'}\n\nOn instance['ama_pra_cat2']:\n    None\nPlease read our documentation for more information: https://docs.landing.ai/ade/ade-extract-troubleshoot"))},
#  'CME_Mendez_ex3': {'parse_result': ParseResponse(chunks=[Chunk(id='70d1b725-d83d-48d4-8954-20e51667c8b2', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.3272070288658142, left=0.04761023074388504, right=0.22455552220344543, top=0.08180047571659088), page=0), markdown='<a id=\'70d1b725-d83d-48d4-8954-20e51667c8b2\'></a>\n\n<::logo: Johns Hopkins Medicine\nJOHNS HOPKINS\nMEDICINE\nTurner 20 / 720 Rutland Avenue\nBaltimore, Maryland 21205-2195\n(410)502-9634 T / (866)510-7088 F\nThe logo features a yellow dome structure on a blue shield-like shape, with the words "JOHNS HOPKINS MEDICINE" in dark blue text below.::>', type='logo'), Chunk(id='1d8245ab-9f31-406c-ac1b-2467584b38b8', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.3243864178657532, left=0.3056454658508301, right=0.6662086248397827, top=0.1693696826696396), page=0), markdown="<a id='1d8245ab-9f31-406c-ac1b-2467584b38b8'></a>\n\nCERTIFICATE OF ATTENDANCE\n\nJohns Hopkins University School of Medicine\n\nCertifies that", type='text'), Chunk(id='ee93e7ed-4eb5-40ea-89b6-98e8ef2cd09b', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.623545229434967, left=0.07257243990898132, right=0.8272275924682617, top=0.48901185393333435), page=0), markdown="<a id='ee93e7ed-4eb5-40ea-89b6-98e8ef2cd09b'></a>\n\nManoel Cortes Mendez, BS\n\nhas participated in the Enduring Material titled Pain Medicine Management - Pain Management of Low Back Pain on 08/18/2022. This activity was designated for 1.00 AMA PRA Category 1 Credit(s)™.", type='text'), Chunk(id='96f834e2-4fb6-42e9-9957-18efa7fcea94', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.9993059039115906, left=0.6581355929374695, right=0.852717936038971, top=0.9171302914619446), page=0), markdown="<a id='96f834e2-4fb6-42e9-9957-18efa7fcea94'></a>\n\n<::attestation: Signature\nSigned\nSignature: illegible\nA blue handwritten signature is centered in the image.::>", type='attestation')], markdown='<a id=\'70d1b725-d83d-48d4-8954-20e51667c8b2\'></a>\n\n<::logo: Johns Hopkins Medicine\nJOHNS HOPKINS\nMEDICINE\nTurner 20 / 720 Rutland Avenue\nBaltimore, Maryland 21205-2195\n(410)502-9634 T / (866)510-7088 F\nThe logo features a yellow dome structure on a blue shield-like shape, with the words "JOHNS HOPKINS MEDICINE" in dark blue text below.::>\n\n<a id=\'1d8245ab-9f31-406c-ac1b-2467584b38b8\'></a>\n\nCERTIFICATE OF ATTENDANCE\n\nJohns Hopkins University School of Medicine\n\nCertifies that\n\n<a id=\'ee93e7ed-4eb5-40ea-89b6-98e8ef2cd09b\'></a>\n\nManoel Cortes Mendez, BS\n\nhas participated in the Enduring Material titled Pain Medicine Management - Pain Management of Low Back Pain on 08/18/2022. This activity was designated for 1.00 AMA PRA Category 1 Credit(s)™.\n\n<a id=\'96f834e2-4fb6-42e9-9957-18efa7fcea94\'></a>\n\n<::attestation: Signature\nSigned\nSignature: illegible\nA blue handwritten signature is centered in the image.::>', metadata=ParseMetadata(credit_usage=3.0, duration_ms=3398, filename='CME_Mendez_ex3.png', job_id='9d6e6d99b2944a5d99894aa7e064f34b', org_id='u3z0u1hn4acl', page_count=1, version='dpt-2-20251103', failed_pages=[]), splits=[Split(chunks=['70d1b725-d83d-48d4-8954-20e51667c8b2', '1d8245ab-9f31-406c-ac1b-2467584b38b8', 'ee93e7ed-4eb5-40ea-89b6-98e8ef2cd09b', '96f834e2-4fb6-42e9-9957-18efa7fcea94'], class_='full', identifier='full', markdown='<a id=\'70d1b725-d83d-48d4-8954-20e51667c8b2\'></a>\n\n<::logo: Johns Hopkins Medicine\nJOHNS HOPKINS\nMEDICINE\nTurner 20 / 720 Rutland Avenue\nBaltimore, Maryland 21205-2195\n(410)502-9634 T / (866)510-7088 F\nThe logo features a yellow dome structure on a blue shield-like shape, with the words "JOHNS HOPKINS MEDICINE" in dark blue text below.::>\n\n<a id=\'1d8245ab-9f31-406c-ac1b-2467584b38b8\'></a>\n\nCERTIFICATE OF ATTENDANCE\n\nJohns Hopkins University School of Medicine\n\nCertifies that\n\n<a id=\'ee93e7ed-4eb5-40ea-89b6-98e8ef2cd09b\'></a>\n\nManoel Cortes Mendez, BS\n\nhas participated in the Enduring Material titled Pain Medicine Mana ...
#   'extraction_result': ExtractResponse(extraction={'recipient_name': 'Manoel Cortes Mendez', 'issuing_org': 'Johns Hopkins University School of Medicine', 'activity_title': 'Pain Medicine Management - Pain Management of Low Back Pain', 'date_awarded': '2022-08-18', 'credit_awarded': '1.00 AMA PRA Category 1 Credit(s)™', 'credit_numeric': 1.0, 'ama_pra_cat1': True, 'ama_pra_cat2': None}, extraction_metadata={'recipient_name': {'value': 'Manoel Cortes Mendez', 'references': ['ee93e7ed-4eb5-40ea-89b6-98e8ef2cd09b']}, 'issuing_org': {'value': 'Johns Hopkins University School of Medicine', 'references': ['1d8245ab-9f31-406c-ac1b-2467584b38b8']}, 'activity_title': {'value': 'Pain Medicine Management - Pain Management of Low Back Pain', 'references': ['ee93e7ed-4eb5-40ea-89b6-98e8ef2cd09b']}, 'date_awarded': {'value': '2022-08-18', 'references': ['ee93e7ed-4eb5-40ea-89b6-98e8ef2cd09b']}, 'credit_awarded': {'value': '1.00 AMA PRA Category 1 Credit(s)™', 'references': ['ee93e7ed-4eb5-40ea-89b6-98e8ef2cd09b']}, 'credit_numeric': {'value': 1.0, 'references': ['ee93e7ed-4eb5-40ea-89b6-98e8ef2cd09b']}, 'ama_pra_cat1': {'value': True, 'references': ['ee93e7ed-4eb5-40ea-89b6-98e8ef2cd09b']}, 'ama_pra_cat2': {'value': None, 'references': []}}, metadata=Metadata(credit_usage=0.5258, duration_ms=5213, filename='upload.md', job_id='a886acede873468294075bd10d831a84', org_id='u3z0u1hn4acl', version='extract-20251024', fallback_model_version=None, schema_violation_error="Extracted data does not completely conform to the requested schema. See below error for details.\nNone is not of type 'boolean'\n\nFailed validating 'type' in schema['properties']['ama_pra_cat2']:\n    {'description': 'True if the CME credits awarded qualify for AMA PRA '\n                    'Category 2.',\n     'title': 'Ama Pra Cat2',\n     'type': 'boolean'}\n\nOn instance['ama_pra_cat2']:\n    None\nPlease read our documentation for more information: https://docs.landing.ai/ade/ade-extract-troubleshoot"))},
#  'CME_Mendez_ex2': {'parse_result': ParseResponse(chunks=[Chunk(id='580b3443-0448-4dd0-8782-256eb3254a66', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.29143989086151123, left=0.2804635167121887, right=0.7190355658531189, top=0.08393116295337677), page=0), markdown='<a id=\'580b3443-0448-4dd0-8782-256eb3254a66\'></a>\n\n<::logo: Stanford Medicine\nStanford Medicine\nA maroon shield with three internal sections: a fern, a medical caduceus, and an abstract shape, all in white, accompanies the red text "Stanford" and the black text "MEDICINE"::>', type='logo'), Chunk(id='3ae64901-9273-431f-8ac2-7cd97251e3e9', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.41620951890945435, left=0.2726283669471741, right=0.7245925068855286, top=0.31513482332229614), page=0), markdown="<a id='3ae64901-9273-431f-8ac2-7cd97251e3e9'></a>\n\nStanford University School of Medicine certifies that\nManoel Cortes Mendez, BS", type='text'), Chunk(id='30e9f752-ddfb-4692-a822-1ede7ee92eb1', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.4822801649570465, left=0.23967155814170837, right=0.7585526704788208, top=0.4308590590953827), page=0), markdown="<a id='30e9f752-ddfb-4692-a822-1ede7ee92eb1'></a>\n\nhas participated for _2.50_ hours in the Enduring Material titled", type='text'), Chunk(id='3e8a3adf-3437-40cb-8ee1-afbcd68fdffa', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.5507793426513672, left=0.29683440923690796, right=0.7017825245857239, top=0.4958336353302002), page=0), markdown="<a id='3e8a3adf-3437-40cb-8ee1-afbcd68fdffa'></a>\n\nIntroduction to Food and Health", type='text'), Chunk(id='e7290719-0e1f-44b7-81b8-1a68a33b9deb', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.611706554889679, left=0.4345460534095764, right=0.5687195658683777, top=0.5666806101799011), page=0), markdown="<a id='e7290719-0e1f-44b7-81b8-1a68a33b9deb'></a>\n\non 06/27/2022", type='text'), Chunk(id='f0b5a2b3-4949-42e4-bb3c-d8ef3e466e5a', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.667594313621521, left=0.2731092572212219, right=0.7263872027397156, top=0.6241222620010376), page=0), markdown="<a id='f0b5a2b3-4949-42e4-bb3c-d8ef3e466e5a'></a>\n\nThis Activity was designated for **2.50** *AMA PRA Category 1 Credit(s)*™", type='text'), Chunk(id='9ec6e791-b4f9-4abb-8912-a18be74839ad', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.8346899151802063, left=0.05367165803909302, right=0.8952194452285767, top=0.6814711689949036), page=0), markdown="<a id='9ec6e791-b4f9-4abb-8912-a18be74839ad'></a>\n\nJOINTLY ACCREDITED PROVIDER\nINTERPROFESSIONAL CONTINUING EDUCATION\n\nAccreditation\nIn support of improving patient care, Stanford Medicine is jointly accredited by the Accreditation Council for\nContinuing Medical Education (ACCME), the Accreditation Council for Pharmacy Education (ACPE), and the\nAmerican Nurses Credentialing Center (ANCC), to provide continuing education for the healthcare team.", type='text'), Chunk(id='56b3c9d6-da5e-432a-8632-25332a8aef76', grounding=ChunkGrounding(box=ParseGroundingBox(bottom=0.9931328892707825, left=0.6252646446228027, right=0.9524755477905273, top=0.8421760201454163), page=0), markdown="<a id='56b3c9d6-da5e-432a-8632-25332a8aef76'></a>\n\n<::attestation: Signature\nSigned\nSignature: legible\nDaryl Oakes, MD\nAssociate Dean for Continuing Medical Education\nA black, stylized signature is placed above the typed name and title, centered in the image.::>", type='attestation')], markdown='<a id=\'580b3443-0448-4dd0-8782-256eb3254a66\'></a>\n\n<::logo: Stanford Medicine\nStanford Medicine\nA maroon shield with three internal sections: a fern, a medical caduceus, and an abstract shape, all in white, accompanies the red text "Stanford" and the black text "MEDICINE"::>\n\n<a id=\'3ae64901-9273-431f-8ac2-7cd97251e3e9\'></a>\n\nStanford University School of Medicine certifies that\nManoel Cortes Mendez, BS\n\n<a id=\'30e9f752-ddfb-4692-a822-1ede7ee92eb1\'></a>\n\nhas participated for _2.50_ h ...
#   'extraction_result': ExtractResponse(extraction={'recipient_name': 'Manoel Cortes Mendez', 'issuing_org': 'Stanford University School of Medicine', 'activity_title': 'Introduction to Food and Health', 'date_awarded': '2022-06-27', 'credit_awarded': '2.50 AMA PRA Category 1 Credit(s)', 'credit_numeric': 2.5, 'ama_pra_cat1': True, 'ama_pra_cat2': None}, extraction_metadata={'recipient_name': {'value': 'Manoel Cortes Mendez', 'references': ['3ae64901-9273-431f-8ac2-7cd97251e3e9']}, 'issuing_org': {'value': 'Stanford University School of Medicine', 'references': ['3ae64901-9273-431f-8ac2-7cd97251e3e9']}, 'activity_title': {'value': 'Introduction to Food and Health', 'references': ['3e8a3adf-3437-40cb-8ee1-afbcd68fdffa']}, 'date_awarded': {'value': '2022-06-27', 'references': ['e7290719-0e1f-44b7-81b8-1a68a33b9deb']}, 'credit_awarded': {'value': '2.50 AMA PRA Category 1 Credit(s)', 'references': ['f0b5a2b3-4949-42e4-bb3c-d8ef3e466e5a']}, 'credit_numeric': {'value': 2.5, 'references': ['f0b5a2b3-4949-42e4-bb3c-d8ef3e466e5a']}, 'ama_pra_cat1': {'value': True, 'references': ['f0b5a2b3-4949-42e4-bb3c-d8ef3e466e5a']}, 'ama_pra_cat2': {'value': None, 'references': []}}, metadata=Metadata(credit_usage=0.6068, duration_ms=5209, filename='upload.md', job_id='647683023a734e718cabc0340c004d00', org_id='u3z0u1hn4acl', version='extract-20251024', fallback_model_version=None, schema_violation_error="Extracted data does not completely conform to the requested schema. See below error for details.\nNone is not of type 'boolean'\n\nFailed validating 'type' in schema['properties']['ama_pra_cat2']:\n    {'description': 'True if the CME credits awarded qualify for AMA PRA '\n                    'Category 2.',\n     'title': 'Ama Pra Cat2',\n     'type': 'boolean'}\n\nOn instance['ama_pra_cat2']:\n    None\nPlease read our documentation for more information: https://docs.landing.ai/ade/ade-extract-troubleshoot"))}}

# %% [markdown]
# ## 📊 Define Helper Functions
#
# Helper functions to flatten nested dictionaries and create a summary DataFrame from extraction results.

# %%
# Define helper functions that flattens arbitrarily nested dicts and lists into flat, DataFrame-friendly key/value pairs.

import pandas as pd
from typing import Any, Dict, List, Tuple

def flatten_dict(
    data: Dict[str, Any],
    parent_key: str = "",
    sep: str = "_"
) -> Dict[str, Any]:
    items = {}
    for k, v in data.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k

        if isinstance(v, dict):
            items.update(flatten_dict(v, new_key, sep))
        elif isinstance(v, list):
            items[new_key] = str(v)  # lists → string for DataFrame safety
        else:
            items[new_key] = v

    return items


def create_summary_dataframe(
    extraction_results: List[Tuple[Any, Any, str]]
) -> pd.DataFrame:
    records = []

    for _, extract_result, doc_name in extraction_results:
        extraction = extract_result.extraction or {}
        metadata = extract_result.extraction_metadata or {}

        # Flatten extraction fields
        flat_extraction = flatten_dict(extraction)

        record = {
            "document_name": doc_name,
            **flat_extraction,
        }

        # Attach metadata references generically
        for field, meta in metadata.items():
            refs = meta.get("references") if isinstance(meta, dict) else None
            if refs is not None:
                record[f"{field}_chunks"] = str(refs)

        records.append(record)

    return pd.DataFrame(records)

# %% [markdown]
# ## 💾 Convert to Table and Save
#
# Convert the field extractions to a pandas dataframe. Save it to the results folder created earlier.

# %%
print("\n📊 Creating summary DataFrame...")

df = create_summary_dataframe(extraction_results)

df
# Out:
# 📊 Creating summary DataFrame...
#     document_name        recipient_name  \
# 0  CME_Mendez_ex5  Manoel Cortes Mendez
# 1  CME_Mendez_ex4  Manoel Cortes Mendez
# 2  CME_Mendez_ex1  Manoel Cortes Mendez
# 3  CME_Mendez_ex3  Manoel Cortes Mendez
# 4  CME_Mendez_ex2  Manoel Cortes Mendez
#
#                                          issuing_org  \
# 0                                      Medscape, LLC
# 1  The University of Texas MD Anderson Cancer Center
# 2  The Warren Alpert Medical School of Brown Univ...
# 3        Johns Hopkins University School of Medicine
# 4             Stanford University School of Medicine
#
#                                       activity_title date_awarded  \
# 0  Patient Case: To Screen or Not to Screen for C...   2022-10-18
# 1  Cancer Survivorship Series: Module 1 - Overvie...   2022-10-18
# 2  Fears, Bias and Discrimination - Substance Use...   2022-08-19
# 3  Pain Medicine Management - Pain Management of ...   2022-08-18
# 4                    Introduction to Food and Health   2022-06-27
#
#                        credit_awarded  credit_numeric  ama_pra_cat1  \
# 0  0.25 AMA PRA Category 1 Credit(s)™            0.25          True
# 1  0.75 AMA PRA Category 1 Credit(s)™            0.75          True
# 2    1.00 AMA PRA Category 1 Credits™            1.00          True
# 3  1.00 AMA PRA Category 1 Credit(s)™            1.00          True
# 4   2.50 AMA PRA Category 1 Credit(s)            2.50          True
#
#   ama_pra_cat2                     recipient_name_chunks  \
# 0         None  ['891aab28-5f0c-4574-be29-34952a9e785d']
# 1         None  ['0df7409d-2070-40d4-b216-cce320b3df17']
# 2         None  ['768937c9-ed87-4c4c-9696-6086564077d4']
# 3         None  ['ee93e7ed-4eb5-40ea-89b6-98e8ef2cd09b']
# 4         None  ['3ae64901-9273-431f-8ac2-7cd97251e3e9']
#
#                                   issuing_org_chunks  \
# 0  ['332c09ab-40b2-4266-a4f4-2880d3c6c95a', '9d67...
# 1           ['853255b3-7ffe-44f9-8fe1-0a21b2df0fb3']
# 2  ['4d4a7cf6-e3bf-4ce6-8c14-bb63ead659b7', '553f...
# 3           ['1d8245ab-9f31-406c-ac1b-2467584b38b8']
# 4           ['3ae64901-9273-431f-8ac2-7cd97251e3e9']
#
#                       activity_title_chunks  \
# 0  ['5d546a77-822b-4c1a-a327-5fcd5630ee70']
# 1  ['6f049e31-2054-4816-8e8b-077ec3a46574']
# 2  ['58f86398-f8cd-4001-834b-7c6110d233fa']
# 3  ['ee93e7ed-4eb5-40ea-89b6-98e8ef2cd09b']
# 4  ['3e8a3adf-3437-40cb-8ee1-afbcd68fdffa']
#
#                         date_awarded_chunks  \
# 0  ['6974c665-2168-489a-946d-075c6c2dccd8']
# 1  ['6f049e31-2054-4816-8e8b-077ec3a46574']
# 2  ['f56ec3a7-513b-4b3c-afbe-5e54f59c5733']
# 3  ['ee93e7ed-4eb5-40ea-89b6-98e8ef2cd09b']
# 4  ['e7290719-0e1f-44b7-81b8-1a68a33b9deb']
#
#                       credit_awarded_chunks  \
# 0  ['6974c665-2168-489a-946d-075c6c2dccd8']
# 1  ['5be2a9fc-2bf6-43a2-9c9e-bacf8cef989d']
# 2  ['2b4e046e-7165-40c1-97f5-ffafd63627da']
# 3  ['ee93e7ed-4eb5-40ea-89b6-98e8ef2cd09b']
# 4  ['f0b5a2b3-4949-42e4-bb3c-d8ef3e466e5a']
#
#                                credit_numeric_chunks  \
# 0  ['6974c665-2168-489a-946d-075c6c2dccd8', '9d67...
# 1           ['5be2a9fc-2bf6-43a2-9c9e-bacf8cef989d']
# 2           ['2b4e046e-7165-40c1-97f5-ffafd63627da']
# 3           ['ee93e7ed-4eb5-40ea-89b6-98e8ef2cd09b']
# 4           ['f0b5a2b3-4949-42e4-bb3c-d8ef3e466e5a']
#
#                                  ama_pra_cat1_chunks ama_pra_cat2_chunks
# 0  ['6974c665-2168-489a-946d-075c6c2dccd8', '9d67...                  []
# 1  ['5be2a9fc-2bf6-43a2-9c9e-bacf8cef989d', '397e...                  []
# 2           ['2b4e046e-7165-40c1-97f5-ffafd63627da']                  []
# 3           ['ee93e7ed-4eb5-40ea-89b6-98e8ef2cd09b']                  []
# 4           ['f0b5a2b3-4949-42e4-bb3c-d8ef3e466e5a']                  []

# %%
# Save the DataFrame to a CSV file inside the results_folder
csv_path = results_folder / "cme_output.csv"
df.to_csv(csv_path, index=False)

# %% [markdown]
# ## ✅ Wrap-Up
#
# You’ve now used LandingAI’s ADE to:
# - Parse and extract data from images or PDFs
# - Define custom fields using `pydantic`
# - Export structured results to a table
#
# To learn more, visit the [LandingAI Documentation](https://docs.landing.ai/ade/ade-overview).
